# %%
import pandas as pd
import os
from spacy.lemmatizer import Lemmatizer, ADJ, NOUN, VERB
import spacy
import numpy as np
import distance

# %%
def precision(y_true, y_pred):
    i = set()
    len1 = len(y_pred)
    for pred in y_pred:
        for true in y_true:
            if pred == true:
                i.add(pred)
                break
            if len(true) == len(pred):
                if distance.hamming(true,pred) < 7:
                    i.add(pred)
    if len1 == 0:
        return 0.0
    else:
        return float(len(i) / len1)


def recall(y_true, y_pred):
    i = set()
    if len(y_true) == 0:
        return 0.0
    else:
        for pred in y_pred:
            for true in y_true:
                if pred == true:
                    i.add(pred)
                    break
                if len(true) == len(pred):
                    if distance.hamming(true,pred) < 7:
                        i.add(pred)
        return float(len(i) / len(y_true))


def f1(y_true, y_pred):
    p = precision(y_true, y_pred)
    r = recall(y_true, y_pred)
    if p + r == 0:
        return 0.0
    else:
        return 2 * (p * r) / (p + r)
    
def get_PI(filename):
    getFilename = os.path.basename(filename)
    filename, ext = getFilename.split(".")
    if "_" in filename:
        filename, rest = filename.split("_", 1)
    return filename

# %%
os.chdir(r"C:\Users\Goegg\OneDrive\Desktop\Durchgänge")

# %%
# create df out of goldstandard
goldstandard = pd.ExcelFile(r"GOLDSTANDARD.xlsx")
# choose model-combinations for predictions:
directory = r"2. TFIDF - FLAIR\MI_Schlagworte_Composed"
extension = ".xlsx"
nlp = spacy.load("de_core_news_lg")
lemmatizer = nlp.vocab.morphology.lemmatizer

# %%
#Geographischer Index

all_geo_precision = []
all_geo_recall = []
all_geo_f1 = []
for filename in os.listdir(r"C:\Users\Goegg\OneDrive\Desktop\zu annotieren"):
    
    pi_name = get_PI(filename)
    print("Presseinformation:", pi_name)
    #get geo-pred
    df_pred = pd.read_excel(os.path.join(directory, pi_name + extension), header=0)
    pred_geo_out = df_pred['Geographischer Index:'].tolist()
    pred_geo = [x for x in pred_geo_out if x == x]
    #get geo-gold
    df_gold = pd.read_excel(goldstandard, pi_name)
    gold_geo_out = df_gold['Geographischer Index'].tolist()
    gold_geo = [lemmatizer(x, NOUN)[0].lower() for x in gold_geo_out if x == x]
    print("Goldstandard:", gold_geo)
    print("Predicted:", pred_geo, "\n")
    if len(gold_geo) == 0 and len(pred_geo) == 0:
        print("both nothing\n __________________________")
        all_geo_precision.append(1.0)
        all_geo_recall.append(1.0)
        all_geo_f1.append(1.0)
        continue
    else:
        print("Precision:", precision(gold_geo, pred_geo))
        print("Recall:", recall(gold_geo, pred_geo))
        print("F1-Score:", f1(gold_geo, pred_geo), "\n___________________________")
        all_geo_precision.append(precision(gold_geo, pred_geo))
        all_geo_recall.append(recall(gold_geo, pred_geo))
        all_geo_f1.append(f1(gold_geo, pred_geo))
        
mean_geo_precision = sum(all_geo_precision) / len(all_geo_precision)
mean_geo_recall = sum(all_geo_recall) / len(all_geo_recall)
mean_geo_f1 = sum(all_geo_f1) / len(all_geo_f1)    
print(mean_geo_precision, mean_geo_recall, mean_geo_f1)
# Out:
# Presseinformation: 2000 0310
# Goldstandard: []
# Predicted: []
#
# both nothing
#  __________________________
# Presseinformation: 2000 0702
# Goldstandard: ['backnang']
# Predicted: ['backnang']
#
# Precision: 1.0
# Recall: 1.0
# F1-Score: 1.0
# ___________________________
# Presseinformation: 2000 1009
# Goldstandard: []
# Predicted: []
#
# both nothing
#  __________________________
# Presseinformation: 2001 0350
# Goldstandard: ['genf']
# Predicted: []
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2001 0909
# Goldstandard: ['ravensburg']
# Predicted: []
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2002 0114
# Goldstandard: ['hildesheim', 'miskolc', 'stuttgart-feuerbach', 'wemerstraße']
# Predicted: ['wemerstraße', 'germany', 'stuttgart-feuerbach']
#
# Precision: 0.6666666666666666
# Recall: 0.5
# F1-Score: 0.5714285714285715
# ___________________________
# Presseinformation: 2002 0403
# Goldstandard: []
# Predicted: []
#
# both nothing
#  __________________________
# Presseinformation: 2002 0710
# Goldstandard: ['abstatt', 'heilbronn']
# Predicted: ['abstatt', 'abstau']
#
# Precision: 0.5
# Recall: 0.5
# F1-Score: 0.5
# ___________________________
# Presseinformation: 2002 1008
# Goldstandard: []
# Predicted: []
#
# both nothing
#  __________________________
# Presseinformation: 2003 0212
# Goldstandard: []
# Predicted: []
#
# both nothing
#  __________________________
# Presseinformation: 2003 0512
# Goldstandard: []
# Predicted: []
#
# both nothing
#  __________________________
# Presseinformation: 2003 0811
# Goldstandard: []
# Predicted: []
#
# both nothing
#  __________________________
# Presseinformation: 2003 1203
# Goldstandard: []
# Predicted: []
#
# both nothing
#  __________________________
# Presseinformation: 2004 0317
# Goldstandard: []
# Predicted: []
#
# both nothing
#  __________________________
# Presseinformation: 2004 0615
# Goldstandard: []
# Predicted: []
#
# both nothing
#  __________________________
# Presseinformation: 2004 0951
# Goldstandard: []
# Predicted: []
#
# both nothing
#  __________________________
# Presseinformation: 2005 0112
# Goldstandard: ['stuttgart']
# Predicted: []
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2005 0607
# Goldstandard: []
# Predicted: []
#
# both nothing
#  __________________________
# Presseinformation: 2005 0951
# Goldstandard: ['berlin', 'frankfurt am main']
# Predicted: []
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2006 0307
# Goldstandard: []
# Predicted: []
#
# both nothing
#  __________________________
# Presseinformation: 2006 0911
# Goldstandard: []
# Predicted: []
#
# both nothing
#  __________________________
# Presseinformation: 2007 0307
# Goldstandard: []
# Predicted: []
#
# both nothing
#  __________________________
# Presseinformation: 2007 1001
# Goldstandard: []
# Predicted: []
#
# both nothing
#  __________________________
# Presseinformation: 2008 0318
# Goldstandard: []
# Predicted: []
#
# both nothing
#  __________________________
# Presseinformation: 2008 1101
# Goldstandard: ['brüssel', 'europa']
# Predicted: ['europa']
#
# Precision: 1.0
# Recall: 0.5
# F1-Score: 0.6666666666666666
# ___________________________
# Presseinformation: 2009 0419
# Goldstandard: []
# Predicted: []
#
# both nothing
#  __________________________
# Presseinformation: 2009 1004
# Goldstandard: ['südafrika', 'kapstadt', 'johannesburg', 'stuttgart']
# Predicted: ['kapstadt', 'südafrika', 'johannesburg']
#
# Precision: 1.0
# Recall: 0.75
# F1-Score: 0.8571428571428571
# ___________________________
# Presseinformation: 2010 0701
# Goldstandard: ['stuttgart', 'deutschland', 'grasbrunn']
# Predicted: []
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2010 1019
# Goldstandard: ['schweiz', 'st. niklaus', 'zermatt']
# Predicted: []
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2011 0326
# Goldstandard: ['deutschland']
# Predicted: []
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2011 0807
# Goldstandard: ['detmold']
# Predicted: []
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2012 0113
# Goldstandard: []
# Predicted: []
#
# both nothing
#  __________________________
# Presseinformation: 2012 0808
# Goldstandard: []
# Predicted: []
#
# both nothing
#  __________________________
# Presseinformation: 2013 0201
# Goldstandard: []
# Predicted: []
#
# both nothing
#  __________________________
# Presseinformation: 2013 0618
# Goldstandard: ['berlin', 'europa', 'südeuropa']
# Predicted: []
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2013 0947
# Goldstandard: []
# Predicted: []
#
# both nothing
#  __________________________
# Presseinformation: 2014 0218
# Goldstandard: ['österreich', 'wien', 'tschechien', 'großbritannien', 'türkei', 'deutschland', 'slowakei']
# Predicted: ['österreich', 'wien']
#
# Precision: 1.0
# Recall: 0.2857142857142857
# F1-Score: 0.4444444444444445
# ___________________________
# Presseinformation: 2014 0912
# Goldstandard: ['stuttgart', 'münchen', 'europa', 'berlin']
# Predicted: []
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2015 0405
# Goldstandard: ['türkei', 'erenler', 'schwarzmeerküste']
# Predicted: ['erenler', 'schwarzmeerküste', 'türkei']
#
# Precision: 1.0
# Recall: 1.0
# F1-Score: 1.0
# ___________________________
# Presseinformation: 2015 0908
# Goldstandard: ['nordamerika', 'europa', 'farmington hills', 'michigan', 'usa', 'waiblingen', 'georgia', 'bristol']
# Predicted: ['decatur']
#
# Precision: 1.0
# Recall: 0.125
# F1-Score: 0.2222222222222222
# ___________________________
# Presseinformation: 2016 0501
# Goldstandard: ['abstatt', 'frankfurt am main']
# Predicted: []
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2016 0922
# Goldstandard: ['karlsruhe']
# Predicted: []
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2017 0303
# Goldstandard: ['karlsruhe', 'boxberg', 'böblingen']
# Predicted: []
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2018 0204
# Goldstandard: []
# Predicted: []
#
# both nothing
#  __________________________
# Presseinformation: 2019 0501
# Goldstandard: ['karlsruhe', 'plochingen', 'europa']
# Predicted: []
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2019 1103
# Goldstandard: ['stuttgart']
# Predicted: ['silber']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# 0.6557971014492753 0.6013198757763975 0.6143892339544513

# %%
#Körperschaftsindex

all_org_precision = []
all_org_recall = []
all_org_f1 = []
for filename in os.listdir(r"C:\Users\Goegg\OneDrive\Desktop\zu annotieren"):
    
    pi_name = get_PI(filename)
    print("Presseinformation:", pi_name)
    #get org-pred
    df_pred = pd.read_excel(os.path.join(directory, pi_name + extension), header=0)
    pred_org_out = df_pred['Körperschaftsindex:'].tolist()
    pred_org = [x for x in pred_org_out if x == x]
    #get org-gold
    df_gold = pd.read_excel(goldstandard, pi_name)
    gold_org_out = df_gold['Körperschaftsindex'].tolist()
    gold_org = [lemmatizer(x, NOUN)[0].lower() for x in gold_org_out if x == x]
    print("Goldstandard:", gold_org)
    print("Predicted:", pred_org, "\n")
    if len(gold_org) == 0 and len(pred_org) == 0:
        print("both nothing\n __________________________")
        all_org_precision.append(1.0)
        all_org_recall.append(1.0)
        all_org_f1.append(1.0)
        continue
    else:
        print("Precision:", precision(gold_org, pred_org))
        print("Recall:", recall(gold_org, pred_org))
        print("F1-Score:", f1(gold_org, pred_org), "\n___________________________")
        all_org_precision.append(precision(gold_org, pred_org))
        all_org_recall.append(recall(gold_org, pred_org))
        all_org_f1.append(f1(gold_org, pred_org))
        
mean_org_precision = sum(all_org_precision) / len(all_org_precision)
mean_org_recall = sum(all_org_recall) / len(all_org_recall)
mean_org_f1 = sum(all_org_f1) / len(all_org_f1)    
print(mean_org_precision, mean_org_recall, mean_org_f1)
# Out:
# Presseinformation: 2000 0310
# Goldstandard: []
# Predicted: []
#
# both nothing
#  __________________________
# Presseinformation: 2000 0702
# Goldstandard: []
# Predicted: ['zö', 'zoef']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2000 1009
# Goldstandard: ['daimler-chrysler', 'audi', 'bmw', 'cadillac', 'citroen', 'daewoo', 'fiat', 'lancia', 'mitsubishi', 'opel', 'peugeot', 'porsche', 'renault', 'suzuki', 'vauxhall', 'volvo', 'vw']
# Predicted: []
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2001 0350
# Goldstandard: ['blaupunkt']
# Predicted: []
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2001 0909
# Goldstandard: ['hawera probst gmbh']
# Predicted: ['hawera']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2002 0114
# Goldstandard: []
# Predicted: []
#
# both nothing
#  __________________________
# Presseinformation: 2002 0403
# Goldstandard: ['gesellschaft für technische überwachung']
# Predicted: ['gesellschaft für technische  überwachung']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2002 0710
# Goldstandard: ['assel gmbh']
# Predicted: ['assel gmbh']
#
# Precision: 1.0
# Recall: 1.0
# F1-Score: 1.0
# ___________________________
# Presseinformation: 2002 1008
# Goldstandard: ['junker']
# Predicted: ['bosch-thermotechnik']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2003 0212
# Goldstandard: ['skil']
# Predicted: ['skil']
#
# Precision: 1.0
# Recall: 1.0
# F1-Score: 1.0
# ___________________________
# Presseinformation: 2003 0512
# Goldstandard: []
# Predicted: []
#
# both nothing
#  __________________________
# Presseinformation: 2003 0811
# Goldstandard: []
# Predicted: []
#
# both nothing
#  __________________________
# Presseinformation: 2003 1203
# Goldstandard: []
# Predicted: []
#
# both nothing
#  __________________________
# Presseinformation: 2004 0317
# Goldstandard: []
# Predicted: ['bosch-presse']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2004 0615
# Goldstandard: ['junkers/bosch-thermotechnik']
# Predicted: ['bosch-thermotechnik']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2004 0951
# Goldstandard: []
# Predicted: ['fsa']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2005 0112
# Goldstandard: ['car multimedia', 'bosch rexroth', 'max-planck-forschungsinstitut', 'bosch-gruppe']
# Predicted: ['max-planck-forschungsinstitut', 'pi g2']
#
# Precision: 0.5
# Recall: 0.25
# F1-Score: 0.3333333333333333
# ___________________________
# Presseinformation: 2005 0607
# Goldstandard: ['bosch sicherheitssysteme']
# Predicted: []
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2005 0951
# Goldstandard: ['blaupunkt']
# Predicted: []
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2006 0307
# Goldstandard: ['mercedes-benz', 'siemens vdo', 'bmw']
# Predicted: ['mercedes-benz']
#
# Precision: 1.0
# Recall: 0.3333333333333333
# F1-Score: 0.5
# ___________________________
# Presseinformation: 2006 0911
# Goldstandard: []
# Predicted: []
#
# both nothing
#  __________________________
# Presseinformation: 2007 0307
# Goldstandard: []
# Predicted: []
#
# both nothing
#  __________________________
# Presseinformation: 2007 1001
# Goldstandard: ['bosch klassik teilevermittlung', 'bosch automotive tradition', 'ebay']
# Predicted: ['bosch klassik teilevermittlung', 'bosch automotive', 'tns infratest automotive', 'ebay']
#
# Precision: 0.5
# Recall: 0.6666666666666666
# F1-Score: 0.5714285714285715
# ___________________________
# Presseinformation: 2008 0318
# Goldstandard: ['bosch sicherheitssysteme']
# Predicted: []
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2008 1101
# Goldstandard: ['esafety-award-komitee', 'fia', 'esafety']
# Predicted: ['europäischen kommission']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2009 0419
# Goldstandard: []
# Predicted: []
#
# both nothing
#  __________________________
# Presseinformation: 2009 1004
# Goldstandard: ['bosch packaging technology', 'propak']
# Predicted: ['bosch packaging technology']
#
# Precision: 1.0
# Recall: 0.5
# F1-Score: 0.6666666666666666
# ___________________________
# Presseinformation: 2010 0701
# Goldstandard: ['bosch sicherheitssysteme']
# Predicted: ['open network video interface forum']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2010 1019
# Goldstandard: []
# Predicted: []
#
# both nothing
#  __________________________
# Presseinformation: 2011 0326
# Goldstandard: []
# Predicted: []
#
# both nothing
#  __________________________
# Presseinformation: 2011 0807
# Goldstandard: ['bosch packaging technology']
# Predicted: []
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2012 0113
# Goldstandard: ['bosch sensortec']
# Predicted: ['bosch sensortec', 'bosch sensortec gmbh']
#
# Precision: 0.5
# Recall: 1.0
# F1-Score: 0.6666666666666666
# ___________________________
# Presseinformation: 2012 0808
# Goldstandard: ['chassis systems control']
# Predicted: []
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2013 0201
# Goldstandard: ['bosch power tools', 'skil', 'dremel']
# Predicted: []
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2013 0618
# Goldstandard: ['internationales deutschlandforum']
# Predicted: ['internationalen deutschlandforum', 'allensbach instituts']
#
# Precision: 0.5
# Recall: 1.0
# F1-Score: 0.6666666666666666
# ___________________________
# Presseinformation: 2013 0947
# Goldstandard: ['bosch power tools']
# Predicted: []
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2014 0218
# Goldstandard: ['robert bosch ag', 'universität mannheim', 'universität stuttgart-hohenheim']
# Predicted: ['robert bosch ag', 'bosch-gruppe']
#
# Precision: 0.5
# Recall: 0.3333333333333333
# F1-Score: 0.4
# ___________________________
# Presseinformation: 2014 0912
# Goldstandard: ['bsh', 'siemens']
# Predicted: ['bsh', 'siemens', 'siemens ag', 'sec']
#
# Precision: 0.75
# Recall: 1.5
# F1-Score: 1.0
# ___________________________
# Presseinformation: 2015 0405
# Goldstandard: ['türk traktör', 'bosell']
# Predicted: ['türk traktör', 'bosell']
#
# Precision: 1.0
# Recall: 1.0
# F1-Score: 1.0
# ___________________________
# Presseinformation: 2015 0908
# Goldstandard: ['bosch packaging technology', 'kliklok-woodman', 'ampack gmbh', 'osgood industries']
# Predicted: ['kliklok-woodman', 'bosch packaging technology', 'osgood industries', 'ampack gmbh']
#
# Precision: 1.0
# Recall: 1.0
# F1-Score: 1.0
# ___________________________
# Presseinformation: 2016 0501
# Goldstandard: ['technischen aufsichtsbehörde hessen', 'bosch engineering gmbh', 'verkehrsgesellschaft frankfurt am main']
# Predicted: ['vgf', 'technischen aufsichtsbehörde hessen', 'bosch engineering gmbh', 'bosch engineering']
#
# Precision: 0.5
# Recall: 0.6666666666666666
# F1-Score: 0.5714285714285715
# ___________________________
# Presseinformation: 2016 0922
# Goldstandard: ['escrypt', 'automotive aftermarket', 'automotive service solutions']
# Predicted: ['aa']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2017 0303
# Goldstandard: ['motorworld stuttgart', 'bosch classic', 'bosch oldtimer schrauber e.v.', 'bosch fotogruppe', 'automotive aftermarket', 'automotive service solutions']
# Predicted: ['motorworld stuttgart', 'bosch fotogruppe', 'bosch classic', 'aa']
#
# Precision: 0.75
# Recall: 0.5
# F1-Score: 0.6
# ___________________________
# Presseinformation: 2018 0204
# Goldstandard: []
# Predicted: []
#
# both nothing
#  __________________________
# Presseinformation: 2019 0501
# Goldstandard: ['automotive aftermarket']
# Predicted: ['esitronic']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2019 1103
# Goldstandard: []
# Predicted: ['nevonex']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# 0.4673913043478261 0.47282608695652173 0.4560041407867495

# %%
#Personen-Index

all_per_precision = []
all_per_recall = []
all_per_f1 = []
for filename in os.listdir(r"C:\Users\Goegg\OneDrive\Desktop\zu annotieren"):
    
    pi_name = get_PI(filename)
    print("Presseinformation:", pi_name)
    #get per-pred
    df_pred = pd.read_excel(os.path.join(directory, pi_name + extension), header=0)
    pred_per_out = df_pred['Personen-Index'].tolist()
    pred_per = [x for x in pred_per_out if x == x]
    #get per-gold
    df_gold = pd.read_excel(goldstandard, pi_name)
    gold_per_out = df_gold['Personen-Index'].tolist()
    gold_per = [lemmatizer(x, NOUN)[0].lower() for x in gold_per_out if x == x]
    print("Goldstandard:", gold_per)
    print("Predicted:", pred_per, "\n")
    if len(gold_per) == 0 and len(pred_per) == 0:
        print("both nothing\n __________________________")
        all_per_precision.append(1.0)
        all_per_recall.append(1.0)
        all_per_f1.append(1.0)
        continue
    else:
        print("Precision:", precision(gold_per, pred_per))
        print("Recall:", recall(gold_per, pred_per))
        print("F1-Score:", f1(gold_per, pred_per), "\n___________________________")
        all_per_precision.append(precision(gold_per, pred_per))
        all_per_recall.append(recall(gold_per, pred_per))
        all_per_f1.append(f1(gold_per, pred_per))
        
mean_per_precision = sum(all_per_precision) / len(all_per_precision)
mean_per_recall = sum(all_per_recall) / len(all_per_recall)
mean_per_f1 = sum(all_per_f1) / len(all_per_f1)    
print(mean_per_precision, mean_per_recall, mean_per_f1)
# Out:
# Presseinformation: 2000 0310
# Goldstandard: []
# Predicted: []
#
# both nothing
#  __________________________
# Presseinformation: 2000 0702
# Goldstandard: []
# Predicted: ['borm1nn']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2000 1009
# Goldstandard: []
# Predicted: []
#
# both nothing
#  __________________________
# Presseinformation: 2001 0350
# Goldstandard: []
# Predicted: []
#
# both nothing
#  __________________________
# Presseinformation: 2001 0909
# Goldstandard: ['dr. marco lang']
# Predicted: []
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2002 0114
# Goldstandard: []
# Predicted: ['hans walz', 'robert bosch', 'walz', 'georg zundel']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2002 0403
# Goldstandard: []
# Predicted: []
#
# both nothing
#  __________________________
# Presseinformation: 2002 0710
# Goldstandard: []
# Predicted: []
#
# both nothing
#  __________________________
# Presseinformation: 2002 1008
# Goldstandard: []
# Predicted: []
#
# both nothing
#  __________________________
# Presseinformation: 2003 0212
# Goldstandard: []
# Predicted: []
#
# both nothing
#  __________________________
# Presseinformation: 2003 0512
# Goldstandard: []
# Predicted: []
#
# both nothing
#  __________________________
# Presseinformation: 2003 0811
# Goldstandard: []
# Predicted: []
#
# both nothing
#  __________________________
# Presseinformation: 2003 1203
# Goldstandard: []
# Predicted: []
#
# both nothing
#  __________________________
# Presseinformation: 2004 0317
# Goldstandard: []
# Predicted: []
#
# both nothing
#  __________________________
# Presseinformation: 2004 0615
# Goldstandard: ['albrecht schäfer']
# Predicted: []
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2004 0951
# Goldstandard: []
# Predicted: []
#
# both nothing
#  __________________________
# Presseinformation: 2005 0112
# Goldstandard: ['siegfried dais']
# Predicted: ['siegfried dais']
#
# Precision: 1.0
# Recall: 1.0
# F1-Score: 1.0
# ___________________________
# Presseinformation: 2005 0607
# Goldstandard: []
# Predicted: []
#
# both nothing
#  __________________________
# Presseinformation: 2005 0951
# Goldstandard: []
# Predicted: []
#
# both nothing
#  __________________________
# Presseinformation: 2006 0307
# Goldstandard: ['dr. rolf leonhard']
# Predicted: []
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2006 0911
# Goldstandard: []
# Predicted: []
#
# both nothing
#  __________________________
# Presseinformation: 2007 0307
# Goldstandard: []
# Predicted: []
#
# both nothing
#  __________________________
# Presseinformation: 2007 1001
# Goldstandard: []
# Predicted: []
#
# both nothing
#  __________________________
# Presseinformation: 2008 0318
# Goldstandard: []
# Predicted: []
#
# both nothing
#  __________________________
# Presseinformation: 2008 1101
# Goldstandard: ['dr. bernd bohr']
# Predicted: []
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2009 0419
# Goldstandard: []
# Predicted: []
#
# both nothing
#  __________________________
# Presseinformation: 2009 1004
# Goldstandard: ['friedbert klefenz']
# Predicted: []
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2010 0701
# Goldstandard: []
# Predicted: []
#
# both nothing
#  __________________________
# Presseinformation: 2010 1019
# Goldstandard: []
# Predicted: []
#
# both nothing
#  __________________________
# Presseinformation: 2011 0326
# Goldstandard: ['dr. wolfgang malchow']
# Predicted: ['malchow']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2011 0807
# Goldstandard: ['michael voeth']
# Predicted: ['michael voeth']
#
# Precision: 1.0
# Recall: 1.0
# F1-Score: 1.0
# ___________________________
# Presseinformation: 2012 0113
# Goldstandard: []
# Predicted: []
#
# both nothing
#  __________________________
# Presseinformation: 2012 0808
# Goldstandard: ['gerhard steiger']
# Predicted: []
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2013 0201
# Goldstandard: []
# Predicted: []
#
# both nothing
#  __________________________
# Presseinformation: 2013 0618
# Goldstandard: ['franz fehrenbach', 'angela merkel']
# Predicted: ['fehrenbach']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2013 0947
# Goldstandard: []
# Predicted: []
#
# both nothing
#  __________________________
# Presseinformation: 2014 0218
# Goldstandard: ['klaus peter fouquet', 'klaus huttelmaier']
# Predicted: ['fouquet', 'klaus huttelmaier', 'angelika kiessling', 'klaus peter fouquet']
#
# Precision: 0.5
# Recall: 1.0
# F1-Score: 0.6666666666666666
# ___________________________
# Presseinformation: 2014 0912
# Goldstandard: ['volkmar denner']
# Predicted: []
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2015 0405
# Goldstandard: []
# Predicted: []
#
# both nothing
#  __________________________
# Presseinformation: 2015 0908
# Goldstandard: []
# Predicted: []
#
# both nothing
#  __________________________
# Presseinformation: 2016 0501
# Goldstandard: ['bernhard bihr', 'christoph zemelka']
# Predicted: []
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2016 0922
# Goldstandard: []
# Predicted: []
#
# both nothing
#  __________________________
# Presseinformation: 2017 0303
# Goldstandard: []
# Predicted: []
#
# both nothing
#  __________________________
# Presseinformation: 2018 0204
# Goldstandard: ['christoph kübel', 'kerstin mai']
# Predicted: []
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2019 0501
# Goldstandard: []
# Predicted: []
#
# both nothing
#  __________________________
# Presseinformation: 2019 1103
# Goldstandard: ['andrew allen']
# Predicted: []
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# 0.6847826086956522 0.6956521739130435 0.6884057971014493

# %%
#Themen-Index

all_thema_precision = []
all_thema_recall = []
all_thema_f1 = []
for filename in os.listdir(r"C:\Users\Goegg\OneDrive\Desktop\zu annotieren"):
    
    pi_name = get_PI(filename)
    print("Presseinformation:", pi_name)
    #get thema-pred
    df_pred = pd.read_excel(os.path.join(directory, pi_name + extension), header=0)
    pred_thema_out = df_pred['Themen-Index'].tolist()
    pred_thema = [x for x in pred_thema_out if x == x]
    #get thema-gold
    df_gold = pd.read_excel(goldstandard, pi_name)
    gold_thema_out = df_gold['Themen-Index'].tolist()
    gold_thema = [lemmatizer(x, NOUN)[0].lower() for x in gold_thema_out if x == x]
    print("Goldstandard:", gold_thema)
    print("Predicted:", pred_thema, "\n")
    if len(gold_thema) == 0 and len(pred_thema) == 0:
        print("both nothing\n __________________________")
        all_thema_precision.append(1.0)
        all_thema_recall.append(1.0)
        all_thema_f1.append(1.0)
        continue
    else:
        print("Precision:", precision(gold_thema, pred_thema))
        print("Recall:", recall(gold_thema, pred_thema))
        print("F1-Score:", f1(gold_thema, pred_thema), "\n___________________________")
        all_thema_precision.append(precision(gold_thema, pred_thema))
        all_thema_recall.append(recall(gold_thema, pred_thema))
        all_thema_f1.append(f1(gold_thema, pred_thema))
        
mean_thema_precision = sum(all_thema_precision) / len(all_thema_precision)
mean_thema_recall = sum(all_thema_recall) / len(all_thema_recall)
mean_thema_f1 = sum(all_thema_f1) / len(all_thema_f1)    
print(mean_thema_precision, mean_thema_recall, mean_thema_f1)
# Out:
# Presseinformation: 2000 0310
# Goldstandard: ['elektrowerkzeug']
# Predicted: ['ahs 6000 pro', 'bild', 'griff', 'ahs 7000   pro']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2000 0702
# Goldstandard: ['raumfahrttechnik']
# Predicted: []
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2000 1009
# Goldstandard: []
# Predicted: ['die fließgepresste mittelelektrode', 'f 8 oper']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2001 0350
# Goldstandard: []
# Predicted: ['silver plus', 'die spitzenbatterie von bosch']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2001 0909
# Goldstandard: ['hammerbohrer', 'diamant']
# Predicted: ['handwerker', 'metall']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2002 0114
# Goldstandard: ['mitarbeiter', 'kündigung']
# Predicted: ['firma', 'jahr', 'ersten weltkrieg']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2002 0403
# Goldstandard: []
# Predicted: []
#
# both nothing
#  __________________________
# Presseinformation: 2002 0710
# Goldstandard: ['chassissysteme']
# Predicted: ['euro', 'richtfest', 'techniker']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2002 1008
# Goldstandard: ['junkers/bosch-thermotechnik', 'junkers-website', 'heizung']
# Predicted: ['beratung', 'rubrik', 'tipps']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2003 0212
# Goldstandard: ['elektrowerkzeugen']
# Predicted: ['modell']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2003 0512
# Goldstandard: ['garten- und forstgeräte']
# Predicted: ['garten']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2003 0811
# Goldstandard: ['abtragsleistung']
# Predicted: ['das geheimnis des 250 mil limeter', 'sds-plus-flachmeißel von bosch', 'rich']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2003 1203
# Goldstandard: ['videoüberwachung', 'sicherheit']
# Predicted: ['alarm', 'monitor', 'bild', 'schule']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2004 0317
# Goldstandard: []
# Predicted: []
#
# both nothing
#  __________________________
# Presseinformation: 2004 0615
# Goldstandard: []
# Predicted: ['aluminium']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2004 0951
# Goldstandard: ['fahrzeuggewicht', 'nutzfahrzeug']
# Predicted: []
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2005 0112
# Goldstandard: ['forschung', 'kraftfahrzeugausrüstung', 'kommunikationstechnik', 'geschäftsführung']
# Predicted: ['januar', 'vorsitzender', 'zentralbereiche forschung']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2005 0607
# Goldstandard: ['videoüberwachungssysteme']
# Predicted: ['nacht', 'tag']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2005 0951
# Goldstandard: []
# Predicted: []
#
# both nothing
#  __________________________
# Presseinformation: 2006 0307
# Goldstandard: ['benzin-direkteinspritzung', 'strahlgeführtes brennverfahren']
# Predicted: ['mini']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2006 0911
# Goldstandard: ['heimwerker']
# Predicted: ['euro']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2007 0307
# Goldstandard: ['elektrowerkzeuge', 'vibrationsschutz']
# Predicted: ['jahr 2001']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2007 1001
# Goldstandard: ['ersatzteile']
# Predicted: ['bosch klassik', 'tradition']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2008 0318
# Goldstandard: ['tonwiedergabe']
# Predicted: []
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2008 1101
# Goldstandard: []
# Predicted: ['verbreitung', 'einsatz', 'kategorie', 'untersuchung']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2009 0419
# Goldstandard: ['pollen', 'gesundheitsschutz', 'sicherheit', 'komfort']
# Predicted: ['luft', 'winter']
#
# Precision: 0.5
# Recall: 0.25
# F1-Score: 0.3333333333333333
# ___________________________
# Presseinformation: 2009 1004
# Goldstandard: []
# Predicted: ['euro']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2010 0701
# Goldstandard: []
# Predicted: ['200 serie', 'serie']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2010 1019
# Goldstandard: ['feinmechanik']
# Predicted: ['mörtel', 'fiberglas']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2011 0326
# Goldstandard: ['akademiker', 'kaufleute', 'jubiläumsjahr', 'mitarbeiter', 'junior manager program', 'graduate specialist program']
# Predicted: ['frau', 'arbeitgeber', 'akademiker', 'absolventen', 'ruf', 'vielfalt']
#
# Precision: 0.16666666666666666
# Recall: 0.16666666666666666
# F1-Score: 0.16666666666666666
# ___________________________
# Presseinformation: 2011 0807
# Goldstandard: ['müllereitagung']
# Predicted: []
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2012 0113
# Goldstandard: []
# Predicted: ['euro']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2012 0808
# Goldstandard: ['sicherheit', 'komfort', 'bremsregelsysteme']
# Predicted: ['esp® 9 premium', 'youtube link', 'premium', 'euro']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2013 0201
# Goldstandard: ['electronic cell protection', 'leistung']
# Predicted: ['euro']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2013 0618
# Goldstandard: ['wohlstandsverlust', 'wirtschaft', 'lebensqualität', 'fortschritt', 'wettbewerb']
# Predicted: ['internationale deutschlandforum', 'fortschritt', 'herausforderung', 'wirtschaft']
#
# Precision: 0.5
# Recall: 0.4
# F1-Score: 0.4444444444444445
# ___________________________
# Presseinformation: 2013 0947
# Goldstandard: ['metall']
# Predicted: ['expert for steel', 'euro', 'metall']
#
# Precision: 0.3333333333333333
# Recall: 1.0
# F1-Score: 0.5
# ___________________________
# Presseinformation: 2014 0218
# Goldstandard: ['wechsel', 'vorstand', 'ruhestand', 'manager']
# Predicted: []
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2014 0912
# Goldstandard: []
# Predicted: ['euro']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2015 0405
# Goldstandard: ['absicherung']
# Predicted: ['werk']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2015 0908
# Goldstandard: ['unternehmen', 'übernahme', 'ausbau']
# Predicted: ['übernahme', 'nahrungsmittel']
#
# Precision: 0.5
# Recall: 0.3333333333333333
# F1-Score: 0.4
# ___________________________
# Presseinformation: 2016 0501
# Goldstandard: ['sicherheit', 'straßenbahnen', 'unfall', 'beifahrer']
# Predicted: ['straßenbahnen', 'bahn', 'beifahrer']
#
# Precision: 0.6666666666666666
# Recall: 0.5
# F1-Score: 0.5714285714285715
# ___________________________
# Presseinformation: 2016 0922
# Goldstandard: ['werkstätte', 'dienstleistung', 'betreuung', 'service']
# Predicted: ['werkstätte', 'werkstatt']
#
# Precision: 0.5
# Recall: 0.25
# F1-Score: 0.3333333333333333
# ___________________________
# Presseinformation: 2017 0303
# Goldstandard: ['rallye', 'bosch boxberg klassik rallye']
# Predicted: ['bosch boxberg klassik', 'rallye', 'klassik', 'juni']
#
# Precision: 0.25
# Recall: 0.5
# F1-Score: 0.3333333333333333
# ___________________________
# Presseinformation: 2018 0204
# Goldstandard: ['fahrrad-leasing', 'mitarbeiter', 'gesundheit', 'sport']
# Predicted: ['mitarbeiter', 'stadt', 'verkehrsmittel']
#
# Precision: 0.6666666666666666
# Recall: 0.5
# F1-Score: 0.5714285714285715
# ___________________________
# Presseinformation: 2019 0501
# Goldstandard: ['online', 'computer aided service']
# Predicted: ['online']
#
# Precision: 1.0
# Recall: 0.5
# F1-Score: 0.6666666666666666
# ___________________________
# Presseinformation: 2019 1103
# Goldstandard: ['landwirtschaft', 'effizienz', 'automatisierung', 'vernetzung']
# Predicted: ['landwirtschaft', 'landwirt', 'agritechnica innovation award', 'service']
#
# Precision: 0.25
# Recall: 0.25
# F1-Score: 0.25
# ___________________________
# 0.18115942028985504 0.16630434782608694 0.16457902001380262

# %%
#Produkt-Index

all_prod_precision = []
all_prod_recall = []
all_prod_f1 = []
for filename in os.listdir(r"C:\Users\Goegg\OneDrive\Desktop\zu annotieren"):
    
    pi_name = get_PI(filename)
    print("Presseinformation:", pi_name)
    #get prod-pred
    df_pred = pd.read_excel(os.path.join(directory, pi_name + extension), header=0)
    pred_prod_out = df_pred['Produkt-Index'].tolist()
    pred_prod = [x for x in pred_prod_out if x == x]
    #get prod-gold
    df_gold = pd.read_excel(goldstandard, pi_name)
    gold_prod_out = df_gold['Produkt-Index'].tolist()
    gold_prod = [lemmatizer(x, NOUN)[0].lower() for x in gold_prod_out if x == x]
    print("Goldstandard:", gold_prod)
    print("Predicted:", pred_prod, "\n")
    if len(gold_prod) == 0 and len(pred_prod) == 0:
        print("both nothing\n __________________________")
        all_prod_precision.append(1.0)
        all_prod_recall.append(1.0)
        all_prod_f1.append(1.0)
        continue
    else:
        print("Precision:", precision(gold_prod, pred_prod))
        print("Recall:", recall(gold_prod, pred_prod))
        print("F1-Score:", f1(gold_prod, pred_prod), "\n___________________________")
        all_prod_precision.append(precision(gold_prod, pred_prod))
        all_prod_recall.append(recall(gold_prod, pred_prod))
        all_prod_f1.append(f1(gold_prod, pred_prod))
        
mean_prod_precision = sum(all_prod_precision) / len(all_prod_precision)
mean_prod_recall = sum(all_prod_recall) / len(all_prod_recall)
mean_prod_f1 = sum(all_prod_f1) / len(all_prod_f1)    
print(mean_prod_precision, mean_prod_recall, mean_prod_f1)
# Out:
# Presseinformation: 2000 0310
# Goldstandard: ['ahs 6000 pro', 'ahs 7000']
# Predicted: ['messer', 'anwender']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2000 0702
# Goldstandard: ['leiterplatten']
# Predicted: ['leiterplatten']
#
# Precision: 1.0
# Recall: 1.0
# F1-Score: 1.0
# ___________________________
# Presseinformation: 2000 1009
# Goldstandard: ['slk 320', 'zündkerze']
# Predicted: []
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2001 0350
# Goldstandard: ['silver plus', 'powercontrol system', 'esp', 'common rail', 'bea 350', 'zündkerze', 'funline']
# Predicted: ['produktvorteil powercontrol system', 'powercontrol system']
#
# Precision: 0.5
# Recall: 0.14285714285714285
# F1-Score: 0.22222222222222224
# ___________________________
# Presseinformation: 2001 0909
# Goldstandard: ['quadro-x', 'sägeblätter']
# Predicted: ['qualität']
#
# Precision: 1.0
# Recall: 0.5
# F1-Score: 0.6666666666666666
# ___________________________
# Presseinformation: 2002 0114
# Goldstandard: ['starter']
# Predicted: []
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2002 0403
# Goldstandard: ['bremse', 'bremsanlage']
# Predicted: ['bremsanlage']
#
# Precision: 1.0
# Recall: 0.5
# F1-Score: 0.6666666666666666
# ___________________________
# Presseinformation: 2002 0710
# Goldstandard: []
# Predicted: []
#
# both nothing
#  __________________________
# Presseinformation: 2002 1008
# Goldstandard: []
# Predicted: ['junkers', 'suche']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2003 0212
# Goldstandard: ['handkreissägen', 'säge']
# Predicted: ['säge']
#
# Precision: 1.0
# Recall: 0.5
# F1-Score: 0.6666666666666666
# ___________________________
# Presseinformation: 2003 0512
# Goldstandard: ['zündkerze', 'rasenmäher', 'rasentrimmer', 'blattgebläse', 'gartentraktoren', 'heckenscheren', 'kettensägen', 'laubsauger', 'motorsensen', 'netzstromaggregate', 'wasserpumpen', 'schneefräsen', 'schneewerfer']
# Predicted: []
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2003 0811
# Goldstandard: ['sds-plus-flachmeißel', 'meißel']
# Predicted: ['meißel']
#
# Precision: 1.0
# Recall: 0.5
# F1-Score: 0.6666666666666666
# ___________________________
# Presseinformation: 2003 1203
# Goldstandard: ['eazeo', 'kamera']
# Predicted: ['kamera']
#
# Precision: 1.0
# Recall: 0.5
# F1-Score: 0.6666666666666666
# ___________________________
# Presseinformation: 2004 0317
# Goldstandard: ['kettensägen', 'sägekette']
# Predicted: ['kette']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2004 0615
# Goldstandard: ['wärmeübertrager', 'cerasmart']
# Predicted: ['junkers', 'wasser']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2004 0951
# Goldstandard: ['esp', 'load adaptive control']
# Predicted: ['messtechnik']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2005 0112
# Goldstandard: []
# Predicted: []
#
# both nothing
#  __________________________
# Presseinformation: 2005 0607
# Goldstandard: ['autodome-kameras']
# Predicted: []
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2005 0951
# Goldstandard: ['travelpilot rome', 'radio']
# Predicted: ['elektrik', 'touchscreen', 'leichtes handheld-gerät']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2006 0307
# Goldstandard: ['piezo-injektoren']
# Predicted: ['brennraum']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2006 0911
# Goldstandard: ['bosch-sds-system', 'maschine', 'säge']
# Predicted: ['säge', 'maschine']
#
# Precision: 1.0
# Recall: 0.6666666666666666
# F1-Score: 0.8
# ___________________________
# Presseinformation: 2007 0307
# Goldstandard: ['winkelschleifer ', 'vibration control']
# Predicted: []
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2007 1001
# Goldstandard: []
# Predicted: []
#
# both nothing
#  __________________________
# Presseinformation: 2008 0318
# Goldstandard: ['lautsprecher']
# Predicted: ['lautsprecher', 'nachteil', 'qualität']
#
# Precision: 0.3333333333333333
# Recall: 1.0
# F1-Score: 0.5
# ___________________________
# Presseinformation: 2008 1101
# Goldstandard: ['esp®']
# Predicted: ['nutzen']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2009 0419
# Goldstandard: ['aktivkohle-innenraumfilter', 'innenraumfilter']
# Predicted: ['klimaanlage']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2009 1004
# Goldstandard: []
# Predicted: ['prozesstechnik']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2010 0701
# Goldstandard: ['kamera']
# Predicted: ['kamera', 'mithilfe']
#
# Precision: 0.5
# Recall: 1.0
# F1-Score: 0.6666666666666666
# ___________________________
# Presseinformation: 2010 1019
# Goldstandard: ['mörtel', 'mörtelentferner', 'oscillating interface system']
# Predicted: []
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2011 0326
# Goldstandard: []
# Predicted: []
#
# both nothing
#  __________________________
# Presseinformation: 2011 0807
# Goldstandard: ['dornrad-paketieranlage', 'paketieranlage']
# Predicted: []
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2012 0113
# Goldstandard: ['smartphones', 'drehratensensor', 'sensor', 'applikation', 'telefon']
# Predicted: ['sensor', 'smartphones']
#
# Precision: 1.0
# Recall: 0.4
# F1-Score: 0.5714285714285715
# ___________________________
# Presseinformation: 2012 0808
# Goldstandard: ['rückförderpumpe', 'adaptive cruise control', 'hill hold control']
# Predicted: ['version', 'funktionsweise']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2013 0201
# Goldstandard: ['schlagbohrschrauber', 'schlagfunktion', 'akku']
# Predicted: ['akku', 'gang']
#
# Precision: 1.0
# Recall: 0.6666666666666666
# F1-Score: 0.8
# ___________________________
# Presseinformation: 2013 0618
# Goldstandard: []
# Predicted: []
#
# both nothing
#  __________________________
# Presseinformation: 2013 0947
# Goldstandard: ['kaltkreissäge', 'expert for steel']
# Predicted: ['mm', 'schnitt']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2014 0218
# Goldstandard: []
# Predicted: []
#
# both nothing
#  __________________________
# Presseinformation: 2014 0912
# Goldstandard: ['hausgeräte']
# Predicted: ['aussage']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2015 0405
# Goldstandard: ['traktor', 'serie 5000']
# Predicted: []
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2015 0908
# Goldstandard: []
# Predicted: []
#
# both nothing
#  __________________________
# Presseinformation: 2016 0501
# Goldstandard: ['rail control unit']
# Predicted: []
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2016 0922
# Goldstandard: []
# Predicted: ['fahrzeug', 'geschäftsfeld']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2017 0303
# Goldstandard: []
# Predicted: []
#
# both nothing
#  __________________________
# Presseinformation: 2018 0204
# Goldstandard: ['fahrrad', 'ebikes']
# Predicted: ['fahrrad']
#
# Precision: 1.0
# Recall: 0.5
# F1-Score: 0.6666666666666666
# ___________________________
# Presseinformation: 2019 0501
# Goldstandard: ['esitronic', 'festplatte']
# Predicted: []
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2019 1103
# Goldstandard: ['nevonex']
# Predicted: []
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# 0.4202898550724638 0.34513457556935817 0.36000690131124913

# %%
print("Standard Deviation of Precision/Products is ", np.std(all_thema_precision))
# Out:
# Standard Deviation of Precision/Products is  0.31770631578170844

# %% [markdown]
# ###
