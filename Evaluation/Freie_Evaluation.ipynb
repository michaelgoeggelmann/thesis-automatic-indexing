# %%
import pandas as pd
import os
from spacy.lemmatizer import Lemmatizer, ADJ, NOUN, VERB
import spacy
import numpy as np
import itertools

# %%
def precision(y_true, y_pred):
    i = set(y_true).intersection(y_pred)
    len1 = len(y_pred)
    if len1 == 0:
        return 0.0
    else:
        return float(len(i) / len1)


def recall(y_true, y_pred):
    if len(y_true) == 0:
        return 0.0
    else:
        i = set(y_true).intersection(y_pred)
        return float(len(i) / len(y_true))


def f1(y_true, y_pred):
    p = precision(y_true, y_pred)
    r = recall(y_true, y_pred)
    if p + r == 0:
        return 0.0
    else:
        return 2 * (p * r) / (p + r)
    
def get_PI(filename):
    getFilename = os.path.basename(filename)
    filename, ext = getFilename.split(".")
    if "_" in filename:
        filename, rest = filename.split("_", 1)
    return filename

# %%
os.chdir(r"C:\Users\Goegg\OneDrive\Desktop\Durchgänge")

# %%
# create df out of goldstandard
goldstandard = pd.ExcelFile(r"GOLDSTANDARD.xlsx")
# choose model-combinations for predictions:
directory = r"9. YAKE - BERT\MI_Schlagworte_Decomposed"
extension = ".xlsx"
nlp = spacy.load("de_core_news_lg")
lemmatizer = nlp.vocab.morphology.lemmatizer

# %%
#ALL
corpus_p = []
corpus_r = []
corpus_f = []
for filename in os.listdir(r"C:\Users\Goegg\OneDrive\Desktop\zu annotieren"):
    pi_name = get_PI(filename)
    print("Presseinformation:", pi_name)
    #get geo-pred
    df_pred = pd.read_excel(os.path.join(directory, pi_name + extension), header=0)
    pred_geo_out = df_pred['Geographischer Index:'].tolist()
    pred_geo = [x for x in pred_geo_out if x == x]
    #get geo-gold
    df_gold = pd.read_excel(goldstandard, pi_name)
    gold_geo_out = df_gold['Geographischer Index'].tolist()
    gold_geo = [lemmatizer(x, NOUN)[0].lower() for x in gold_geo_out if x == x]
    #get org-pred
    df_pred = pd.read_excel(os.path.join(directory, pi_name + extension), header=0)
    pred_org_out = df_pred['Körperschaftsindex:'].tolist()
    pred_org = [x for x in pred_org_out if x == x]
    #get org-gold
    df_gold = pd.read_excel(goldstandard, pi_name)
    gold_org_out = df_gold['Körperschaftsindex'].tolist()
    gold_org = [lemmatizer(x, NOUN)[0].lower() for x in gold_org_out if x == x]
    #get per-pred
    df_pred = pd.read_excel(os.path.join(directory, pi_name + extension), header=0)
    pred_per_out = df_pred['Personen-Index'].tolist()
    pred_per = [x for x in pred_per_out if x == x]
    #get per-gold
    df_gold = pd.read_excel(goldstandard, pi_name)
    gold_per_out = df_gold['Personen-Index'].tolist()
    gold_per = [lemmatizer(x, NOUN)[0].lower() for x in gold_per_out if x == x]
    #get thema-pred
    df_pred = pd.read_excel(os.path.join(directory, pi_name + extension), header=0)
    pred_thema_out = df_pred['Themen-Index'].tolist()
    pred_thema = [x for x in pred_thema_out if x == x]
    #get thema-gold
    df_gold = pd.read_excel(goldstandard, pi_name)
    gold_thema_out = df_gold['Themen-Index'].tolist()
    gold_thema = [lemmatizer(x, NOUN)[0].lower() for x in gold_thema_out if x == x]
    #get prod-pred
    df_pred = pd.read_excel(os.path.join(directory, pi_name + extension), header=0)
    pred_prod_out = df_pred['Produkt-Index'].tolist()
    pred_prod = [x for x in pred_prod_out if x == x]
    #get prod-gold
    df_gold = pd.read_excel(goldstandard, pi_name)
    gold_prod_out = df_gold['Produkt-Index'].tolist()
    gold_prod = [lemmatizer(x, NOUN)[0].lower() for x in gold_prod_out if x == x]
    
    all_preds = list(itertools.chain(pred_geo, pred_org, pred_per, pred_thema, pred_prod))
    all_gold = list(itertools.chain(gold_geo, gold_org, gold_per, gold_thema, gold_prod))
    corpus_p.append(precision(all_gold, all_preds))
    corpus_r.append(recall(all_gold, all_preds))
    corpus_f.append(f1(all_gold, all_preds))
    print("Goldstandard:", all_gold)
    print("Predicted:", all_preds, "\n")
    print("Precision:", precision(all_gold, all_preds))
    print("Recall:", recall(all_gold, all_preds))
    print("F1-Score:", f1(all_gold, all_preds), "\n___________________________")
mean_corpus_precision = sum(corpus_p) / len(corpus_p)
mean_corpus_recall = sum(corpus_r) / len(corpus_r)
mean_corpus_f1 = sum(corpus_f) / len(corpus_f)    
print(mean_corpus_precision, mean_corpus_recall, mean_corpus_f1)
# Out:
# Presseinformation: 1951 0601
# Goldstandard: ['bundesgebiet', 'batterie-prüfdienst', 'batterie', 'auto', 'fahrzeug', 'batterie-station', 'bosch-batterie']
# Predicted: ['werbeburo', 'bosch', 'gmbh', 'robert bosch', 'nachdruck', 'nach', 'druck', 'pflege', 'robert', 'dienst', 'arbeit', 'batterie', 'batterie', 'fahrzeug']
#
# Precision: 0.14285714285714285
# Recall: 0.2857142857142857
# F1-Score: 0.19047619047619047
# ___________________________
# Presseinformation: 1961 0302
# Goldstandard: ['abtauen', 'automatie', 'abtau-automatie', 'kühlschrank', 'verdampfer']
# Predicted: ['gmbh', 'pressestelle', 'cingcs', 'neuon', 'deehalb', 'robert bosch', 'tauwa ssers', 'desson', 'lhnon', 'wtr', 'haus', 'frau', 'robert', 'technik', 'verdampfer', 'kühlschrank']
#
# Precision: 0.125
# Recall: 0.4
# F1-Score: 0.19047619047619047
# ___________________________
# Presseinformation: 1965 0102
# Goldstandard: ['stuttgart', 'deutschland', 'konzentrationslager sachsenhausen', 'technischen hochschule stuttgart', 'gestapo', 'vereinigung württembergischer arbeitgeberverbände', 'landesversicherungsanstalt', 'baurat fischer', 'albrecht fischer', 'gedenken', 'politik', 'wirtschaft', 'aufsichtsrat', 'vorsitzender']
# Predicted: ['breitscheidstraße 4', 'bundesrepublik deutschland', 'gmbh', 'mci.ngel', 'sachsenhausen', 'stuttgart', 'eitscheidstraße 4', 'ßaden-württember6', 'allgcmeinhei', 'deutschland', 'lanclesversicherunßsanstalt baden-württember3', 'landesversicherungsanstalt', 'landesversicherungsanstalt ßaden-wurttember', 'robert bosch', 'robert bosch gmbh', 'rober t bosch gmbh besonder s', 'robert bosch grnbh', 'techni schen hochschul e.', 'technischen hochschul e', 'technischen hochschule', 'technischen hochschule stutt gart;', 'technischen hochschule stuttgart', 'technischen hochschule stuttgart;', 'vereinigung württembergischer arbeitgeberverbände', 'albr echt', 'albrecht fischer', 'albrecht fisci0', 'baur', 'baur at fischer', 'baurat fischer', 'bosch', 'daurat fischer', 'fi scher', 'fischer', 'fr eunden', 'karl go0rdeler', 'karl goordelcr', 'stuttßart', 'vorsi zend8r', 'c.ieser', 'clem', 'echt', 'er•', 'ip.m', 'ief', 'uls verbindungsmann', 'robert', 'technische', 'hochschule', 'leben', 'mitglied', 'gegen']
#
# Precision: 0.1346153846153846
# Recall: 0.5
# F1-Score: 0.21212121212121213
# ___________________________
# Presseinformation: 1966 0411
# Goldstandard: ['eisemann gmbh', 'strom', 'volt', 'versorgung', 'spannungsregelung', 'leistung', 'energie', 'stromerzeuger', 'eisemann-stromerzeuger']
# Predicted: ['hasenbergstraße 95', 'stuttgart', 'eisemann', 'hannover-messe', 'magnetbosch technlcpress', 'preaaeatelle technik', 'robert', 'last', 'mitglied', 'bosch', 'gmbh', 'pumpe', 'säge']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 1967 0405
# Goldstandard: ['fahrzeug', 'lenkung', 'servo-lenkung', 'konstruktion', 'hilfskraftlenkung', 'hzl-lenkung', 'lenkrad']
# Predicted: ['hasenbergstraße 95', 'bosch', 'prt', '£rj', 'robert bosch', 'traktor', 'baumaschinen', 'bau', 'robert', 'kraft', 'gmbh', 'fahrzeug', 'maschine', 'fahrzeug', 'servo']
#
# Precision: 0.06666666666666667
# Recall: 0.14285714285714285
# F1-Score: 0.09090909090909091
# ___________________________
# Presseinformation: 1967 0843
# Goldstandard: ['küche', 'dachwohnung', 'haushalt', 'elektroherd', 'kühlschrank', 'elektrogeräte', 'küche']
# Predicted: ['prt', 'robert bosch gmbh', 'dach', 'wohnung', 'einrichtung', 'raum', 'haus', 'frau', 'dach', 'küche', 'vorteil', 'gerät']
#
# Precision: 0.08333333333333333
# Recall: 0.14285714285714285
# F1-Score: 0.10526315789473685
# ___________________________
# Presseinformation: 1968 0406
# Goldstandard: ['europa', 'handwerk', 'landwirtschaft', 'elektrowerkzeug', 'aluminium', 'handmotor', 'universal-bohrmaschine']
# Predicted: ['europa', 'hasenbergstraße 95', 'hohage', 'stuttgart', 'bosch', 'bosch presse-lnfonnatlon', 'robert bosch gmbh', 'eckhard o. noelte', 'elke', 'gerd neermann', 'haus', 'universal', 'technik', 'robert', 'hausgeräte', 'gerät', 'telefon', 'bohrmaschine']
#
# Precision: 0.05555555555555555
# Recall: 0.14285714285714285
# F1-Score: 0.08
# ___________________________
# Presseinformation: 1969 0216
# Goldstandard: ['hausgeräte-programm', 'frischsaftbereitung', 'reinaluminium', 'einfüllschacht', 'kunststoff', 'fruchtrückstände', 'klarsichtdeckel', 'frischsaft-zentrifuge']
# Predicted: ['hasenbergstraße 95', 'stuttgart', 'bosch', 'robert bosch gmbh', 'eckhard d. noelte', 'gerd neermann', 'lrmgard müller', 'haus', 'redaktion', 'müller', 'hausgeräte', 'gerät', 'telefon']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 1969 1101
# Goldstandard: ['stuttgart-feuerbach', 'städtischen berufsfeuerwehr', 'klöckner-humboldt-deutz ag', 'metz gmbh', 'willi hofmann', 'hajek', 'einweihung', 'feuerwache', 'feuerschutzes', 'neubau', 'werkfeuerwehr', 'brandschutz']
# Predicted: ['baden', 'breltscheidstraße 4', 'bteitscheidstraße 4', 'germann', 'giengen/brenz', 'karlsruhe', 'ladenburg', 'ludwigsburg', 'nordwürttemberg', 'stuttgart', 'stuttgart-feuerbach', 'stuttgartfeuerbach', 'ulm', 'württemberg', 'bosch', 'bosch prehe•lnformatlon', 'daiml er benz ag', 'fabrikfeuerwehr', 'leonber', 'metz', 'minimax ag', 'pmsse•lnformation', 'robert bosch gmbh', 'total', 'ziegeler', 'vvn land', 'f. w. knellessen', 'f. w. knallessen', 'günther gruber', 'günther karnmler', 'k. germann', 'w. bauer', 'w.ilauer', 'w6eder', 'wöeder', 'feuerwache', 'einweihung', 'robert', 'berufsfeuerwehr', 'bauer', 'gelände', 'bau']
#
# Precision: 0.07142857142857142
# Recall: 0.25
# F1-Score: 0.11111111111111112
# ___________________________
# Presseinformation: 1970 1002
# Goldstandard: ['bamberg', 'kurzarbeit', 'mitarbeiter']
# Predicted: ['stuttgart', 'bosch', 'bamberg', 'robert bosch gmbh', 'gto', 'dr.', 'f. wolfgang knellessan', 'f. wolfgang knellessen', 'klaus germann', 'margarete doker', 'margarete düker', 'wolfgang knallessan', 'robert', 'kurzarbeit', 'kurz', 'arbeit', 'gmbh', 'oktober', 'firma', 'werk', 'redaktion', 'leiter', 'leitung', 'teil', 'gebiet', 'monat', 'post']
#
# Precision: 0.07407407407407407
# Recall: 0.6666666666666666
# F1-Score: 0.13333333333333333
# ___________________________
# Presseinformation: 1971 0607
# Goldstandard: ['mulhouse', 'frankreich', 'leinfelden', 'solothurn', 'st. niklaus', 'dreiländereck', 'export', 'fabrik', 'hochfrequenz-elektrowerkzeuge', 'druckluftwerkzeuge']
# Predicted: ['dreiländereck', 'leinfelden', 'solothurn', 'stuttgart', 'boschcornbi', 'fabrik', 'export', 'gelände', 'mitarbeiter', 'druckluft', 'werkzeug']
#
# Precision: 0.45454545454545453
# Recall: 0.5
# F1-Score: 0.47619047619047616
# ___________________________
# Presseinformation: 1972 0209
# Goldstandard: ['kolbenstange', 'spanne', 'heben', 'auswerfen', 'richtung', 'zylinder', 'dämpfung']
# Predicted: ['stuttgart', 'bosch-industrie-pneumatik', 'robert bosch gmbh', 'eckhard d. noelte', 'f. wolfgang knellessen', 'gerd neermann', 'irmgard müller', 'programm', 'reihe', 'bosch', 'durchmesser', 'robert', 'dämpfung', 'zylinder']
#
# Precision: 0.14285714285714285
# Recall: 0.2857142857142857
# F1-Score: 0.19047619047619047
# ___________________________
# Presseinformation: 1972 0804
# Goldstandard: ['lübeck', 'stuttgart-feuerbach', 'schornstein', 'rauch', 'luft', 'staubabsonderung', 'abscheidegrad', 'korrosionsanfälligkeit', 'staub', 'kamin', 'kupolofenentstaubung', 'abkühlung', 'temperatur', 'geräuschbelästigung', 'kupolofen', 'filterschläuche', 'filterkammer', 'schalldämpfer']
# Predicted: ['luheck', 'lübeck', 'stuttear t -feuerbach', 'stuttgart', 'stuttgart-feuerbach', "'robert bosch gmbh", 'abt und', 'anl', 'anl age', 'bosch', 'beth', 'bosch i n', 'robert bohch gmb h', 'robert bosch gmbh', 'robert bosch gmbh robert bosch gmbh', 'choltitz', 'klaus germann', 'margarete düker', 'timo v. choltitz', 'wolfgang knallassen', 'wolfgang knellessen', 'luft', 'robert', 'luft', 'gmbh', 'mark', 'kamin']
#
# Precision: 0.14814814814814814
# Recall: 0.2222222222222222
# F1-Score: 0.17777777777777776
# ___________________________
# Presseinformation: 1973 0309
# Goldstandard: ['stuttgart-feuerbach', 'mannheim', 'kirchberg', 'jagst', 'bundesverband der deutschen industrie', 'edgar gutbub', 'modellschreinerei', 'künstler', 'werk', 'entlliftungsschächten', 'heizungsrohren', 'saugstutzen', 'metallwerk', 'schreinerei', 'schaffen', 'atelier']
# Predicted: ['mannheim', 'mßnnheim', 'stuttgart', 'stuttgart-feuerbach', 'robert bosch gmbh', 'ormation', 'abt', 'bosch', 'edgar gutbub', 'f. wolfgang kneliessen', "k'unstler edgar", "k'unstler edgar gutbub", 'klaus germann', 'margarete düker', 'professor', 'timo v. choltitz', 'wolfgang kneliessen', 'gut', 'robert', 'edgar', 'gmbh', 'presse', 'atelier', 'beginn', 'vermittlung']
#
# Precision: 0.16
# Recall: 0.25
# F1-Score: 0.19512195121951217
# ___________________________
# Presseinformation: 1973 1111
# Goldstandard: ['baden-württemberg', 'robert bosch industrieausrüstung gmbh', 'rohrleitungen', 'strangfärberei', 'frottier', 'rohrsysteme', 'rohr', 'rieber-rohrleitungssysteme']
# Predicted: ['baden-württemberg', 'stuttgart', 'prt', 'robert bosch gmbh', 'robert bosch industrieausrüstung gmbh', 'eckhard d. noelte', 'f. wolfgang knellesseri', 'gerd neermann', 'lrmgard müller', 'bosch', 'bereich', 'färberei', 'industrie', 'ausrüstung', 'robert', 'gmbh', 'presse', 'information', 'weberei', 'betrieb']
#
# Precision: 0.1
# Recall: 0.25
# F1-Score: 0.14285714285714288
# ___________________________
# Presseinformation: 1974 0607
# Goldstandard: ['stuttgart-mühlhausen', 'luft', 'reinhaltung', 'kondensator', 'zink', 'ventilatoren', 'entstaubungsanlagen', 'zinkstaub', 'zinkstaubabscheider', 'zinkspritzautomaten', 'filter']
# Predicted: ['mülhausen', 'stuttgart', 'stuttgart-mühlhausen', 'bosch', 'robert bosch gmbh', 'choltitz', 'f_ wolfgang knellessen', 'klaus gennann', 'margarete düker', 'luft', 'robert', 'menge', 'zink', 'gmbh', 'filter']
#
# Precision: 0.26666666666666666
# Recall: 0.36363636363636365
# F1-Score: 0.30769230769230765
# ___________________________
# Presseinformation: 1975 0102
# Goldstandard: ['gewicht', 'schleifer', 'arbeit', 'leistung', 'naßschleifer', 'baugröße', 'universal-naßschleifer', 'einschaltsperre']
# Predicted: ['stuttgart', 'bosch bpd', 'bosch', 'prt', 'pressestelle technik robert bosch gmbh', 'von robert bosch gmbh', 'eckhard d. noelte', 'f. wolfgang knellessen', 'gerd neermann', 'lrmgard müller', 'januar', 'natur', 'arbeit', 'presse', 'information', 'leistung', 'universal', 'robert', 'und', 'gerät']
#
# Precision: 0.1
# Recall: 0.25
# F1-Score: 0.14285714285714288
# ___________________________
# Presseinformation: 1975 0502
# Goldstandard: ['blaichach', 'allgäu', 'stuttgart', 'stuttgart-feuerbach', 'sonthofen', 'walter krüger', 'mitarbeiter', 'motorenhersteller', 'motor', 'abgaswerte', 'zündanlagen', 'magnetzünder', 'spulenzündung']
# Predicted: ['allgäu', 'blaichach', 'italien', 'schweden', 'sonthofen', 'stuttgart', 'stuttgart-feuerbach', 'stuttgart1', 'werk blaichach', 'bosch', 'baumwol lspinnerei und · weberei', 'robert bosch', 'robert bosch gmbh', 'zentralabteilung presse und information', 'klaus germann', 'wolfgang knellessen', 'werk', 'mai', 'robert', 'gmbh', 'kraftfahrzeug', 'ausrüstung', 'presse']
#
# Precision: 0.21739130434782608
# Recall: 0.38461538461538464
# F1-Score: 0.27777777777777773
# ___________________________
# Presseinformation: 1976 0101
# Goldstandard: ['handhabungssystem', 'programmierung', 'bedienung', 'industrieausrüstung', 'lochbildern', 'löten', 'schweißen', 'palettieren', 'koordinatentisch']
# Predicted: ['stuttgart1', 'bosch', 'robert bosch gmbh', 'robert bosch und', 'gerd neermann knellessen', 'klaus germann', 'serie', 'januar', 'industrie', 'ausrüstung', 'robert', 'wirtschaftlich', 'gmbh', 'presse', 'information', 'programm', 'leitung', 'programmierung']
#
# Precision: 0.05555555555555555
# Recall: 0.1111111111111111
# F1-Score: 0.07407407407407407
# ___________________________
# Presseinformation: 1976 0907
# Goldstandard: ['bosch gmbh', 'wärmewerte', 'zweitaktmotor', 'unempfindlichkeit', 'verschmutzung', 'motor', 'gemischzugängigkeit', 'verbrennungsdruck', 'sportzündkerze', 'kerze']
# Predicted: ['isle of man', 'stuttgart', 'bosch', 'gmbh', 'robert bosch und', 'eckhard d. noelte', 'klaus germann', 'wolfgang knellessen', 'arbeit', 'erprobung', 'fertigung', 'kerze']
#
# Precision: 0.08333333333333333
# Recall: 0.1
# F1-Score: 0.0909090909090909
# ___________________________
# Presseinformation: 1977 0123
# Goldstandard: ['spültechnik', 'betriebskosten', 'wasser', 'heizstrom-verbrauch', 'ersparniswerte', 'küche', 'programmwahl', 'geschirrspüler']
# Predicted: ['stuttgart', 'robert bosch', 'zentralabteilung presse und information bosch gmbh', 'klaus germann', 'wolfgang knellessen', 'wolfgang messerschmidt', 'programm', 'wahl', 'programm', 'technik', 'entwicklung', 'erkenntnis', 'modell', 'bosch', 'prozent', 'gerät']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 1977 1006
# Goldstandard: ['karlsruhe', 'karlsruhe-hagsfeld', 'aarau', 'karlsruhe-durlach', 'europa', 'oehler-wyhlen-lagertechnik ag', 'zentrallager', 'hochregallager', 'greiflager', 'lager', 'mitarbeiter']
# Predicted: ['aarau/', 'europa', 'karlsruhe', 'karlsruhe-durlach', 'karlsruhe-hagsfeld', 'stuttgart', 'bosch', 'boschgeschäftsbereich', 'robert bosch gmbh', 'robertbosch', 'gerd neermann', 'klaus germann', 'wolfgang knellessen', 'bau', 'industrie', 'gebiet', 'robert', 'presse', 'information', 'gmbh', 'leitung']
#
# Precision: 0.19047619047619047
# Recall: 0.36363636363636365
# F1-Score: 0.25
# ___________________________
# Presseinformation: 1978 1014
# Goldstandard: ['blaupunkt', 'musik', 'tonqualität', 'cb-funk', 'rundfunk', 'recorder', 'boot']
# Predicted: ['stuttgart', 'blaupunkt', 'robert bosch gmbh', 'zentralabteilung presse und information', 'klaus germann', 'noelte', 'wolfgang knellessen', 'bosch', 'boot', 'presse', 'information', 'leitung', 'information', 'robert', 'musik', 'rundfunk', 'tanz', 'musik', 'bord', 'wetter', 'nachricht', 'tanzmusik']
#
# Precision: 0.18181818181818182
# Recall: 0.5714285714285714
# F1-Score: 0.27586206896551724
# ___________________________
# Presseinformation: 1979 0501
# Goldstandard: ['schwieberdingen', 'ludwigsburg', 'kinoton gmbh', 'zentralabteitung presse und information', 'katastrophenschutzübung', 'katastrophenschutz-organisation', 'brand', 'feuer', 'mitarbeiter', 'sicherheit']
# Predicted: ['münchen', 'stuttgart', 'robert bosch gmbh', 'bosch', 'klaus germann', 'wolfgang knellessen', 'xii', 'robert', 'gmbh', 'leitung', 'gebiet', 'markt', 'entwicklung', 'zukunft']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 1979 1103
# Goldstandard: ['vereinigten staaten', 'usa', 'borg-warner corporation', 'applied electronics  corporation', 'surftran corporation', 'gesellschaft', 'unternehmen', 'kraftfahrzeug-handelsgeschäft', 'vertrieb', 'markt', 'hörgerät']
# Predicted: ['staaten', 'stuttgart', 'usa', 'vereinigten', 'borg-warner corporation', 'bosch', 'robert - bosch corporation', 'robert bosch corporation', 'robert bosch gmbh', 'robert bosch sales corpo ration', 'robert bosch sales corporation', '·beschäftigt', 'klaus germann', 'wolfgang knallessen', 'wolfgang knellessen', 'robert', 'corporation', 'vertrieb', 'staat', 'leitung', 'gmbh', 'januar', 'gesellschaft', 'fernseh', 'aktivität']
#
# Precision: 0.16
# Recall: 0.36363636363636365
# F1-Score: 0.2222222222222222
# ___________________________
# Presseinformation: 1980 0601
# Goldstandard: ['gerlingen-schillerhöhe', 'scintilla ag', 'stanley power  tools', 'geschichte', 'geschichtsunterricht', 'jugendliche', 'erwachsene', 'förderung', 'familie']
# Predicted: ['gerlingen-schillerhöhe', 'nordamerika.', 'usa', 'rbar', 'rbik', 'robert bosch', 'wolfgang knellessen', 'robert', 'juni', 'gmbh', 'essen', 'bosch', 'familie', 'kenntnis']
#
# Precision: 0.14285714285714285
# Recall: 0.2222222222222222
# F1-Score: 0.17391304347826086
# ___________________________
# Presseinformation: 1981 0116
# Goldstandard: ['bügel', 'stoff', 'platzbedarf', 'aufbewahrung', 'bügelautomaten', 'bosch-büglers']
# Predicted: ['stuttgart', 'robert bosch', 'robert bosch gmbh', 'zentralabteilung und', 'frank-ulrich breitsprecher', 'wolfgang knellessen·t', 'wolfgang messerschmidt', 'stück', 'familie', 'breiten', 'kraft', 'anwendung', 'wäsche', 'handhabung', 'bm 85 ke']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 1981 0908
# Goldstandard: ['nutzfahrzeuge', 'dieselmotoren', 'starter', 'einspursicherheit', 'motor', 'bosch-starter', 'ke-starterreihe']
# Predicted: ['stuttgart', 'bosch', 'robert bosch gmbh', 'eckhard d. noelte', 'frank-ulrich breitsprecher', 'wolfgang knellessen', 'nutzfahrzeuge', 'presse', 'information', 'leitung', 'liter', 'ke', 'starter']
#
# Precision: 0.15384615384615385
# Recall: 0.2857142857142857
# F1-Score: 0.2
# ___________________________
# Presseinformation: 1982 0707
# Goldstandard: ['messung', 'prüfung', 'drehstromgenerator-tester wpg 012']
# Predicted: ['stuttgart', 'bosch', 'robert bosch', 'robert bosch gmbh', 'zentralabteilung presse und information', 'eckhard d. noelte', 'frank-ulrich breitsprecher', 'wolfgang knellessen', 'test', 'presse', 'information', 'leitung', 'robert', 'größe', 'gerät', 'drehstrom', 'generator']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 1983 0604
# Goldstandard: ['waiblingen', 'lorch', 'stuttgart-feuerbach', 'höfliger + karg-fabrik', 'werk', 'fertigung', 'entwicklung', 'vertrieb', 'bau', 'fabrik', 'umwelt', 'bosch-verpackungsmaschinen']
# Predicted: ['stuttgart', 'stuttgart-feuerbach', 'waiblingen', 'bosch', 'hesser', 'höfliger + karg', 'höfliger + karg-fabrik', 'presse bosch', 'robert bosch gmbh', 'verpackungsmaschinen', 'unt', 'wolfgang knellessen', 'jahr', 'anfang', 'erkenntnis', 'vertrieb', 'werk', 'mitarbeiter', 'kantine', 'information', 'maschine']
#
# Precision: 0.23809523809523808
# Recall: 0.4166666666666667
# F1-Score: 0.30303030303030304
# ___________________________
# Presseinformation: 1984 0307
# Goldstandard: ['lärmminderung', 'lärm', 'bosch-hochfrequenz-außenrüttler', 'umformer', 'verdichtung']
# Predicted: ['stuttgart', 'bosch', 'robert bosch gmbh', "frank-ulrichbreitsprecher'8'62", 'gerd neermann', 'knellessen', 'beton', 'form', 'verdichtung', 'kva']
#
# Precision: 0.1
# Recall: 0.2
# F1-Score: 0.13333333333333333
# ___________________________
# Presseinformation: 1984 1101
# Goldstandard: ['haushalt', 'elektrogeräte', 'dampfstop-automatik', 'küche', 'wasser', 'wasserkocher']
# Predicted: ['hochstraße 17', 'münchen', 'hal be', 'bosch', 'bundespost', 'robert bosch haus gmbh', 'robert bosch hausgeräte gmbh', 'presse', 'liter', 'wasser', 'wasserkocher', 'wasser']
#
# Precision: 0.16666666666666666
# Recall: 0.3333333333333333
# F1-Score: 0.2222222222222222
# ___________________________
# Presseinformation: 1985 0436
# Goldstandard: ['bamberg', 'homburg-ost', 'rodez', 'bosch-werk bamberg', 'fertigung', 'einspritzsysteme', 'einspritzventilen', 'benzineinspritztechnik']
# Predicted: ['bamberg', 'homburg', 'homburg-ost', 'rodez', 'stuttgart', 'veni ssieux', 'bosch', 'bosch-gruppe', 'robert bosch gmbh', 'frank-ulrich breitsprecher', 'wolfgang knellessen', 'million', 'produktions', 'erweiterung', 'robert', 'leitung']
#
# Precision: 0.1875
# Recall: 0.375
# F1-Score: 0.25
# ___________________________
# Presseinformation: 1985 0905
# Goldstandard: ['porsche', 'reifendruck', 'rennfahrzeugen', 'sicherheit', 'entwicklung', 'rennsport', 'reifendruckkontrollsystem']
# Predicted: ['bosch', 'porsche', 'zeit', 'einsatz', 'vordergrund', 'sicherheit', 'rennsport', 'erfolg', 'serie', 'system']
#
# Precision: 0.3
# Recall: 0.42857142857142855
# F1-Score: 0.3529411764705882
# ___________________________
# Presseinformation: 1986 0806
# Goldstandard: ['verkehrssicherheit', 'sicht', 'spoiler-wischblatt']
# Predicted: ['stuttgart', 'bosch', 'jpuhhh', 'robert bosch gmbh', 'frank-ulrich breitsprecher', 'wolfgang knellessen', 'beitrag', 'fahrer', 'seite', 'leitung', 'presse', 'abteilung', 'sicht']
#
# Precision: 0.07692307692307693
# Recall: 0.3333333333333333
# F1-Score: 0.125
# ___________________________
# Presseinformation: 1987 0706
# Goldstandard: ['karosserie', 'scheinwerfer-reinigungsanlagen', 'fahrzeugscheinwerfer', 'hochdruck-reinigungsanlagen', 'düse', 'scheinwerfer']
# Predicted: ['stuttgart', 'bosch', 'robert bosch gmbh', 'eckhard d.noelte', 'frank-ulrich breitsprecher', 'wolfgang knellessen', 'prozent', 'karosserie', 'leitung', 'robert', 'bosch bpi 41', 'wetter', 'düse']
#
# Precision: 0.15384615384615385
# Recall: 0.3333333333333333
# F1-Score: 0.21052631578947367
# ___________________________
# Presseinformation: 1988 0110
# Goldstandard: ['kettensäge', 'oil-automatik', 'öl', 'kette', 'säge']
# Predicted: ['stuttgart', 'bosch', 'robert bosch gmbh', 'brigitte diefenbacher', 'frank-ulrich breitsprecher', 'wolfgang knellessen', 'arbeit', 'länge', 'leitung', 'metern', 'kette', 'säge', 'kette']
#
# Precision: 0.15384615384615385
# Recall: 0.4
# F1-Score: 0.2222222222222222
# ___________________________
# Presseinformation: 1988 0705
# Goldstandard: ['geschäftsbereich industrieausrustung', 'informationsfluss', 'automatisierung', 'fertigung', 'datenträger', 'schreib-lese-station', 'programmiergerät']
# Predicted: ['stuttgart', 'bosch', 'robert bosch gmbh', 'robert bosch gmbh telex', 'rts', 'frank-ulrich breitsprecher', 'jürgen goroncy', 'wolfgang knellessen', 'fertigung', 'träger', 'weg', 'automatisierung', 'datum', 'und', 'datum', 'speicher']
#
# Precision: 0.125
# Recall: 0.2857142857142857
# F1-Score: 0.17391304347826086
# ___________________________
# Presseinformation: 1988 0709
# Goldstandard: ['allied signal inc.', 'akebono', 'akebono brake industry', 'nutzfahrzeuge', 'antiblockiersystemen']
# Predicted: ['hbhe', 'new', 'stuttgart', 'akebono', 'bosch', 'bosch bosch gmbh', 'robert bosch gmbh', 'frank·ulr/ch', 'wolfgang knellessen', 'prozent', 'beteiligung', 'robert', 'gmbh', 'information', 'nutzfahrzeuge']
#
# Precision: 0.13333333333333333
# Recall: 0.4
# F1-Score: 0.2
# ___________________________
# Presseinformation: 1990 0001
# Goldstandard: ['sebnitz', 'ddr', 'leipzig', 'eisenach', 'veb elektrowerkzeuge', 'intel', 'ruhla', 'robert bosch fahrzeugelektrik eisenach gmbh ', 'voest-alpine automotive gmbh', 'novatel', 'nal telecom', 'telenorma', '16-bit-mikrokontroller']
# Predicted: ['ddr', 'leipzi', 'bosch', 'intel', 'nal telecom', 'novatel bosch', 'robert bosch fahrzeugelektrik eisenach', 'robert bosch fahrzeugelektrik eisenach gmbh', 'ruhla', 'telenorma', 'lnformatlon', 'robert', 'mio', 'gmbh', 'automotive', 'änderung', 'aufsichtsrat']
#
# Precision: 0.29411764705882354
# Recall: 0.38461538461538464
# F1-Score: 0.33333333333333337
# ___________________________
# Presseinformation: 1990 0812
# Goldstandard: ['fahrzeug', 'motortester', 'mot 150', 'motor', 'einspritzsysteme ']
# Predicted: ['bosch', 'robert bosch gmbh', 'generation', 'leitung', 'robert', 'anzeige']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 1991 0315
# Goldstandard: ['heizung', 'gas-kesselthermen', 'cerastar']
# Predicted: ['stuttgart', 'bosch', 'junkers-gasgeräte-progradml', 'robert bosch gmbh', 'frank-ulrich breitsprecher', 'wolfgang knellessen', 'konzept', 'baureihe', 'bau', 'reihe', 'betrieb', 'information', 'leitung', 'edelstahl', 'gas']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 1992 0805
# Goldstandard: ['module', 'turboline-system', 'profilnuten', 'arbeitsplatte', 'produktionsmodul']
# Predicted: ['stuttgart', 'bosch', 'presse', 'robert bosch gmbh', 'frank-ulrich breitsprecher', 'friedrich schröder', 'wolfgang knellessen', 'station', 'produktions', 'angebot', 'aufbau', 'information', 'system']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 1993 0315
# Goldstandard: ['bosch telecom', 'handtelefon', 'cartel sc', 'akku']
# Predicted: ['hildesheim', 'bosch', 'robert bosch gmbh', 'lefone', 'com', 'stunde', 'display', 'presse', 'information', 'markt', 'bosch telecom', 'cartel sc']
#
# Precision: 0.16666666666666666
# Recall: 0.5
# F1-Score: 0.25
# ___________________________
# Presseinformation: 1994 0103
# Goldstandard: ['bonneville', 'china', 'argentinien', 'hildesheim', 'blaupunkt', 'telecom service', 'signalbau huber', 'hawera', 'übernahme', 'ascom-betriebsfunkgerät', 'tv-geräte']
# Predicted: ['bonneville', 'blaupunkt', 'bosch', 'cpoac', 'telecom service', 'h. scholl', 'huber', 'übernahme', 'unternehmen', 'tv', 'januar', 'pressekonferenz', 'gerät', 'ms 70 digital pro']
#
# Precision: 0.2857142857142857
# Recall: 0.36363636363636365
# F1-Score: 0.32
# ___________________________
# Presseinformation: 1994 1104
# Goldstandard: ['frankfurt', 'eschborn', 'kleyerstraße', 'bosch-vermittlungstechnik', 'telenorma gmbh', 'mitarbeiter', 'betriebsräte']
# Predicted: ['eschborn', 'frankfurt', 'frankfurt am main', 'kleyerstraße', 'bosc', 'bosch-vermittlungstechnik', 'telenorma gmbh', 'november', 'meldung', 'presse', 'technik', 'sitz', 'main', 'mitarbeiter', 'gmbh', 'bosch', 'dienstag']
#
# Precision: 0.35294117647058826
# Recall: 0.8571428571428571
# F1-Score: 0.5
# ___________________________
# Presseinformation: 1995 0813
# Goldstandard: ['pagingdienst', 'multifunktions-pager', 'p-com 416', 'scall', 'cityruf']
# Predicted: ['deutschland', 'frankfurt am main', 'stuttgart', 'bosch', 'bosch telecom', 'detemobil', 'internationalen funkausstellung', 'robert bosch gmbh', 'frank\\jlrich breitsprecher', 'city', 'ruf', 'internationale', 'nutzer', 'com', 'dienst', 'größe', 'presse']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 1996 0207
# Goldstandard: ['bonn', 'nordrheinwestfalen', 'berlinbrandenburg', 'deutschen telekom ag', 'dr. gert siegle', 'volker steiner', 'willfried seibel', 'fahrzeug', 'bewegtbildübertragung', 'digital audio broadcasting-verfahrens', 'dab']
# Predicted: ['baden-württemberg', 'berlinbrandenburg', 'deutschland', 'nordrheinwestfalen', 'sachsen', 'sachsen-anhalt', 'thüringen', 'bosch', 'boschgeräte', 'deutsche telekom', 'deutsche telekom ag', 'deutschen telekom', 'deutschen telekom ag', 'ifa', 'internationalen funkausstellung', 'robert bosch gmbh', 'mobil bosch', 'siegle', 'steiner', 'thomas knoll', 'willfried seibel', 'deutsche', 'robert', 'land', 'öffentlichkeit', 'telekom', 'multimedia', 'fahrzeug', 'video', 'signal', 'fahrzeug', 'möglichkeit', 'dab', 'dab i']
#
# Precision: 0.17647058823529413
# Recall: 0.5454545454545454
# F1-Score: 0.26666666666666666
# ___________________________
# Presseinformation: 1996 0820
# Goldstandard: ['prag', 'tschechien', 'eurotel', 'bosch telecom gmbh', 'richtfunktechnik', 'mobilfunk-kommunikation', 'sdh-richtfunkeinrichtungen']
# Predicted: ['prag', 'stuttgar', 'stuttgart', 'tschechien', 'bosch', 'bosch telecom', 'bosch telecom gmbh', 'eurotel', 'eurotel praha', 'robert bosch gmbh', 'us west international', 'frank-ulrich breitsprecher', 'betreiber', 'com', 'technik', 'vertrag', 'praha', 'technik', 'mobilfunk', 'richtfunk', 'richtfunk', 'system']
#
# Precision: 0.18181818181818182
# Recall: 0.5714285714285714
# F1-Score: 0.27586206896551724
# ___________________________
# Presseinformation: 1997 0309
# Goldstandard: ['fern-und automatikstart', 'stromerzeuger', 'profiline', 'benzin-modellen']
# Predicted: ['stuttgart', 'bosch', 'dvgw verein des gas· und wasserfaches', 'kölner eisenwarenmesse', 'robert bosch gmbh', 'frank-ulrich breitsprecher', 'strom', 'energie', 'modellreihe', 'modell', 'reihe', 'kölner', 'presse', 'information', 'verbraucher', 'stromerzeuger', 'variante', 'kva', 'g 4000 sp 6000 pm', 'gd 6000 spe', 'gd 8000 spe']
#
# Precision: 0.047619047619047616
# Recall: 0.25
# F1-Score: 0.08
# ___________________________
# Presseinformation: 1997 0905
# Goldstandard: ['stromversorgungskonzepte', 'motorstart', 'verbraucher', 'spannung', 'bordnetze', 'start-stop-betrieb', 'starter-und versorgungsbatterie', 'starterbatterie']
# Predicted: ['stuttgart', 'bosch', 'robert bosch gmbh', 'frank-ulrich breitsprecher', 'spannung', 'volt', 'lösung', 'anspruch', 'antrieb', 'neben', 'form', 'pkw', 'konzept', 'motor', 'generator', 'batterie', 'aggregat', 'beispiel']
#
# Precision: 0.05555555555555555
# Recall: 0.125
# F1-Score: 0.07692307692307691
# ___________________________
# Presseinformation: 1998 0313
# Goldstandard: ['fiat', 'diesel-einspritztechnik', 'speichereinspritzsystems', 'verbrennungsprozeß', 'dieselmotoren', 'common rail', 'auto motor']
# Predicted: ['stuttgart', 'bosch pi ks', 'bosch', 'comrnon', 'cornrnon', 'cornrnon rail', 'fiat', 'robert bosch gmbh', 'rni', 'c.aß', 'frank-ulrich breitsprecher', 'dieselmotoren', 'hilfe', 'redaktion', 'hersteller', 'entwicklung', 'verbrauch', 'mission', 'preis', 'innovation', 'rail', 'speicher', 'automobil', 'abgas']
#
# Precision: 0.08333333333333333
# Recall: 0.2857142857142857
# F1-Score: 0.12903225806451613
# ___________________________
# Presseinformation: 1998 0804
# Goldstandard: ['volkswagen', 'tdi-generation', 'unit-injector-system', 'radialkolben-verteilereinspritzpurnpe']
# Predicted: ['stuttgart', 'bosch', 'robert bosch gmbh', 'volkswagen', 'rni', 'frank-ulrich breitsprecher', 'herbst', 'generation', 'serie', 'generation', 'voraussetzung', 'kraftstoff', 'menge', 'presse', 'information', 'dieselmotoren', 'pumpe', 'düse', 'zylinder', 'commonrail system crs']
#
# Precision: 0.05
# Recall: 0.25
# F1-Score: 0.08333333333333334
# ___________________________
# Presseinformation: 1999 0303
# Goldstandard: ['gerlingen', 'leverkusen', 'hamburg', 'jugend forscht', 'jugend', 'biologie', 'chemie']
# Predicted: ['baden-württemberg', 'bodensee', 'gerlingen', 'gerlinger stadlhalle', 'hamburg', 'leverkusen', 'stuttgart', 'wuld', 'jugend forschte', 'limdeswettbewerb', 'roben bosch gmbh', 'sradthalle', '\\iz', 'frank-ulrich breitaprecher', 'frank-ulrich breitsprecher', 'krause', 'robert bosch', 'tterer', 'jugend', 'bosch', 'märz', 'gmbh', 'robert', 'jugendliche', 'biologie', 'chemie', 'arbeit', 'mathematik', 'informatik', 'zimmermann', 'und']
#
# Precision: 0.1935483870967742
# Recall: 0.8571428571428571
# F1-Score: 0.3157894736842105
# ___________________________
# Presseinformation: 1999 1105
# Goldstandard: ['adac', 'batterie', 'mobilitätsgarantie']
# Predicted: ['deutschland', 'gmbh/zö', 'stuttgart', 'tololon', 'adac', 'adac strassenwacht', 'bosch', 'efc', 'oel', 'robert bosch gmbh', 'zöf robort bosch qmbh', 'eme', 'bormann', 'botton', 'frank-ulrich braitsprechar', 'frank-ulrich breltaprecher', 'knoll', 'noebel bajnovlc', 'robert bosch', 'ulf-malte wünsch', 'tobar', 'presse', 'mitteilung', 'presse', 'forum', 'notruf', 'nummer', 'gmbh/zö.zöi»', 'krause', 'batterie', 'kontakt', 'zubehör', 'start']
#
# Precision: 0.06060606060606061
# Recall: 0.6666666666666666
# F1-Score: 0.1111111111111111
# ___________________________
# Presseinformation: 2000 0310
# Goldstandard: ['elektrowerkzeug', 'ahs 6000 pro', 'ahs 7000', 'messer']
# Predicted: ['stuttgart', 'robert bosch gmbh', 'ttl', 'gerhard ketterer', 'pro', 'internet', 'presse', 'forum', 'dauer', 'einsatz', 'ahs 6000 pro', 'ahs 7000 pro', 'bosch', 'maßstab']
#
# Precision: 0.07142857142857142
# Recall: 0.25
# F1-Score: 0.11111111111111112
# ___________________________
# Presseinformation: 2000 0702
# Goldstandard: ['backnang', 'raumfahrttechnik', 'leiterplatten']
# Predicted: ['backnang', 'stuttgart', 'tol■', 'gmbh/', 'ketterer', 'rob11rt rneeh gmbh', 'telecom', 'vda', 'bielet', 'iwei', 'jc12r', 'arnold borm1nn', 'dr.', 'gerhard', 'horton', 'robert bosch', 'yrol•yl', 'auftrag', 'leiter', 'gmbh', 'presse', 'information', 'robert', 'bosch', 'anforderung', 'leiterplatten', 'fax']
#
# Precision: 0.07407407407407407
# Recall: 0.6666666666666666
# F1-Score: 0.13333333333333333
# ___________________________
# Presseinformation: 2000 1009
# Goldstandard: ['daimler-chrysler', 'audi', 'bmw', 'cadillac', 'citroen', 'daewoo', 'fiat', 'lancia', 'mitsubishi', 'opel', 'peugeot', 'porsche', 'renault', 'suzuki', 'vauxhall', 'volvo', 'vw', 'slk 320', 'zündkerze']
# Predicted: ['stuttgart', 'bmw', 'bosch', 'daimler-chrysler', 'fiat', 'kata', 'volvo', 'oschmbh', 'ttl', 'frank·ulnch', 'robert bosch', 'ulf-malte wünsch', 'mercedes', 'gmbh', 'werk', 'robert', 'bild', 'masse', 'klasse', 'oper', 'leistung', 'modell', 'f 8 oper c-klasse', 'mercedes c-kla11e', 'elektrode']
#
# Precision: 0.16
# Recall: 0.21052631578947367
# F1-Score: 0.1818181818181818
# ___________________________
# Presseinformation: 2001 0350
# Goldstandard: ['genf', 'blaupunkt', 'silver plus', 'powercontrol system', 'esp', 'common rail', 'bea 350', 'zündkerze', 'funline']
# Predicted: ['europa', 'bosch', 'silver', 'plus', 'kraft', 'energie', 'stand', 'zeit', 'prozent', 'anzeige', 'silver plus', 'start', 'start', 'batterie']
#
# Precision: 0.07142857142857142
# Recall: 0.1111111111111111
# F1-Score: 0.08695652173913043
# ___________________________
# Presseinformation: 2001 0909
# Goldstandard: ['ravensburg', 'hawera probst gmbh', 'dr. marco lang', 'handwerker', 'metall', 'quadro-x', 'sägeblätter', 'hammerbohrer']
# Predicted: ['ravensburg', 'schützenstraße 77', 'combi tee', 'hawera probst', 'hawera', 'hawera probst gmbh', 'superfine tee', 'september', 'leiter', 'hersteller', 'pressekonferenz', 'presse', 'konferenz', 'marktführer', 'markt', 'handwerker', 'einsatz', 'fast cut', 'qualität', 'ausführung']
#
# Precision: 0.15
# Recall: 0.375
# F1-Score: 0.21428571428571425
# ___________________________
# Presseinformation: 2002 0114
# Goldstandard: ['hildesheim', 'miskolc', 'stuttgart-feuerbach', 'wemerstraße', 'hans walz', 'robert bosch', 'mitarbeiter', 'kündigung', 'ersten weltkrieg', 'firma', 'vorsitz', 'starter']
# Predicted: ['bundesrepublik', 'cologne', 'dessau', 'detroit', 'deutschland', 'england', 'europas', 'europe', 'federal republic', 'hoppenlau-friedhofs', 'israel', 'köln', 'magdeburg', 'mains', 'modeme', 'neckar canal', 'neckarkanals', 'obertürkheim', 'p.o', 'paris', 'rotebühlstraße 75b', 'springfield', 'stuttgart feuerbach', 'stuttgart germany', "stuttgart's hoppenlau cemetery", "stuttgart's houses", 'stuttgart-feuerbach', 'stuttgart-feuerbach 70442', 'stuttgarts', 'usa', 'ulm', 'wemerstraße 1', 'wernerstraße 1', 'western', 'westeuropa', 'aufsich', 'custody', 'force', 'ofstuttgart', 'sandstone', 'south ofthe river main', 'threestorey building', 'vehicle-repair', 'allianz -versicherungs ag', 'allianz insurance company', 'allied air raids', 'american military administration', 'assets', 'association of metal workers', 'bosch company', 'bosch group', 'bosch jewish', 'bosch employees', 'bosch factories', 'bosch ignition for motor vehicles', "bosch's company", 'british military governments', 'british television', 'bugen bauer gmbh', 'company', 'company archives', 'daimler motoren-gesellschaft', 'de dion bouton motor tricycles', 'deutz motor factory', 'diesel injection equipment', 'düsseldorfer mannesmann ag', 'electric power tools division', 'electrical', 'elektrotechnische', 'engineering', 'feuerbach', 'ford', 'ford company', 'gennany', 'german', 'germany', 'gmbh', 'hugo junkers', 'hugo junkers and production', 'ideal-werken', 'iimited liability company', "merkle's", 'motorenfabrik deutz', 'national socialist period of israel', 'national socialists', 'page5 and exhibitions', 'page6', 'page9 bosch gmbh', 'precision', 'reich government', 'robert bosch foundation', 'robert bosch gmbh', 'robert bosch industriebeteiligung', 'robert bosch industriebeteiligung gmbh', 'robert bosch industrietreuhand', 'robert bosch industrietreuhand kg', 'robert bosch robert bosch gmbh', 'robert bosch stiftung', 'robert-bosch-krankenhaus', 'robert-bosch-stiftung', 'stuttgart polytechnic', 'stuttgart suburb', 'technischen hochschule stuttgart', 'the fortunes', 'this', 'vacuum', 'wild and fellmeth', 'agencies', 'and', 'automobile', 'charitable causes', 'correct', 'earncd abroad', 'eine equipment factory eugen bauer gmbh', 'entire bosch group', 'for', 'foundation', 'foundation ofan agency', 'für', 'his', 'joint-stock', 'joint-stock company', 'joumalists', 'labour', 'lynch-pin', 'magneto ignition', 'marriage', 'motor-vehicle equipment and fuel-injection for aircraft engines', 'motor-vehicle equipment sector', "nephew's suggestion", 'nonjewish parentage', 'offcrcd', 'ofthe bosch company', 'ofthe industrial equipment division', 'ofthe robert bosch gmbh', 'ofthe robert bosch industrietreuhand kg', 'ofthe robert robert bosch', 'ofthe stuttgart', 'opcned', 'partner', "plumber's", 'pre-first-world-war', 'retirement age for members', "shareholders' meetings", 'staff', 'supervisory board', 'task ofthis', 'und', 'victorious', 'wholesale', 'world economic crisis', 'anna kayser', "bemhard's", 'berger', 'bierich', 'bosch', "bosch's", 'boschs', 'bugen kayser', 'carl goerdeler', 'clara zetkin', "clay's", 'englishman', 'eugen kayser', 'eva', 'fellmeth', 'fellmethjedoch', 'gemiany', 'gennany gennan', 'georg zundel', 'gerrnan words', 'gottlob honold', 'hans l. merke', 'hans l. merkle', 'hans l. merkle died', 'hans walz', 'hans walz died', "hans walz's", 'hans walzafter', 'hans walz„', 'henry ford', 'hermann bosch', 'hermann fellmeth', 'honold', 'hugo borst', 'karl', 'karl martell wild', 'lucian bernhard', 'marcus bierich', 'margarete', 'merkle', 'merkles', 'messrs', 'paula', 'paula bosch', "paula's", 'robert', 'robert bosch', 'robert bosch bosch', 'robert bosch d.j', 'robert bosch thus', 'robert boschs', 'rudolf diesel', 'ss man', 'sigmund schuckert', 'simms', 'walz', "walz's", 'wild', 'willy schlossstein', 'willy schloßstein', 'brother karl', 'chairman', 'eam money', 'genas bosch', 'having', 'him', 'married georg zundel', 'ofrobert bosch', 'ofhis', 'ofmind', 'ofthe', 'ofthe bo ...
#
# Precision: 0.00974025974025974
# Recall: 0.25
# F1-Score: 0.018750000000000003
# ___________________________
# Presseinformation: 2002 0403
# Goldstandard: ['gesellschaft für technische  überwachung', 'bremse', 'bremsanlage']
# Predicted: ['stuttgart', 'bosch', 'gesellschaft für technische überwachung gtü', 'robert bosch gmbh', 'frank-ulrich breitsprecher', 'wechsel', 'presse', 'information', 'prozent', 'bremse', 'fahrzeug', 'bremsanlage', 'auto']
#
# Precision: 0.15384615384615385
# Recall: 0.6666666666666666
# F1-Score: 0.25
# ___________________________
# Presseinformation: 2002 0710
# Goldstandard: ['abstatt', 'heilbronn', 'assel gmbh', 'chassissysteme', 'richtfest', 'techniker']
# Predicted: ['absta ti/stuttgart', 'abstau', 'abstatt', 'abstull', 'heilbronn', 'stuttgarl', 'bosch', 'bosch rexroth ag', 'bosch-gruppe', 'chassissystemc', 'roberl bosch gmbh', 'robert bosch gmbh', 'zvw', 'frank-ulrich breitsprecher', 'martin lober', 'robert', 'robert bosch', 'richtfest', 'gmbh', 'etappe', 'ziel', 'kraftfahrzeug', 'technik', 'entwicklung', 'milliarde', 'ingenieur', 'euro']
#
# Precision: 0.1111111111111111
# Recall: 0.5
# F1-Score: 0.1818181818181818
# ___________________________
# Presseinformation: 2002 1008
# Goldstandard: ['junker', 'bosch-thermotechnik', 'junkers/bosch-thermotechnik', 'junkers-website', 'heizung', 'neuer junkers-internetauftritt', 'beratung']
# Predicted: ['wernau', 'junkers', 'junkers-pressebild', 'junkers/bosch', 'junkers/bosch-thermotechnik', 'robert bosch gmbh', 'bau', 'herr', 'tipps', 'internet', 'informations', 'medium', 'auftritt', 'konzept', 'design', 'rubrik', 'beratung', 'technik', 'suche', 'produkt']
#
# Precision: 0.1
# Recall: 0.2857142857142857
# F1-Score: 0.14814814814814817
# ___________________________
# Presseinformation: 2003 0212
# Goldstandard: ['skil', 'elektrowerkzeugen', 'handkreissägen', 'säge']
# Predicted: ['stuttgart', 'robert bosch gmbh', 'skil', 'maxima robert bosch gmbh', 'frank-ulrich breitsprecher', 'gerhard ketterer', 'februar', 'netz', 'betrieb', 'kompetenz', 'anbieter', 'säge']
#
# Precision: 0.16666666666666666
# Recall: 0.5
# F1-Score: 0.25
# ___________________________
# Presseinformation: 2003 0512
# Goldstandard: ['garten- und forstgeräte', 'garten', 'zündkerze', 'rasenmäher', 'rasentrimmer', 'blattgebläse', 'gartentraktoren', 'heckenscheren', 'kettensägen', 'laubsauger', 'motorsensen', 'netzstromaggregate', 'wasserpumpen', 'schneefräsen', 'schneewerfer']
# Predicted: ['stuttgart', 'bosch', 'robert bosch gmbh', 'frank-ulrich breitsprecher', 'garten', 'mai', 'markt', 'robert', 'betrieb', 'anwendung', 'gmbh', 'garten', 'traktor', 'gerät', 'zündkerze', 'telefon', 'automobile', 'rasentrimmer']
#
# Precision: 0.16666666666666666
# Recall: 0.2
# F1-Score: 0.1818181818181818
# ___________________________
# Presseinformation: 2003 0811
# Goldstandard: ['abtragsleistung', 'sds-plus-flachmeißel', 'meißel']
# Predicted: ['stuttgart', 'bosch', 'robert bosch', 'robert bosch gmbh', 'frank-ulrich breitsprecher', 'gerhard ketterer', 'prozent', 'august', 'modell', 'material', 'robert', 'holz', 'fax', 'meißel']
#
# Precision: 0.07142857142857142
# Recall: 0.3333333333333333
# F1-Score: 0.11764705882352941
# ___________________________
# Presseinformation: 2003 1203
# Goldstandard: ['videoüberwachung', 'sicherheit', 'alarm', 'eazeo', 'kamera']
# Predicted: ['stuttgart', 'bosch', 'bosch sicherheitssysteme gmbh', 'robert bosch gmbh', 'frank-ulrich breitsprecher', 'gerhard ketterer', 'schule', 'geschäft', 'hotel', 'betrieb', 'dezember', 'betrieb', 'sicherheit', 'sport', 'freizeit', 'kamera', 'video', 'überwachung']
#
# Precision: 0.1111111111111111
# Recall: 0.4
# F1-Score: 0.1739130434782609
# ___________________________
# Presseinformation: 2004 0317
# Goldstandard: ['kettensägen', 'sägekette', 'kette']
# Predicted: ['bosch', 'bosch-presse', 'bosch-pressemeldung', 'dr.', 'gerhard ketterer', 'schmidt', 'professional', 'märz', 'service', 'zimmer', 'bereich', 'mittwoch', 'kette', 'säge', 'leute']
#
# Precision: 0.06666666666666667
# Recall: 0.3333333333333333
# F1-Score: 0.1111111111111111
# ___________________________
# Presseinformation: 2004 0615
# Goldstandard: ['junker', 'bosch-thermotechnik', 'albrecht schäfer', 'aluminium', 'wärmeübertrager', 'cerasmart']
# Predicted: ['stuttgart', 'wernau', 'junkers', 'junkers-pressebild', 'junkers/bosch-thermotechnik', 'robert bosch gmbh', 'schäfer', 'uta-micaela dürig', 'aluminium', 'juni', 'kanal', 'wärme', 'heizgerät', 'wasser', 'wasser']
#
# Precision: 0.06666666666666667
# Recall: 0.16666666666666666
# F1-Score: 0.09523809523809522
# ___________________________
# Presseinformation: 2004 0951
# Goldstandard: ['fahrzeuggewicht', 'nutzfahrzeug', 'esp', 'load adaptive control']
# Predicted: ['stuttgart', 'automotive aftermarket', 'bosch', 'robert bosch gmbh', 'uta-micaela dürig', 'februar', 'lösung', 'voraussetzung', 'arbeits', 'zustand', 'qualität', 'messtechnik']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2005 0112
# Goldstandard: ['stuttgart', 'car multimedia', 'bosch rexroth', 'max-planck-forschungsinstitut', 'bosch-gruppe', 'universität stuttgart', 'zentralbereiche forschung', 'siegfried dais', 'forschung', 'kraftfahrzeugausrüstung', 'kommunikationstechnik', 'geschäftsführung']
# Predicted: ['stuttgart', 'bosch rexroth', 'car multimedia', 'max-planck-forschungsinstitut', 'robert bosch', 'robert bosch gmb', 'robert bosch gmbh', 'pi g2', 'siegfried dais', 'bosch', 'robert', 'januar', 'siegfried', 'sieg', 'gmbh', 'vorsitzender', 'kraftfahrzeug', 'ausrüstung', 'kommunikations', 'technik']
#
# Precision: 0.25
# Recall: 0.4166666666666667
# F1-Score: 0.3125
# ___________________________
# Presseinformation: 2005 0607
# Goldstandard: ['bosch sicherheitssysteme', 'videoüberwachungssysteme', 'nacht', 'autodome-kameras']
# Predicted: ['stuttgart', 'bosch', 'bosch sicherheitssysteme gmbh', 'bosch-gruppe', 'robert bosch', 'robert bosch gmbh', 'robert bosch industrietreuhand kg', 'robert bosch stiftung', 'heutige', 'gerhard ketterer', 'uta-micaela dürig', 'von robert', 'robert', 'detail', 'ansicht', 'bereich', 'nacht', 'bild', 'euro', 'system', 'kamera', 'steuerung', 'kamera', 'kamera', 'qualität']
#
# Precision: 0.04
# Recall: 0.25
# F1-Score: 0.06896551724137932
# ___________________________
# Presseinformation: 2005 0951
# Goldstandard: ['berlin', 'frankfurt am main', 'blaupunkt', 'travelpilot rome', 'radio', 'touchscreen']
# Predicted: ['stuttgart', 'automotive aftermarket', 'bosch', 'uta-micaela', 'wü/he robert bosch gmbh', 'dürig', 'prüfung', 'programm', 'touch', 'screen', 'elektrik', 'elektronik', 'fahrzeug', 'akku', 'gerät', 'touchscreen', 'telefon']
#
# Precision: 0.058823529411764705
# Recall: 0.16666666666666666
# F1-Score: 0.08695652173913045
# ___________________________
# Presseinformation: 2006 0307
# Goldstandard: ['mercedes-benz', 'siemens vdo', 'bmw', 'dr. rolf leonhard', 'benzin-direkteinspritzung', 'strahlgeführtes brennverfahren', 'piezo-injektoren', 'ottomotor']
# Predicted: ['stuttgart', 'bosch', 'bosch-gruppe', 'deutschen zukunftspreis', 'leonhard', 'robert bosch gmbh', 'robert bosch industrietreuhand kg', 'robert bosch stiftung', 'siemens vdo', 'den', 'mit', 'robert bosch', 'uta-micaela dürig', 'robert', 'mercedes', 'benz', 'benzin', 'verbrauch', 'premiere', 'prozent', 'benzin', 'euro']
#
# Precision: 0.045454545454545456
# Recall: 0.125
# F1-Score: 0.06666666666666667
# ___________________________
# Presseinformation: 2006 0911
# Goldstandard: ['heimwerker', 'bosch-sds-system', 'maschine', 'säge']
# Predicted: ['leinfelden-echterdingen', 'stuttgart', 'bosch', 'bosch-gruppe', 'die bosch-gruppe', 'feinmechanik', 'robert bosch gmbh', 'robert bosch industrietreuhand kg', 'robert bosch stiftung', 'für', 'und', 'gerhard ketterer', 'michael schmidtke', 'robert bosch', 'uta-micaela dürig', 'robert', 'september', 'einstellung', 'euro', 'säge', 'komfort', 'pi 5520 pt ms']
#
# Precision: 0.045454545454545456
# Recall: 0.25
# F1-Score: 0.07692307692307693
# ___________________________
# Presseinformation: 2007 0307
# Goldstandard: ['elektrowerkzeuge', 'vibrationsschutz', 'winkelschleifer ', 'vibration control']
# Predicted: ['leinfelden-echterdingen', 'stuttgart', 'bosch', 'bosch-gruppe', 'feinmechanik', 'robert bosch gmbh', 'robert bosch industrietreuhand kg', 'robert bosch stiftung', 'für', 'und', 'gerhard ketterer', 'michael schmidtke', 'robert bosch', 'uta-micaela dürig', 'robert', 'märz', 'benutzung', 'euro', 'maschine']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2007 1001
# Goldstandard: ['bosch automotive tradition', 'ebay', 'bosch klassik teilevermittlung', 'ersatzteile']
# Predicted: ['breit 4', 'deutschland', 'karlsruhe', 'stuttgart', 'automobilia', 'bosch', 'bosch automotive tradition', 'bosch klassik', 'bosch klassik teilevermittlung', 'bosch-gruppe', 'ebay', 'klassik', 'robert bosch gmbh', 'robert bosch gmbh automotive aftermarket', 'robert bosch industrietreuhand kg', 'robert bosch stiftung gmbh', 'tns infratest automotive', 'heiderose dreiner', 'robert bosch', 'uta-micaela dürig', 'robert', 'teil', 'vermittlung', 'automotive', 'tradition', 'gmbh', 'euro']
#
# Precision: 0.1111111111111111
# Recall: 0.75
# F1-Score: 0.19354838709677416
# ___________________________
# Presseinformation: 2008 0318
# Goldstandard: ['bosch sicherheitssysteme', 'tonwiedergabe', 'lautsprecher']
# Predicted: ['stuttgart', 'bosch', 'bosch sicherheitssysteme gmbh', 'bosch-gruppe', 'robert bosch gmbh', 'robert bosch industrietreuhand kg', 'robert bosch stiftung gmbh', 'erika görge', 'p.o', 'robert bosch', 'uta-micaela dürig', 'robert', 'sprecher', 'ton', 'märz', 'musik', 'gmbh', 'technik', 'euro', 'lautsprecher', 'laut', 'wiedergabe', 'wiedergabe', 'lautsprecher']
#
# Precision: 0.041666666666666664
# Recall: 0.3333333333333333
# F1-Score: 0.07407407407407407
# ___________________________
# Presseinformation: 2008 1101
# Goldstandard: ['brüssel', 'europa', 'esafety-award-komitee', 'fia', 'esafety', 'automobilweltverbands fia', 'europäischen kommission', 'dr. bernd bohr', 'esp®']
# Predicted: ['europa', 'köln', 'stuttgart', 'award', 'bosch', 'bosch-gruppe', 'environment', 'europäischen kommission', 'fia', 'road', 'robert bosch gmbh', 'robert bosch industrietreuhand kg;', 'robert bosch stiftung gmbh', 'and', 'esafety award', 'esafety-award-komitee', 'for', 'the', 'bohr', 'robert bosch', 'uta-micaela dürig', 'robert', 'brüssel', 'technologie', 'kommunikation', 'technik', 'aufklärung', 'esp® brüssel', 'euro', 'prize', 'world', 'wissen']
#
# Precision: 0.15625
# Recall: 0.5555555555555556
# F1-Score: 0.24390243902439024
# ___________________________
# Presseinformation: 2009 0419
# Goldstandard: ['pollen', 'gesundheitsschutz', 'sicherheit', 'komfort', 'luft', 'aktivkohle-innenraumfilter', 'innenraumfilter', 'klimaanlage']
# Predicted: ['karlsruhe', 'stuttgart', 'bosch', 'bosch-gruppe', 'robert bosch gmbh', 'robert bosch gmbh automotive aftermarket', 'robert bosch industrietreuhand kg;', 'robert bosch stiftung gmbh', 'heiderose dreiner', 'robert bosch', 'uta-micaela dürig', 'robert', 'gmbh', 'april', 'kilometer', 'zeit', 'wechsel', 'prozent', 'euro']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2009 1004
# Goldstandard: ['südafrika', 'kapstadt', 'johannesburg', 'stuttgart', 'bosch packaging technology', 'propak', 'friedbert klefenz']
# Predicted: ['afrika', 'johannesburg', 'kapstadt', 'stuttgart', 'südafrika', 'waiblingen', 'bosch', 'bosch packaging technology', 'bosch-gruppe', 'propak', 'robert bosch gmbh', 'robert bosch industrietreuhand kg;', 'robert bosch stiftung gmbh', 'robert bosch', 'uta-micaela dürig', 'packaging', 'niederlassung', 'technology', 'robert', 'oktober', 'präsenz', 'euro', 'vorteil']
#
# Precision: 0.2608695652173913
# Recall: 0.8571428571428571
# F1-Score: 0.4
# ___________________________
# Presseinformation: 2010 0701
# Goldstandard: ['stuttgart', 'deutschland', 'grasbrunn', 'bosch sicherheitssysteme', 'kamera']
# Predicted: ['deutschland', 'grasbrunn', 'postfach', 'stuttgart', 'bosch', 'bosch robert bosch gmbh', 'bosch sicherheitssysteme', 'bosch-gruppe', 'robert bosch gmbh', 'robert bosch industrietreuhand kg;', 'robert bosch stiftung gmbh', 'erika görge', 'robert bosch', 'uta-micaela dürig', 'robert', 'serie', 'ip', 'juli', 'budget', 'anbieter', 'euro', 'pi 7116 st', 'kamera', 'überwachung', 'speicherung', 'kamera']
#
# Precision: 0.19230769230769232
# Recall: 1.0
# F1-Score: 0.32258064516129037
# ___________________________
# Presseinformation: 2010 1019
# Goldstandard: ['schweiz', 'st. niklaus', 'zermatt', 'feinmechanik', 'mörtel', 'mörtelentferner', 'oscillating interface system']
# Predicted: ['leinfelden-echterdingen', 'st. niklaus', 'stuttgart', 'zermatt/schweiz', 'bosch', 'bosch-gruppe', 'robert bosch gmbh', 'robert bosch industrietreuhand kg;', 'robert bosch stiftung gmbh', 'bk basic', 'gerhard ketterer', 'karin heinlein', 'robert bosch', 'uta-micaela dürig', 'robert', 'gmbh', 'entfernen', 'leben', 'dauer', 'mörtel', 'anwendung', 'einsatz', 'euro', 'welt', 'werkzeug', 'zubehör']
#
# Precision: 0.07692307692307693
# Recall: 0.2857142857142857
# F1-Score: 0.12121212121212123
# ___________________________
# Presseinformation: 2011 0326
# Goldstandard: ['deutschland', 'dr. wolfgang malchow', 'akademiker', 'kaufleute', 'jubiläumsjahr', 'mitarbeiter', 'junior manager program', 'graduate specialist program', 'arbeitgeber', 'absolventen', 'vielfalt']
# Predicted: ['berlin', 'deutschland', 'europa', 'stuttgart', 'bosch', 'bosch-gruppe', 'ende', 'premaster programm', 'robert bosch gmbh', 'robert bosch industrietreuhand kg;', 'robert bosch stiftung gmbh', 'trendence', 'universum', 'das', 'geschäftsführer', 'malchow', 'robert bosch', 'uta-micaela dürig', 'robert', 'akademiker', 'kompetenz', 'feld', 'stelle', 'kaufleute', 'wert', 'orientierung', 'jubiläumsjahr', 'jubiläum', 'jahr', 'euro']
#
# Precision: 0.13333333333333333
# Recall: 0.36363636363636365
# F1-Score: 0.1951219512195122
# ___________________________
# Presseinformation: 2011 0807
# Goldstandard: ['detmold', 'bosch packaging technology', 'michael voeth', 'müllereitagung', 'dornrad-paketieranlage', 'paketieranlage']
# Predicted: ['stuttgart', 'waiblingen', 'bosch', 'bosch packaging technology', 'müllereitagung', 'robert bosch gmbh', 'robert bosch industrietreuhand kg;', 'robert bosch stiftung gmbh', 'technology', 'und reduzierte stillstandzeiten', 'johanna bauer', 'michael voeth', 'robert bosch', 'uta-micaela dürig', 'robert', 'august', 'design', 'gmbh', 'euro', 'maschine']
#
# Precision: 0.15
# Recall: 0.5
# F1-Score: 0.23076923076923075
# ___________________________
# Presseinformation: 2012 0113
# Goldstandard: ['bosch sensortec gmbh', 'smartphones', 'drehratensensor', 'sensor', 'applikation', 'telefon']
# Predicted: ['stuttgart', 'bosch', 'bosch gruppe', 'bosch sensortec', 'bosch sensortec gmbh', 'bosch-gruppe', 'robert bosch gmbh', 'dem bmg160', 'uta-micaela dürig', 'konzept', 'milliarde', 'euro', 'hand', 'sensor', 'smartphones', 'sensor', 'applikation', 'funktionalität', 'sensor', 'telefon']
#
# Precision: 0.25
# Recall: 0.8333333333333334
# F1-Score: 0.3846153846153846
# ___________________________
# Presseinformation: 2012 0808
# Goldstandard: ['chassis systems control', 'gerhard steiger', 'sicherheit', 'komfort', 'bremsregelsysteme', 'premium', 'rückförderpumpe', 'adaptive cruise control', 'hill hold control']
# Predicted: ['stuttgart', 'bosch', 'bosch-gruppe', 'robert bosch', 'robert bosch gmbh', 'systems', 'als', 'uta-micaela dürig', 'basis', 'sicherheit', 'premium', 'esp® 9 premium', 'euro', 'hill hold', 'komfort', 'version']
#
# Precision: 0.1875
# Recall: 0.3333333333333333
# F1-Score: 0.24000000000000005
# ___________________________
# Presseinformation: 2013 0201
# Goldstandard: ['bosch power tools', 'skil', 'dremel', 'electronic cell protection', 'leistung', 'schlagbohrschrauber', 'schlagfunktion', 'akku']
# Predicted: ['leinfelden-echterdingen', 'stuttgart', 'bosch', 'bosch power tools', 'dremel', 'robert', 'robert bosch gmbh', 'skil', 'uta-micaela dürig', 'februar', 'leistung', 'anwendung', 'leichtgewicht', 'prozent', 'bosch bringt mit', 'euro', 'akku', 'akku']
#
# Precision: 0.2777777777777778
# Recall: 0.625
# F1-Score: 0.3846153846153846
# ___________________________
# Presseinformation: 2013 0618
# Goldstandard: ['berlin', 'europa', 'südeuropa', 'internationales deutschlandforum', 'allensbach instituts', 'franz fehrenbach', 'angela merkel', 'wohlstandsverlust', 'wirtschaft', 'lebensqualität', 'fortschritt', 'wettbewerb', 'herausforderung']
# Predicted: ['berlin', 'europa', 'stuttgart', 'südeuropa', 'die', 'allensbach', 'bosch', 'bosch-gruppe', 'feinmechanik', 'robert bosch gmbh', 'robert bosch industrietreuhand kg;', 'robert bosch stiftung gmbh', 'für', 'und', 'angela merkel', 'fehrenbach', 'josef schumpeters', 'merkel', 'robert bosch', 'uta-micaela dürig', 'der bundesregierung', 'robert', 'wettbewerb', 'herausforderung', 'fortschritt', 'deutschland', 'forum', 'lebensqualität', 'leben', 'lösung', 'lösung', 'beim', 'euro', 'internationale deutschlandforum', 'internationalen deutschlandforum', 'zukunft', 'qualität']
#
# Precision: 0.21621621621621623
# Recall: 0.6153846153846154
# F1-Score: 0.32
# ___________________________
# Presseinformation: 2013 0947
# Goldstandard: ['bosch power tools', 'metall', 'laser', 'kaltkreissäge', 'expert for steel']
# Predicted: ['stuttgart', 'bosch', 'bosch power tools', 'dremel', 'robert bosch gmbh', 'skil', 'uta-micaela dürig', 'professional', 'frei', 'september', 'metall', 'nach', 'arbeit', 'handwerker', 'euro', 'mit kaltkreissäge gcd']
#
# Precision: 0.125
# Recall: 0.4
# F1-Score: 0.19047619047619047
# ___________________________
# Presseinformation: 2014 0218
# Goldstandard: ['österreich', 'wien', 'tschechien', 'großbritannien', 'türkei', 'deutschland', 'slowakei', 'robert bosch ag', 'universität mannheim', 'universität stuttgart-hohenheim', 'bosch-gruppe', 'klaus peter fouquet', 'klaus huttelmaier', 'wechsel', 'vorstand', 'ruhestand', 'manager']
# Predicted: ['deutschland', 'großbritannien', 'göllnergasse 15-17 mag', 'hallein', 'linz', 'mannheim', 'mittelosteuropa', 'slowakei', 'stuttgart-hohenheim', 'tschechien', 'türkei', 'wien', 'österreich', 'bosch', 'bosch-gruppe', 'robert bosch ag', 'robert bosch gmbh', 'robert bosch ltd', 'angelika kiessling', 'fouquet', 'klaus huttelmaier', 'klaus peter fouquet', 'robert', 'april', 'klaus', 'peter', 'februar', 'wechsel', 'vorstand', 'ruhestand', 'euro']
#
# Precision: 0.45161290322580644
# Recall: 0.8235294117647058
# F1-Score: 0.5833333333333333
# ___________________________
# Presseinformation: 2014 0912
# Goldstandard: ['stuttgart', 'münchen', 'europa', 'berlin', 'bsh', 'siemens ag', 'volkmar denner', 'hausgeräte']
# Predicted: ['europa', 'stuttgart', 'ersten', 'bsh', 'bsh bosch', 'bosch', 'bosch gruppe', 'feinmechanik', 'gmbh', 'robert bosch gmbh', 'robert bosch industrietreuhand kg;', 'robert bosch stiftung gmbh', 'sec', 'siemens', 'siemens ag', 'siemens hausgeräte gmbh', 'stuttgart/münchen', 'venture bsh bosch', 'am gemeinsamen', 'der', 'für', 'und', 'denner', 'raschke', 'robert bosch', 'thomas', 'uta-micaela dürig', 'robert', 'milliarde', 'unternehmen', 'haus', 'euro', 'key', 'milliarden', 'millionen', 'risk', 'information', 'aussage', 'hausgeräte', 'gerät']
#
# Precision: 0.125
# Recall: 0.625
# F1-Score: 0.20833333333333334
# ___________________________
# Presseinformation: 2015 0405
# Goldstandard: ['türkei', 'erenler', 'schwarzmeerküste', 'türk traktör', 'bosell', 'absicherung', 'traktor', 'serie 5000']
# Predicted: ['erenler', 'grasbrunn', 'türkei', 'bosch', 'bosch sicherheitssysteme gmbh', 'türk traktör', 'bosell', 'erika görge', 'april', 'werk', 'traktor', 'werk', 'hersteller', 'traktor', 'absicherung', 'lösung']
#
# Precision: 0.375
# Recall: 0.75
# F1-Score: 0.5
# ___________________________
# Presseinformation: 2015 0908
# Goldstandard: ['nordamerika', 'europa', 'farmington hills', 'michigan', 'usa', 'waiblingen', 'georgia', 'bristol', 'bosch packaging technology', 'kliklok-woodman', 'ampack gmbh', 'osgood industries', 'unternehmen', 'übernahme', 'ausbau']
# Predicted: ['bosch-wachstumsstrategie', 'bristol', 'decatur', 'deutschland', 'farmington', 'stuttgart', 'usa', 'waiblingen', 'und verpackungstechnik', 'ampack', 'ampack gmbh', 'bsh bosch', 'bosch', 'bosch packaging technology', 'bosch-gruppe', 'international', 'osgood industries', 'robert bosch gmbh', 'robert bosch industrietreuhand kg;', 'robert bosch stiftung gmbh', 'siemens hausgeräte gmbh', 'waiblingen – bosch', 'zf lenksysteme gmbh', 'übernahme der', 'christoph zemelka', 'klefenz', 'kliklok-woodman', 'robert bosch', 'technology', 'packaging', 'robert', 'gmbh', 'unternehmen', 'übernahme', 'nahrungsmittel', 'industrie', 'ausbau', 'euro']
#
# Precision: 0.2631578947368421
# Recall: 0.6666666666666666
# F1-Score: 0.3773584905660377
# ___________________________
# Presseinformation: 2016 0501
# Goldstandard: ['abstatt', 'frankfurt am main', 'technischen aufsichtsbehörde hessen', 'bosch engineering gmbh', 'verkehrsgesellschaft frankfurt am main', 'vgf', 'bernhard bihr', 'christoph zemelka', 'sicherheit', 'straßenbahnen', 'unfall', 'beifahrer', 'bahn', 'rail control unit']
# Predicted: ['abstatt/frankfurt', 'frankfurt', 'frankfurt am', 'heilbronn', 'bosch engineering', 'bosch engineering gmbh', 'bosch-gruppe', 'robert bosch gmbh', 'technischen aufsichtsbehörde hessen frankfurt am main', 'vgf', 'der technischen aufsichtsbehörde', '\uf084 bosch', 'bihr', 'christoph zemelka', 'engineering', 'straßenbahnen', 'bahn', 'sicherheit', 'information', 'mai', 'bosch', 'euro', 'system']
#
# Precision: 0.2608695652173913
# Recall: 0.42857142857142855
# F1-Score: 0.3243243243243243
# ___________________________
# Presseinformation: 2016 0922
# Goldstandard: ['karlsruhe', 'escrypt', 'automotive aftermarket', 'automotive service solutions', 'werkstätte', 'dienstleistung', 'betreuung', 'service', 'fahrzeug']
# Predicted: ['karlsruhe', 'autocrew', 'bosch', 'bosch-gruppe', 'escrypt', 'robert bosch gmbh', 'robert bosch gmbh automotive aftermarket', 'christoph zemelka', 'heiderose dreiner', 'werkstätte', 'betreiber', 'stand', 'zeit', 'information', 'dienstleistung', 'betreuung', 'verarbeitung', 'september', 'euro', 'datum']
#
# Precision: 0.25
# Recall: 0.5555555555555556
# F1-Score: 0.3448275862068966
# ___________________________
# Presseinformation: 2017 0303
# Goldstandard: ['karlsruhe', 'boxberg', 'böblingen', 'motorworld stuttgart', 'bosch classic', 'bosch oldtimer schrauber e.v.', 'bosch fotogruppe', 'automotive aftermarket', 'automotive service solutions', 'bosch boxberg', 'rallye', 'bosch boxberg klassik rallye', 'bosch boxberg klassik']
# Predicted: ['böblingen', 'karlsruhe', 'autocrew', 'bosch', 'bosch boxberg', 'bosch classic', 'bosch oldtimer schrauber e.v', 'bosch-gruppe', 'bosch-prüfzentrum boxberg', 'internet der dinge', 'jahre bremse', 'motorworld stuttgart', 'robert bosch gmbh', 'christoph zemelka', 'juni', 'märz', 'höhepunkt', 'oldtimer', 'freund', 'information', 'robert', 'lösung', 'bosch boxberg klassik', 'euro', 'jahre', 'klassik', 'rallye', 'von', 'telefon', 'fahrzeug', 'bremse']
#
# Precision: 0.22580645161290322
# Recall: 0.5384615384615384
# F1-Score: 0.3181818181818182
# ___________________________
# Presseinformation: 2018 0204
# Goldstandard: ['christoph kübel', 'kerstin mai', 'fahrrad-leasing', 'mitarbeiter', 'gesundheit', 'sport', 'stadt', 'verkehrsmittel', 'fahrrad', 'ebikes']
# Predicted: ['deutschland', 'deutschland.', 'stuttgart', 'bosch', 'bosch-gruppe', 'internet der dinge', 'mk/kb', 'robert bosch gmbh', 'robert bosch industrietreuhand kg;', 'robert bosch stiftung gmbh', 'and', 'christoph zemelka', 'konzernbetriebsratsvorsitzende', 'mitarbeiter', 'robert bosch', 'robert', 'gmbh', 'förderung', 'angebot', 'personal', 'chef', 'unternehmen', 'euro', 'fahrrad']
#
# Precision: 0.08333333333333333
# Recall: 0.2
# F1-Score: 0.11764705882352941
# ___________________________
# Presseinformation: 2019 0501
# Goldstandard: ['karlsruhe', 'plochingen', 'europa', 'automotive aftermarket', 'online', 'computer aided service', 'esitronic', 'festplatte']
# Predicted: ['karlsruhe', 'mit', 'affairs', 'autocrew', 'automotive aftermarket', 'bosch', 'bosch-gruppe', 'communications', 'esitronic robert bosch gmbh', 'governmental', 'internet der dinge', 'robert bosch gmbh', 'von', 'christof ehrhart', 'nico krespach', 'online', 'information', 'mai', 'werkstatt', 'zugang', 'online', 'esitronic 2.0 online', 'euro', 'datum', 'software', 'version', 'festplatte', 'computer aided']
#
# Precision: 0.14285714285714285
# Recall: 0.5
# F1-Score: 0.22222222222222224
# ___________________________
# Presseinformation: 2019 1103
# Goldstandard: ['stuttgart', 'nevonex', 'andrew allen', 'landwirtschaft', 'effizienz', 'automatisierung', 'vernetzung', 'landwirt', 'agritechnica innovation award', 'service', 'nevonex']
# Predicted: ['europa', 'lateinamerika', 'stuttgart', 'agritechnica', 'agritechnica innovation award', 'bosch', 'bosch-gruppe', 'corporate', 'internet der dinge', 'robert bosch gmbh', 'robert bosch industrietreuhand kg;', 'robert bosch stiftung gmbh', 'services robert bosch gmbh', 'xarvio', 'zg raiffeisen', 'andrew', 'christof ehrhart', 'robert bosch', 'robert', 'landwirtschaft', 'land', 'wirtschaft', 'service', 'automatisierung', 'arbeits', 'ablauf', 'vernetzung', 'unternehmen', 'euro', 'nevonex powered by', 'effizienz', 'gerät']
#
# Precision: 0.21875
# Recall: 0.6363636363636364
# F1-Score: 0.3255813953488372
# ___________________________
# 0.1332726534411919 0.35496610985223315 0.18551829036975687

# %%
print("Standard Deviation of Precision/Products is ", np.std(all_thema_precision))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-70805e666a1c> in <module>
# ----> 1 print("Standard Deviation of Precision/Products is ", np.std(all_thema_precision))
#
# NameError: name 'all_thema_precision' is not defined

# %% [markdown]
# ###
