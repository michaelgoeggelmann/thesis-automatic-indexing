# %%
import pandas as pd
import os
from spacy.lemmatizer import Lemmatizer, ADJ, NOUN, VERB
import spacy
import numpy as np
import distance

# %%
def precision(y_true, y_pred):
    i = set()
    len1 = len(y_pred)
    for pred in y_pred:
        for true in y_true:
            if pred == true:
                i.add(pred)
                break
            if len(list(distance.lcsubstrings(pred, true))) != 0:
                anteil = len(list(distance.lcsubstrings(pred, true))[0])/len(true)
                if anteil > 0.3:
                    i.add(pred)
    if len1 == 0:
        return 0.0
    elif float(len(i) / len1) > 1:
        return 1.0
    else:
        return float(len(i) / len1)


def recall(y_true, y_pred):
    i = set()
    if len(y_true) == 0:
        return 0.0
    else:
        for pred in y_pred:
            for true in y_true:
                if pred == true:
                    i.add(pred)
                    break
                if len(list(distance.lcsubstrings(pred, true))) != 0:
                    anteil = len(list(distance.lcsubstrings(pred, true))[0])/len(true)
                    if anteil > 0.3:
                        i.add(pred)
        if float(len(i) / len(y_true)) > 1:
            return 1.0
        else:
            return float(len(i) / len(y_true))


def f1(y_true, y_pred):
    p = precision(y_true, y_pred)
    r = recall(y_true, y_pred)
    if p + r == 0:
        return 0.0
    else:
        return 2 * (p * r) / (p + r)
    
def get_PI(filename):
    getFilename = os.path.basename(filename)
    filename, ext = getFilename.split(".")
    if "_" in filename:
        filename, rest = filename.split("_", 1)
    return filename

# %%
os.chdir(r"C:\Users\Goegg\OneDrive\Desktop\Durchgänge")

# %%
# create df out of goldstandard
goldstandard = pd.ExcelFile(r"GOLDSTANDARD.xlsx")
# choose model-combinations for predictions:
directory = r"7. YAKE - SPACY NE\MI_Schlagworte_Composed"
extension = ".xlsx"
nlp = spacy.load("de_core_news_lg")
lemmatizer = nlp.vocab.morphology.lemmatizer

# %%
#Geographischer Index

all_geo_precision = []
all_geo_recall = []
all_geo_f1 = []
for filename in os.listdir(r"C:\Users\Goegg\OneDrive\Desktop\zu annotieren"):
    
    pi_name = get_PI(filename)
    print("Presseinformation:", pi_name)
    #get geo-pred
    df_pred = pd.read_excel(os.path.join(directory, pi_name + extension), header=0)
    pred_geo_out = df_pred['Geographischer Index:'].tolist()
    pred_geo = [x for x in pred_geo_out if x == x]
    #get geo-gold
    df_gold = pd.read_excel(goldstandard, pi_name)
    gold_geo_out = df_gold['Geographischer Index'].tolist()
    gold_geo = [lemmatizer(x, NOUN)[0].lower() for x in gold_geo_out if x == x]
    print("Goldstandard:", gold_geo)
    print("Predicted:", pred_geo, "\n")
    if len(gold_geo) == 0 and len(pred_geo) == 0:
        print("both nothing\n __________________________")
        all_geo_precision.append(1.0)
        all_geo_recall.append(1.0)
        all_geo_f1.append(1.0)
        continue
    else:
        print("Precision:", precision(gold_geo, pred_geo))
        print("Recall:", recall(gold_geo, pred_geo))
        print("F1-Score:", f1(gold_geo, pred_geo), "\n___________________________")
        all_geo_precision.append(precision(gold_geo, pred_geo))
        all_geo_recall.append(recall(gold_geo, pred_geo))
        all_geo_f1.append(f1(gold_geo, pred_geo))
        
mean_geo_precision = sum(all_geo_precision) / len(all_geo_precision)
mean_geo_recall = sum(all_geo_recall) / len(all_geo_recall)
mean_geo_f1 = sum(all_geo_f1) / len(all_geo_f1)    
print(mean_geo_precision, mean_geo_recall, mean_geo_f1)
# Out:
# Presseinformation: 2000 0310
# Goldstandard: []
# Predicted: ['stuttgart', 'technikpresse']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2000 0702
# Goldstandard: ['backnang']
# Predicted: ['zöw', 'backnang', 'stripline', 'aui', 'bnsismaterialien', 'dielektrikumsznhlen', 'zwei-oder', 'standardoberflächen', 'a 11', 'poatfach', 'stuttgart', 'borm1nn', 'kru••', 'stalb', 'sn60pb', 'indium', 'alumini•']
#
# Precision: 0.058823529411764705
# Recall: 1.0
# F1-Score: 0.1111111111111111
# ___________________________
# Presseinformation: 2000 1009
# Goldstandard: []
# Predicted: ['zöw', 'bosch-platln', 'zundkerzen', 'oper', 'ma.iseelektrode', 'journalisten-rückfragen', 'u.-malte', 'd-70049 stuttgart', 'oflentlichkeitoarbi', 'bosch-platin-zündkerzen', 'stuttgart', 'technikpresse']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2001 0350
# Goldstandard: ['genf']
# Predicted: ['bosch-silver-plus', 'rückzündungen', 'europa']
#
# Precision: 0.3333333333333333
# Recall: 1.0
# F1-Score: 0.5
# ___________________________
# Presseinformation: 2001 0909
# Goldstandard: ['ravensburg']
# Predicted: ['ravensburg', 'gebiet hammerbohren', 'hammerbohrer', 'spannungswellen', 'hauptschneiden', 'anwendertests', 'lieferprogramms', 'diamant-bohrkronen', 'durchmes', 'diamant-segmente', 'm-tech', 'heavy-duty-sägeblätter', 'bimetall-zahnleiste', 'heavy-duty-karat', 'demolition-sägeblätter', 'hawera-programm', 'superfine']
#
# Precision: 0.058823529411764705
# Recall: 1.0
# F1-Score: 0.1111111111111111
# ___________________________
# Presseinformation: 2002 0114
# Goldstandard: ['hildesheim', 'miskolc', 'stuttgart-feuerbach', 'wemerstraße']
# Predicted: ['köln', 'stuttgart', 'obertürkheim', 'deutschland', 'usa', 'nürnberg', 'magdeburg', 'gewürge', 'wemerstraße', 'stuttgart-feuerbach', 'deutzer', 'engländer', 'england', 'frankreich', 'jahrhundertwechsel', 'hinterhofwerkstätten', 'stuttgarter hoppenlau-friedhofs', 'stahlbeton-bauweise', 'erjedoch', 'den usa', 'paris', 'main', 'kummer', 'springfield', 'neckarkanals', 'stadt stuttgart', 'robert-bosch-krankenhaus', 'detroit', 'ideal-werken', 'europa', 'dessau', 'bosch-kühlschrank', 'untertürkheim', 'schweröl-motor', 'feuerbacher', 'ulm', 'britischen militärregierung', 'bundesrepublik deutschland', 'amerikanische militärregierung', 'wernerstraße', 'staat israel', 'bundesrepublik', 'kontaktlose transistorzündung', 'lambda-sonde', 'modem', 'the proximity to obertürkheim', 'time', 'nuremberg', 'his travelling apprenticeship', 'this field', 'this direction', 'autumn', 'retrospect', 'telefon+49', 'wernerstraße 1', 'ofthe', 'france', 'the west of stuttgart', 'hoppenlau cemetery', 'the building', 'neighbouring houses', 'building it of sandstone', 'generated by a spark', 'germany south ofthe river main', 'ousting  his nephews from the company and', 'the usa', 'springfield had passed into  american hands but even the name', 'the stuttgart', 'thc', 'archives telefax+49', 'page6', 'which had already introduced assembly lines for manufacturing its', 'avoiding lay-offs', 'some', 'the stuttgart suburb of untertürkheim', 'the field ofeine', 'wemerstraße 1', 'gemiany', 'stuttgart and feuerbach', 'february', 'the soviet-occupied zone were lost for good', 'having  him released from', 'october', 'vehicle-repair', 'the federal republic', 'and around  which the labour market', 'too', 'düsseldorf', 'germany gennany']
#
# Precision: 0.1797752808988764
# Recall: 1.0
# F1-Score: 0.30476190476190473
# ___________________________
# Presseinformation: 2002 0403
# Goldstandard: []
# Predicted: ['bremsen-check', 'bremsenprüfstand', 'd-70049 stuttgart']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2002 0710
# Goldstandard: ['abstatt', 'heilbronn']
# Predicted: ['abstan', 'heilbronn', 'etappenziels', 'abstull', 'stuttgarl telefax', 'zöw-lo', 'zvw  ', 'abstau', 'abstatt', 'automobil-zuliefererbranche']
#
# Precision: 0.5
# Recall: 1.0
# F1-Score: 0.6666666666666666
# ___________________________
# Presseinformation: 2002 1008
# Goldstandard: []
# Predicted: ['gas-heizungen', 'warmwasserbereitern', 'komfortwünsche', 'staat', 'junkers-lösungen', 'tt wü', 'infocenter', 'heizungsbranche', 'junkers-spezialisten', 'junkers-website', 'produktkonfigurators', 'wernau', 'regionaltarif', 'junkers-pressebild nr.']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2003 0212
# Goldstandard: []
# Predicted: ['d-70049 stuttgart', 'sägeschnitte', 'aluminiumsohle']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2003 0512
# Goldstandard: []
# Predicted: ['aa wü', 'au     ', 'bosch-zündkerzen', 'chrom-nickel-masseelektrode', 'alu-zylinderköpfen']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2003 0811
# Goldstandard: []
# Predicted: ['sds-plus-flachmeißel von bosch', 'durchbrucharbeiten', 'meißel']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2003 1203
# Goldstandard: []
# Predicted: ['eazeo-monitor', 'verdächtiges', 'eazeo', 'd-70049 stuttgart', 'journalisten-rückfragen']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2004 0317
# Goldstandard: []
# Predicted: ['mtt schwertlängen']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2004 0615
# Goldstandard: []
# Predicted: ['wärmeblock', 'brenner', 'gas-brennwertgeräte cerasmart', 'brenneroberfläche', 'prinzipbedingt', 'info-dienst', 'regionaltarif', 'wernau']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2004 0951
# Goldstandard: []
# Predicted: ['prüfablauf', 'esitronic', 'mehrmarken-werkstatt', 'u.-malte wünsch', 'tel']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2005 0112
# Goldstandard: ['stuttgart']
# Predicted: ['stuttgart', 'max-planck-forschungsinstitut']
#
# Precision: 1.0
# Recall: 1.0
# F1-Score: 1.0
# ___________________________
# Presseinformation: 2005 0607
# Goldstandard: []
# Predicted: ['autodome-kameras', 'biphase', 'bilinx-schnittstellen', 'cctv-anlagen', 'stuttgart']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2005 0951
# Goldstandard: ['berlin', 'frankfurt am main']
# Predicted: ['handheld-format']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2006 0307
# Goldstandard: []
# Predicted: ['stuttgart']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2006 0911
# Goldstandard: []
# Predicted: ['d-70049 stuttgart', 'standard-sägeblätter', 'stuttgart']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2007 0307
# Goldstandard: []
# Predicted: ['gesundheitsbewusst', 'winkelschleifern', 'd-70049 stuttgart', 'vibrationsbelastungswert', 'meißel', 'stuttgart']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2007 1001
# Goldstandard: []
# Predicted: ['deutschland', 'shop-kategorien', 'stuttgart']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2008 0318
# Goldstandard: []
# Predicted: ['d-70049 stuttgart', 'stuttgart']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2008 1101
# Goldstandard: ['brüssel', 'europa']
# Predicted: ['europa', 'd-70049 stuttgart', 'stuttgart']
#
# Precision: 0.3333333333333333
# Recall: 0.5
# F1-Score: 0.4
# ___________________________
# Presseinformation: 2009 0419
# Goldstandard: []
# Predicted: ['niesen', 'luftsog', 'vordermannes', 'd-76225 karlsruhe telefax', 'stuttgart']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2009 1004
# Goldstandard: ['südafrika', 'kapstadt', 'johannesburg', 'stuttgart']
# Predicted: ['südafrika', 'kapstadt', 'johannesburg', 'stuttgart', 'afrikanischen kontinent', 'waiblingen', 'land']
#
# Precision: 0.7142857142857143
# Recall: 1.0
# F1-Score: 0.8333333333333333
# ___________________________
# Presseinformation: 2010 0701
# Goldstandard: ['stuttgart', 'deutschland', 'grasbrunn']
# Predicted: ['d-70049 stuttgart', 'stuttgart']
#
# Precision: 1.0
# Recall: 0.6666666666666666
# F1-Score: 0.8
# ___________________________
# Presseinformation: 2010 1019
# Goldstandard: ['schweiz', 'st. niklaus', 'zermatt']
# Predicted: ['bosch-zubehör', 'diamant-riffsägeblatt', 'diamant-riffverbund', 'd-70049 stuttgart', 'isolationsmaterialien', 'bosch-fertigungswerk', 'st. niklaus bei zermatt', 'schweiz', 'stuttgart']
#
# Precision: 0.6666666666666666
# Recall: 1.0
# F1-Score: 0.8
# ___________________________
# Presseinformation: 2011 0326
# Goldstandard: ['deutschland']
# Predicted: ['deutschland', 'stuttgart', 'europa', 'd-70049 stuttgart', 'berlin']
#
# Precision: 0.2
# Recall: 1.0
# F1-Score: 0.33333333333333337
# ___________________________
# Presseinformation: 2011 0807
# Goldstandard: ['detmold']
# Predicted: ['detmold', 'dornrad-paketieranlagen', 'd-70049 stuttgart', 'dornrades', 'rüttelstrecke', 'transportbecher', 'waiblingen', 'stuttgart']
#
# Precision: 0.125
# Recall: 1.0
# F1-Score: 0.2222222222222222
# ___________________________
# Presseinformation: 2012 0113
# Goldstandard: []
# Predicted: ['mems-sensormarkt', 'sensordatenfusion', 'd-70049 stuttgart']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2012 0808
# Goldstandard: []
# Predicted: ['d-70049 stuttgart', 'bosch-kraftfahrzeugtechnik']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2013 0201
# Goldstandard: []
# Predicted: ['d-70049 stuttgart', 'autolock-schnellspann-bohrfutter', 'multischleifer']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2013 0618
# Goldstandard: ['berlin', 'europa', 'südeuropa']
# Predicted: ['berlin', 'europa', 'd-70049 stuttgart', 'deutschlandforum', 'stuttgart']
#
# Precision: 0.6
# Recall: 1.0
# F1-Score: 0.7499999999999999
# ___________________________
# Presseinformation: 2013 0947
# Goldstandard: []
# Predicted: ['d-70049 stuttgart', 'bosch-zubehörprogramm']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2014 0218
# Goldstandard: ['österreich', 'wien', 'tschechien', 'großbritannien', 'türkei', 'deutschland', 'slowakei']
# Predicted: ['österreich', 'dipl.oec', 'wien', 'tschechien', 'slowakei', 'großbritannien', 'deutschland', 'türkei', 'linz', 'hallein']
#
# Precision: 0.8
# Recall: 1.0
# F1-Score: 0.888888888888889
# ___________________________
# Presseinformation: 2014 0912
# Goldstandard: ['stuttgart', 'münchen', 'europa', 'berlin']
# Predicted: ['stuttgart', 'münchen', 'd-70049 stuttgart', 'europa', 'berlin']
#
# Precision: 1.0
# Recall: 1.0
# F1-Score: 1.0
# ___________________________
# Presseinformation: 2015 0405
# Goldstandard: ['türkei', 'erenler', 'schwarzmeerküste']
# Predicted: ['türkei', 'erenler', 'schwarzmeerküste', 'grasbrunn tel']
#
# Precision: 0.75
# Recall: 1.0
# F1-Score: 0.8571428571428571
# ___________________________
# Presseinformation: 2015 0908
# Goldstandard: ['nordamerika', 'europa', 'farmington hills', 'michigan', 'usa', 'waiblingen', 'georgia', 'bristol']
# Predicted: ['nordamerika', 'europa', 'farmington hills', 'michigan', 'usa', 'waiblingen', 'decatur', 'georgia', 'bristol', 'd-70049 stuttgart', 'kartonier', 'verschließmaschinen', 'deutschland', 'den usa', 'stuttgart', 'land']
#
# Precision: 1.0
# Recall: 1.0
# F1-Score: 1.0
# ___________________________
# Presseinformation: 2016 0501
# Goldstandard: ['abstatt', 'frankfurt am main']
# Predicted: ['abstatt', 'frankfurt', 'tramfahrer', 'videosensor', 'radarsensor', 'prellböcke', 'heilbronn', 'frankfurt am main', 'www.twitter/vgf_ffm']
#
# Precision: 0.3333333333333333
# Recall: 1.0
# F1-Score: 0.5
# ___________________________
# Presseinformation: 2016 0922
# Goldstandard: ['karlsruhe']
# Predicted: ['bosch-cloud']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2017 0303
# Goldstandard: ['karlsruhe', 'boxberg', 'böblingen']
# Predicted: ['boxberg', 'böblingen', 'bosch-prüfzentrum boxberg']
#
# Precision: 1.0
# Recall: 1.0
# F1-Score: 1.0
# ___________________________
# Presseinformation: 2018 0204
# Goldstandard: []
# Predicted: ['stuttgart', 'deutschland', 'd-70049 stuttgart', 'schnellstes', 'bundeshaushaltsbudgets', 'pendler']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2019 0501
# Goldstandard: ['karlsruhe', 'plochingen', 'europa']
# Predicted: ['fiat-fahrzeugen', 'security gateway', 'plochingen', 'online-sicherheitszertifikat', 'europa', 'esitronic-abonnenten']
#
# Precision: 0.8333333333333334
# Recall: 1.0
# F1-Score: 0.9090909090909091
# ___________________________
# Presseinformation: 2019 1103
# Goldstandard: ['stuttgart']
# Predicted: ['stuttgart', 'd-70049 stuttgart', 'europa', 'c10', 'ökosystem-ansatz']
#
# Precision: 0.4
# Recall: 1.0
# F1-Score: 0.5714285714285715
# ___________________________
# 0.25840669682626355 0.4384057971014492 0.29476284584980234

# %%
#Körperschaftsindex

all_org_precision = []
all_org_recall = []
all_org_f1 = []
for filename in os.listdir(r"C:\Users\Goegg\OneDrive\Desktop\zu annotieren"):
    
    pi_name = get_PI(filename)
    print("Presseinformation:", pi_name)
    #get org-pred
    df_pred = pd.read_excel(os.path.join(directory, pi_name + extension), header=0)
    pred_org_out = df_pred['Körperschaftsindex:'].tolist()
    pred_org = [x for x in pred_org_out if x == x]
    #get org-gold
    df_gold = pd.read_excel(goldstandard, pi_name)
    gold_org_out = df_gold['Körperschaftsindex'].tolist()
    gold_org = [lemmatizer(x, NOUN)[0].lower() for x in gold_org_out if x == x]
    print("Goldstandard:", gold_org)
    print("Predicted:", pred_org, "\n")
    if len(gold_org) == 0 and len(pred_org) == 0:
        print("both nothing\n __________________________")
        all_org_precision.append(1.0)
        all_org_recall.append(1.0)
        all_org_f1.append(1.0)
        continue
    else:
        print("Precision:", precision(gold_org, pred_org))
        print("Recall:", recall(gold_org, pred_org))
        print("F1-Score:", f1(gold_org, pred_org), "\n___________________________")
        all_org_precision.append(precision(gold_org, pred_org))
        all_org_recall.append(recall(gold_org, pred_org))
        all_org_f1.append(f1(gold_org, pred_org))
        
mean_org_precision = sum(all_org_precision) / len(all_org_precision)
mean_org_recall = sum(all_org_recall) / len(all_org_recall)
mean_org_f1 = sum(all_org_f1) / len(all_org_f1)    
print(mean_org_precision, mean_org_recall, mean_org_f1)
# Out:
# Presseinformation: 2000 0310
# Goldstandard: []
# Predicted: ['robert bosch gmbh', 'bosch', 'rtf-datei', 'ttl']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2000 0702
# Goldstandard: []
# Predicted: ['robert', 'zöt', 'zoef', 'bosch-produktbereich raumfahrttechnik', 'mikrowelllen-streifen', 'bosch', 'iwei microvia', 'zot', 'zof', 'robert bosch', 'vda', 'din', 'esa', 'qnes', 'fur kundemmfrngen']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2000 1009
# Goldstandard: ['daimler-chrysler', 'audi', 'bmw', 'cadillac', 'citroen', 'daewoo', 'fiat', 'lancia', 'mitsubishi', 'opel', 'peugeot', 'porsche', 'renault', 'suzuki', 'vauxhall', 'volvo', 'vw']
# Predicted: ['robert', 'zöt', 'zoef', 'mercedes', 'daimler-chrysler', 'elus1izität', 'bosch', 'audi', 'bmw', 'cadillac', 'citroen', 'daewoo', 'fiat', 'lancia', 'mitsubishi', 'opel', 'peugeot', 'porsche', 'renault', 'seal', 'skodn', 'ssangyong', 'suzuki', 'vauxhall', 'volvo', 'aobert boact', 'seat', 'skoda', 'rtf-datei']
#
# Precision: 0.8620689655172413
# Recall: 1.0
# F1-Score: 0.9259259259259259
# ___________________________
# Presseinformation: 2001 0350
# Goldstandard: ['blaupunkt']
# Predicted: ['bosch']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2001 0909
# Goldstandard: ['hawera probst gmbh']
# Predicted: ['haweraschutzrechte', 'hawera probst gmbh', 'd-88212 ravensburg telefax', 'presseforum', 's4-bohrer', 'bohrdurchmessern', 'bosch', 'hss-spiralbohrer', 'heavy duty', 'demolition']
#
# Precision: 0.2
# Recall: 1.0
# F1-Score: 0.33333333333333337
# ___________________________
# Presseinformation: 2002 0114
# Goldstandard: []
# Predicted: ['bosch', '75b', 'technischen hochschule stuttgart', 'robert bosch gmbh telefax', 'daimler motorengesellschaft', 'stuttgarter firma', 'stuttgarter unternehmens', 'bernhardsche', 'walz', 'aufdie', 'technische hochschule stuttgart', 'vermögensverwaltung bosch', 'firmenanteilen boschs', 'robert-bosch-stiftung', 'ford', 'blaupunkt-werke', 'blaupunkt', 'fernseh a.g.', 'flugzeugproduktion', 'kinogerätefabrik bugen bauer', 'bosch-horn', 'dieseleinspritzpumpen', 'haus bosch', 'nazi', 'stuttgarter ns-potentaten', 'partei', 'waffen-ss', 'ss-hauptamtes', 'aufdas', 'ss-mannes berger', 'bosch-werke', 'robert bosch gmbh', 'kriegsfinanziers', 'zeit des nationalsozialismus', 'bosch-gruppe', 'robert bosch stiftung', 'robert bosch gmbh.', 'robert bosch industriebeteiligung gmbh', 'robert bosch industrietreuhand kg', 'hause bosch', 'verkehrsinformationssystem ari', 'asr', 'litronic scheinwerfersystem', 'esp', 'common rail hochdruck-dieseleinspritzung', 'industrietreuhand kg', 'boschgruppe', 'mannesmann ag', 'allianz -versicherungs ag', 'the 25year old mechanic had spent scveral months thinking about the location and purpose ofhis', 'originally', 'cologne would have appeared tobe a good location for the new company', 'where his fiancee', 'what appears certain', 'is that robert bosch had for some years wished to establish', 'independent business at  some point', 'this is indicated', 'during his  years oftravel around germany and the usa', 'the last stop', 'and robert bosch dreamed of  estabhshing', 'independent existence by founding a lamp factory with his friend and future', 'while bosch', 'established a workshop in the  west', 'cigar-tip cutters', 'cameras with wooden housings', 'a typewriter for blind  people and similar curious articles', "electrifying stuttgart's houses", 'like many other bosch products ofthose years', 'electrical engineering companies', 'the magneto ignition business', 'at the end of the century but even to put a little money aside for  a rainy day  ', 'he and his staff had scored another big coup', 'at the instigation', 'able to test his  ignition device', 'employing a staff of  over forty', 'and the rented accommodation', 'small backyard', 'robert bosch elektrotechnische fabrik', 'saw the market  introduction ofthe bosch', 'that business', 'all important automobile manufacturers ofthe day were now customers ofthe stuttgart company', 'founded', 'followcd by another in the usa', 'dynamo', 'regulator cut-out and battery -supplemented by', 'incurable disease to which young robert bosch succumbed', 'this affair', 'the socialist and pioneer figure', 'the  feminist movement', 'increasingly burdened by the need to care for', 'the eight-hour working day', 'this', 'followed', 'many ofthe symptoms which  bosch describes', 'friends and acquaintances  would seem tobe', 'at the company', 'supported by competent directors without whom the rise', 'the directors', "bosch accepted his nephew's", "bosch's death", 'the directors were tobe given the opportunity ofacquiring', 'that the directors would then hold', 'the structure ofthis joint-stock company', 'however', 'quickly exhibited a fatal flaw', 'bosch recovered his health', 'within the company', 'the joint-stock company paid no dividend for a longish', 'bosch had  pointed out this possible disadvantage when the joint-stock company', 'but had not  been able', 'due to his illness', 'here robert bosch', 'supported  mainly by his private secretary and closest', 'the', 'expropriated by the  victorious', 'since starting up his business', 'had always insisted on the highest  quality standards for his products', 'the company', 'fortunate enough to secure the scrvices of the  well-known advertising', 'trade mark ofthe company', 'the company succeeded', 'the  company', 'bosch exercised his influence over the company', 'whose sole', 'a german gmbh', 'order  to protect it as far as possible from outside influences and to retain his independence', 'as he  repeatedly emphasized even', 'rober ...
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2002 0403
# Goldstandard: ['gesellschaft für technische überwachung']
# Predicted: ['presse-information', 'gesellschaft für technische  überwachung', 'gtü', 'bosch', 'bremsregelsysteme', 'robert bosch gmbh']
#
# Precision: 0.16666666666666666
# Recall: 1.0
# F1-Score: 0.2857142857142857
# ___________________________
# Presseinformation: 2002 0710
# Goldstandard: ['assel gmbh']
# Predicted: ['robert', 'zoef', 'robert bosch gmbh', 'bosch', 'sensotronic brake', 'esp', 'assel gmbh', 'roberl bosch gmbh marlln', 'zör', 'preaseforum', 'darun', 'bosch rexroth', 'bosch-gruppe', 'boschgeschäftsbereichen']
#
# Precision: 0.21428571428571427
# Recall: 1.0
# F1-Score: 0.35294117647058826
# ___________________________
# Presseinformation: 2002 1008
# Goldstandard: ['junker']
# Predicted: ['presse-information', 'junker', 'bosch-thermotechnik', 'bosch thermotechnik', 'robert bosch gmbh']
#
# Precision: 0.8
# Recall: 1.0
# F1-Score: 0.888888888888889
# ___________________________
# Presseinformation: 2003 0212
# Goldstandard: ['skil']
# Predicted: ['presse-information', 'skil']
#
# Precision: 0.5
# Recall: 1.0
# F1-Score: 0.6666666666666666
# ___________________________
# Presseinformation: 2003 0512
# Goldstandard: []
# Predicted: ['bosch', 'zündkerzen-know-how', 'robert bosch gmbh', 'd-70049 stuttgart']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2003 0811
# Goldstandard: []
# Predicted: ['bosch', 'robert bosch gmbh', 'd-70049 stuttgart']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2003 1203
# Goldstandard: []
# Predicted: ['bosch', 'digital-videoüberwachungssystem eazeo', 'robert bosch gmbh', 'bosch pressebild nr.']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2004 0317
# Goldstandard: []
# Predicted: ['zoef', 'schmidt beate', 'gke', 'bce', 'bce professional', 'bosch', 'constant electronic', 'sos-systems', 'bosch-pressemeldung']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2004 0615
# Goldstandard: ['junkers/bosch-thermotechnik']
# Predicted: ['heizgeräteherstel ler', 'junker', 'bosch-thermotechnik', 'wärmeübertragern', 'wärmeübertragers', 'alsi wärmeübertragers', 'robert bosch gmbh', 'uta-micaela dürig', 'd-70049 stuttgart', 'junkers info-dienst']
#
# Precision: 0.1
# Recall: 1.0
# F1-Score: 0.18181818181818182
# ___________________________
# Presseinformation: 2004 0951
# Goldstandard: []
# Predicted: ['fsa', 'bosch', 'fahrzeug-system-analyse fsa', 'fsa-720-messmodul', 'kts', 'robert bosch gmbh', 'uta-micaela dürig', 'd-70049 stuttgart', 'werkstatt-pc', 'fsa-systeme', 'werkstattsoftware esitronic von bosch', 'automotive aftermarket']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2005 0112
# Goldstandard: ['car multimedia', 'bosch rexroth', 'max-planck-forschungsinstitut', 'bosch-gruppe']
# Predicted: ['robert bosch', 'car multimedia', 'bosch rexroth', 'zentralbereiche forschung', 'universität stuttgart', 'bosch-gruppe', 'robert bosch gmbh']
#
# Precision: 0.8571428571428571
# Recall: 1.0
# F1-Score: 0.923076923076923
# ___________________________
# Presseinformation: 2005 0607
# Goldstandard: ['bosch sicherheitssysteme']
# Predicted: ['presse-information', 'bosch', 'tag-nacht-kameramodul', 'd-70049 stuttgart', 'bosch-gruppe', 'firmengr', 'robert bosch gmbh', 'robert bosch stiftung', 'robert bosch industrietreuhand']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2005 0951
# Goldstandard: ['blaupunkt']
# Predicted: ['fsa', 'bosch', 'leichtes handheld-gerät', 'fahrzeug-system-analyse fsa', 'werkstatt-pc', 'corporate communications', 'uta-micaela dürig', 'd-70049 stuttgart', 'automotive aftermarket']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2006 0307
# Goldstandard: ['mercedes-benz', 'siemens vdo', 'bmw']
# Predicted: ['bosch', 'siemens vdo', 'di-motronic', 'magnetventilen   ', 'uta-micaela dürig', 'd-70049 stuttgart', 'bmw', 'psa', 'bosch-gruppe', 'robert  bosch gmbh', 'robert bosch stiftung', 'robert bosch industrietreuhand kg']
#
# Precision: 0.8333333333333334
# Recall: 1.0
# F1-Score: 0.9090909090909091
# ___________________________
# Presseinformation: 2006 0911
# Goldstandard: []
# Predicted: ['presse-information', 'bosch', 'lasermodul', 'robert bosch gmbh', 'd-70745 leinfelden-echterdingen', 'bosch-gruppe', 'robert bosch stiftung', 'robert bosch industrietreuhand kg']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2007 0307
# Goldstandard: []
# Predicted: ['bosch', 'schlaghämmer', 'meißelhämmern', 'robert bosch gmbh', 'dämpfungselement', 'gbh', 'eu-richtlinie', 'd-70745 leinfelden-echterdingen', 'bosch-gruppe', 'robert bosch stiftung', 'robert bosch industrietreuhand kg']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2007 1001
# Goldstandard: ['bosch klassik teilevermittlung', 'bosch automotive tradition', 'ebay']
# Predicted: ['presse-information', 'neuer ebay-shop', 'bosch', 'bosch automotive', 'ebay', 'tns infratest automotive', 'ebay-shop', 'old', 'robert bosch gmbh', 'd-76227 karlsruhe telefax', 'robert bosch gmbh automotive aftermarket', 'bosch-gruppe', 'robert bosch stiftung', 'robert bosch industrietreuhand kg', 'familie bosch', 'robert bosch gmbh.']
#
# Precision: 0.375
# Recall: 1.0
# F1-Score: 0.5454545454545454
# ___________________________
# Presseinformation: 2008 0318
# Goldstandard: ['bosch sicherheitssysteme']
# Predicted: ['bosch', 'bosch sicherheitssysteme', 'robert bosch gmbh', 'bosch sicherheitssysteme gmbh', 'bosch-gruppe', 'robert bosch stiftung', 'robert bosch industrietreuhand kg', 'familie bosch', 'robert bosch gmbh.']
#
# Precision: 0.2222222222222222
# Recall: 1.0
# F1-Score: 0.3636363636363636
# ___________________________
# Presseinformation: 2008 1101
# Goldstandard: ['esafety-award-komitee', 'fia', 'esafety']
# Predicted: ['bosch', 'eu-kommissarin', 'bosch-unternehmensbereichs kraftfahrzeugtechnik', 'automobilweltverbands fia', 'europäischen kommission', 'esafety', 'robert bosch gmbh', 'elektronische stabilitäts-programm', 'universität köln', 'bosch-gruppe', 'robert bosch stiftung', 'robert bosch industrietreuhand kg', 'familie bosch', 'robert bosch gmbh.']
#
# Precision: 0.7142857142857143
# Recall: 1.0
# F1-Score: 0.8333333333333333
# ___________________________
# Presseinformation: 2009 0419
# Goldstandard: []
# Predicted: ['aktivkohle-innenraumfilter', 'bosch', 'kfz-teile-handel', 'bosch-aktivkohle-innenraumfilter', 'robert bosch gmbh automotive aftermarket', 'bosch-gruppe', 'robert bosch gmbh', 'robert bosch stiftung', 'robert bosch industrietreuhand kg', 'familie bosch', 'robert bosch gmbh.']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2009 1004
# Goldstandard: ['bosch packaging technology', 'propak']
# Predicted: ['propak afrika', 'bosch', 'bosch packaging technology', 'lokales servicenetz', 'bosch-gruppe', 'robert bosch gmbh', 'd-70049 stuttgart', 'bosch packaging technology bosch packaging technology', 'robert bosch stiftung', 'robert bosch industrietreuhand kg', 'familie bosch', 'robert bosch gmbh.']
#
# Precision: 0.5833333333333334
# Recall: 1.0
# F1-Score: 0.7368421052631579
# ___________________________
# Presseinformation: 2010 0701
# Goldstandard: ['bosch sicherheitssysteme']
# Predicted: ['bosch', 'dome-kameras pi', 'neue bosch-dome-kameras', 'ip-kamerasystem', 'onvif-standard', 'bosch-gruppe', 'robert bosch gmbh', 'robert bosch stiftung', 'robert bosch industrietreuhand kg', 'familie bosch', 'robert bosch gmbh.']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2010 1019
# Goldstandard: []
# Predicted: ['bosch', 'bosch universal-adapter', 'riffspitze', 'robert bosch gmbh', 'd-70745 leinfelden-echterdingen', 'bosch-gruppe', 'robert bosch stiftung', 'robert bosch industrietreuhand kg', 'familie bosch', 'robert bosch gmbh.']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2011 0326
# Goldstandard: []
# Predicted: ['presse-information', 'bosch', 'bosch-gruppe', 'trendence und universum', 'robert bosch gmbh', 'femtec', 'graduate specialist program', 'robert bosch stiftung', 'robert bosch industrietreuhand kg', 'familie bosch', 'robert bosch gmbh.']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2011 0807
# Goldstandard: ['bosch packaging technology']
# Predicted: ['bosch pi', 'bosch packaging technology', 'robert bosch gmbh', 'brand management', 'bosch', 'bosch geschäftsbereich packaging technology', 'bosch-gruppe', 'robert bosch stiftung', 'robert bosch industrietreuhand kg', 'familie bosch', 'robert bosch gmbh.']
#
# Precision: 0.18181818181818182
# Recall: 1.0
# F1-Score: 0.3076923076923077
# ___________________________
# Presseinformation: 2012 0113
# Goldstandard: ['bosch sensortec']
# Predicted: ['robert bosch gmbh', 'brand management', 'bosch', 'bosch sensortec gmbh', 'robert bosch gmbh.', 'bosch gruppe', 'bosch-gruppe']
#
# Precision: 0.8571428571428571
# Recall: 1.0
# F1-Score: 0.923076923076923
# ___________________________
# Presseinformation: 2012 0808
# Goldstandard: ['chassis systems control']
# Predicted: ['presse-information', 'bosch', 'elektronische stabilitäts-programm', 'brand management', 'berganfahrhilfe hill hold control', 'bosch-gruppe', 'robert bosch gmbh']
#
# Precision: 0.14285714285714285
# Recall: 1.0
# F1-Score: 0.25
# ___________________________
# Presseinformation: 2013 0201
# Goldstandard: ['bosch power tools', 'skil', 'dremel']
# Predicted: ['bosch pi', 'bosch', 'robert bosch gmbh', 'brand management', 'grüne leds', 'ecp', 'bosch akku-geräten', 'schnell-ladegerät', 'akkuspannung/-kapazität', 'robert bosch gmbh tel', 'd-70745 leinfelden-echterdingen', 'bosch-gruppe', 'skil', 'dremel', 'bosch power tools']
#
# Precision: 0.6666666666666666
# Recall: 1.0
# F1-Score: 0.8
# ___________________________
# Presseinformation: 2013 0618
# Goldstandard: ['internationales deutschlandforum']
# Predicted: ['presse-information', 'internationalen deutschlandforum', 'bosch', 'allensbach instituts', 'bosch-gruppe', 'brand management', 'rb zi', 'internationale deutschlandforum', 'robert bosch gmbh', 'robert bosch stiftung', 'robert bosch industrietreuhand kg', 'familie bosch', 'robert bosch gmbh.']
#
# Precision: 0.15384615384615385
# Recall: 1.0
# F1-Score: 0.2666666666666667
# ___________________________
# Presseinformation: 2013 0947
# Goldstandard: ['bosch power tools']
# Predicted: ['presse-information', 'gcd', 'bosch pi', 'bosch', 'robert bosch gmbh', 'brand management', 'd-70745 leinfelden-echterdingen', 'bosch-gruppe', 'skil', 'dremel', 'bosch power tools']
#
# Precision: 0.2727272727272727
# Recall: 1.0
# F1-Score: 0.42857142857142855
# ___________________________
# Presseinformation: 2014 0218
# Goldstandard: ['robert bosch ag', 'universität mannheim', 'universität stuttgart-hohenheim']
# Predicted: ['presse-information', 'robert bosch ag', 'bosch-gruppe', 'robert bosch ltd', 'universität mannheim', 'bosch', 'universität stuttgart-hohenheim', 'mobility solutions', 'industrial technology', 'consumer goods', 'energy and building technology', 'robert bosch gmbh']
#
# Precision: 0.5833333333333334
# Recall: 1.0
# F1-Score: 0.7368421052631579
# ___________________________
# Presseinformation: 2014 0912
# Goldstandard: ['bsh', 'siemens']
# Predicted: ['presse-information', 'bosch', 'bsh bosch', 'siemens hausgeräte gmbh', 'bsh', 'bosch-gruppe', 'siemens-marke', 'siemens', 'robert bosch gmbh', 'bosch gruppe', 'robert bosch gmbh. wie', 'brand management', 'rb ir', 'bsh-anteils', 'siemens ag', 'robert bosch stiftung', 'robert bosch industrietreuhand kg', 'familie bosch', 'robert bosch gmbh.', 'sec', 'börsenaufsicht sec']
#
# Precision: 1.0
# Recall: 1.0
# F1-Score: 1.0
# ___________________________
# Presseinformation: 2015 0405
# Goldstandard: ['türk traktör', 'bosell']
# Predicted: ['bosch', 'erika görge']
#
# Precision: 0.5
# Recall: 0.5
# F1-Score: 0.5
# ___________________________
# Presseinformation: 2015 0908
# Goldstandard: ['bosch packaging technology', 'kliklok-woodman', 'ampack gmbh', 'osgood industries']
# Predicted: ['presse-information', 'packaging technology', 'bosch', 'bosch packaging technology', 'kliklok-woodman corporation', 'kliklok-woodman', 'kliklok international ltd', 'bereichsvorstands', 'robert bosch gmbh', 'pa ac', 'ampack gmbh', 'osgood industries', 'bosch becher', 'bosch-geschäftsbereich packaging technology', 'bosch-gruppe', 'mobility solutions', 'industrial technology', 'consumer goods', 'energy and building technology', 'robert bosch stiftung', 'robert bosch industrietreuhand kg', 'familie bosch', 'robert bosch gmbh.', 'bsh bosch', 'siemens hausgeräte gmbh', 'bsh hausgeräte gmbh', 'zf lenksysteme gmbh', 'robert bosch automotive steering gmbh']
#
# Precision: 0.6071428571428571
# Recall: 1.0
# F1-Score: 0.7555555555555554
# ___________________________
# Presseinformation: 2016 0501
# Goldstandard: ['technischen aufsichtsbehörde hessen', 'bosch engineering gmbh', 'verkehrsgesellschaft frankfurt am main']
# Predicted: ['beg', 'technischen aufsichtsbehörde hessen', '\uf084 bosch', 'bosch engineering', 'verkehrsgesellschaft frankfurt am main', 'bosch engineering gmbh', 'd-74003 heilbronn telefax', 'brand management', 'bosch', 'radar', 'rail control unit', 'robert bosch gmbh', 'bosch-gruppe', 'mobility solutions', 'industrial technology', 'consumer goods', 'energy and building technology', 'd ie', 'vgf', 'sozialen medien']
#
# Precision: 0.2
# Recall: 1.0
# F1-Score: 0.33333333333333337
# ___________________________
# Presseinformation: 2016 0922
# Goldstandard: ['escrypt', 'automotive aftermarket', 'automotive service solutions']
# Predicted: ['intelligentes flottenmanagement bosch', 'aa dr  bosch', 'bosch-lösung', 'bosch', 'd-76225 karlsruhe telefax', 'brand management', 'robert bosch gmbh automotive aftermarket', 'werkstattkonzepte bosch service', 'bosch-gruppe', 'mobility solutions', 'industrial technology', 'consumer goods', 'energy and building technology', 'robert bosch gmbh']
#
# Precision: 0.14285714285714285
# Recall: 0.6666666666666666
# F1-Score: 0.23529411764705882
# ___________________________
# Presseinformation: 2017 0303
# Goldstandard: ['motorworld stuttgart', 'bosch classic', 'bosch oldtimer schrauber e.v.', 'bosch fotogruppe', 'automotive aftermarket', 'automotive service solutions']
# Predicted: ['presse-information', 'bosch boxberg', 'bosch', 'bosch classic', 'bosch oldtimer schrauber e.v.', 'bosch fotogruppe', 'robert bosch gmbh', 'd-76225 karlsruhe telefax', 'brand management', 'werkstattkonzepte bosch service', 'bosch-gruppe', 'mobility solutions', 'industrial technology', 'consumer goods', 'energy and building technology', 'smart home', 'smart city', 'connected mobility']
#
# Precision: 0.5
# Recall: 1.0
# F1-Score: 0.6666666666666666
# ___________________________
# Presseinformation: 2018 0204
# Goldstandard: []
# Predicted: ['bosch', 'fahrrad-leasing', 'neues mobilitäts', 'robert bosch gmbh', 'konzernbetriebsrats', 'bosch-gruppe', 'rb mk', 'mobility solutions', 'industrial technology', 'consumer goods', 'energy and building technology', 'smart home', 'smart city', 'connected mobility', 'robert bosch stiftung', 'robert bosch industrietreuhand kg', 'familie bosch', 'robert bosch gmbh.']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2019 0501
# Goldstandard: ['automotive aftermarket']
# Predicted: ['presse-information automotive aftermarket', 'bosch', 'tsb', 'ebr', 'downloadpakets', 'downloadpaketes', 'esitronic-paket', 'obd-buchse', 'fca gruppe', 'fiat chrysler automobiles', 'security gateways', 'esitronic-nutzern', 'kts-generation', 'robert bosch gmbh automotive aftermarket', 'geschäftsbereich automotive aftermarket', 'werkstattkonzepte bosch service', 'bosch-gruppe', 'mobility solutions', 'industrial technology', 'consumer goods', 'energy and building technology', 'smart home', 'smart city', 'connected mobility', 'robert bosch gmbh']
#
# Precision: 0.12
# Recall: 1.0
# F1-Score: 0.21428571428571425
# ___________________________
# Presseinformation: 2019 1103
# Goldstandard: []
# Predicted: ['presse-information', 'nevonex', 'pessl instruments', 'rauch', 'syngenta', 'topcon', 'xarvio', 'zg raiffeisen', 'bosch', 'robert bosch gmbh', 'beg', 'mbc', 'applikationssoftwares', 'agritechnica', 'bosch-gruppe', 'mobility solutions', 'industrial technology', 'consumer goods', 'energy and building technology', 'smart home', 'smart city', 'connected mobility', 'robert bosch stiftung', 'robert bosch industrietreuhand kg', 'familie bosch', 'robert bosch gmbh.']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# 0.268624574243015 0.5688405797101449 0.3340153795093894

# %%
#Personen-Index

all_per_precision = []
all_per_recall = []
all_per_f1 = []
for filename in os.listdir(r"C:\Users\Goegg\OneDrive\Desktop\zu annotieren"):
    
    pi_name = get_PI(filename)
    print("Presseinformation:", pi_name)
    #get per-pred
    df_pred = pd.read_excel(os.path.join(directory, pi_name + extension), header=0)
    pred_per_out = df_pred['Personen-Index'].tolist()
    pred_per = [x for x in pred_per_out if x == x]
    #get per-gold
    df_gold = pd.read_excel(goldstandard, pi_name)
    gold_per_out = df_gold['Personen-Index'].tolist()
    gold_per = [lemmatizer(x, NOUN)[0].lower() for x in gold_per_out if x == x]
    print("Goldstandard:", gold_per)
    print("Predicted:", pred_per, "\n")
    if len(gold_per) == 0 and len(pred_per) == 0:
        print("both nothing\n __________________________")
        all_per_precision.append(1.0)
        all_per_recall.append(1.0)
        all_per_f1.append(1.0)
        continue
    else:
        print("Precision:", precision(gold_per, pred_per))
        print("Recall:", recall(gold_per, pred_per))
        print("F1-Score:", f1(gold_per, pred_per), "\n___________________________")
        all_per_precision.append(precision(gold_per, pred_per))
        all_per_recall.append(recall(gold_per, pred_per))
        all_per_f1.append(f1(gold_per, pred_per))
        
mean_per_precision = sum(all_per_precision) / len(all_per_precision)
mean_per_recall = sum(all_per_recall) / len(all_per_recall)
mean_per_f1 = sum(all_per_f1) / len(all_per_f1)    
print(mean_per_precision, mean_per_recall, mean_per_f1)
# Out:
# Presseinformation: 2000 0310
# Goldstandard: []
# Predicted: ['gerhard ketterer']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2000 0702
# Goldstandard: []
# Predicted: ['ftir hochfrequeniunwendungcn', 'zuverlässigkeits-und lebensdauerprüfungen', 'liefer-und abnahmespezifi•', 'jouma', 'gerhard ketterer']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2000 1009
# Goldstandard: []
# Predicted: ['eme  ', 'bosch-zündkerzen', 'ersatzteilgeschtlft', 'frank·ulnch breit•prechar', 'robert bosch', 'ulf-malte wünsch']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2001 0350
# Goldstandard: []
# Predicted: []
#
# both nothing
#  __________________________
# Presseinformation: 2001 0909
# Goldstandard: ['dr. marco lang']
# Predicted: ['marco lang', 'hawera', 'bohrfortschritt', 'beschlag-und schlangenbohrer', 'handwerkeralltag', 'heavy-duty-metall']
#
# Precision: 0.16666666666666666
# Recall: 1.0
# F1-Score: 0.2857142857142857
# ___________________________
# Presseinformation: 2002 0114
# Goldstandard: []
# Predicted: ['robert bosch', 'mancherlei', 'karl', 'robert', 'anna kayser', 'sigmund schuckert', 'bugen kayser', 'eugen kayser', 'wasserstandsfernmelder', 'frederick simms', 'de dion bouton-motordreirad', 'simms', 'robert  boschs', 'gottlob honold', 'honold', 'sohn', 'vater', 'paula', 'georg zundel', 'clara', 'zetkin', 'margarete', 'paula bosch', 'robert boschs', 'hermann bosch', 'hugo borst', 'scheuing', 'sohnes robert', 'hermann  bosch', 'hans walz', 'ernst ulmer', 'otto heins', 'gottlob', 'lucian bernhard', 'karl martell wild', 'produktions-und', 'hermann fellmeth', 'eva', 'willy  schloßstein', 'feuerbach', 'wild', 'fellmeth', 'bosch-fertigungstechniker', 'henry ford', 'john l. baird', 'hugo junkers', 'rudolf diesel', 'carl goerdeler', 'gottlob berger', 'carl  goerdeler', 'theodor heuss', 'clay', 'hans  walz', 'fellmethjedoch', 'robert d', 'robert  bosch', 'hans l. merkle', 'hans l.', 'merkle', 'halbjuden', 'werner', 'marcus bierich', 'hans l. merke', 'merkles', 'bierich', 'hermann scholl', 'anna kayser lived', 'whom bosch', 'brother-in-law eugen kayser', 'he manufactured', 'lt was', 'though he had', 'englishman frederick simms', 'englishman simms', "robert bosch's", 'he had', 'adomcd with the lettering', 'gottlob  honold', 'as robert', 'for honold', "ofthe company's turnover", 'robert bosch had married his fiancee anna', 'kayser', 'his younger daughter paula', 'particularly burdensome', 'arnong other reasons', 'married to clara zetkin', "bosch's", 'ailing son', 'frarne ofmind', "ofthe firm's", 'adviser scheuing', 'hermann bosch at their  head', 'even gottlob honold', 'who had repeatedly wamed bosch', 'unexpectedly died ofa', 'gradually reconciliation between', 'robert bosch turned his firm into a limited liability company', 'for robert bosch', 'henry ford himself', 'eugen bauer', 'windscreen wipers', 'trafficators as well as the headlights', 'hard hit by the world economic crisis', 'hans walz had', 'ofthe naziregime', 'senior executives', 'robert bosch himselfhad brought this', 'lord mayor', "walz's", 'july', 'hans walz criticized', 'subsequently', 'ofgottlob berger', 'attempt of20th july', 'secretly', 'although', 'fared well', "clay's", "hans walz's", 'who had', 'hans walz had agreed that the retirement age for members ofthe board of  management should be fixed at 65 years', 'hans walz had even argued for a lower retirement age  ', 'nominated managing', 'ofthe robert bosch', 'nominated by walz as a füll managing director  and made principal financial manager ofthe company', 'belatedly honoured for his conduct during the national socialist', 'hans walz died', 'faced merkle', 'ofthe second halfofthe', 'ofthe gerrnan', 'page11', 'supervisory board', 'ofthe robert  ', 'hans walzafter world war two', 'ofthe supervisory board ofthe robert bosch', "chairman ofthe company's", 'chairman ofthe', 'gennany gennany']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2002 0403
# Goldstandard: []
# Predicted: ['winter-auf sommerreifen', 'bremsregel', 'bosch-pressebild nr.', 'frank-ulrich breitsprecher', 'presseforum']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2002 0710
# Goldstandard: []
# Predicted: ['bosch-geschäftsbereich chassissysteme', 'uberträgl', 'frank-ulrich breitsprecher', 'automobilherstellem', 'chassissysteme', 'pius', 'dureh klick', 'martin']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2002 1008
# Goldstandard: []
# Predicted: ['u.-malte wünsch']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2003 0212
# Goldstandard: []
# Predicted: ['erla ubt', 'handkreis', 'robert bosch', 'frank-ulrich breitsprecher', 'presseforum', 'gerhard ketterer']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2003 0512
# Goldstandard: []
# Predicted: ['eingeschmolzener mittelelektrode', 'robert bosch', 'frank-ulrich breitsprecher']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2003 0811
# Goldstandard: []
# Predicted: ['frank-ulrich breitsprecher']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2003 1203
# Goldstandard: []
# Predicted: ['frank-ulrich breitsprecher', 'presseforum', 'compact-flash-speicherkarten', 'gerhard ketterer']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2004 0317
# Goldstandard: []
# Predicted: ['sägefortschritt', 'gerhard ketterer']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2004 0615
# Goldstandard: ['albrecht schäfer']
# Predicted: ['kor rosion', 'alb', 'brennwertgeräts', 'siede', 'alsi-wärmeübertrager', 'reini gungsmitteln', 'junkers-pressebild nr.', 'u.-malte wünsch']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2004 0951
# Goldstandard: []
# Predicted: ['messkurven']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2005 0112
# Goldstandard: ['siegfried dais']
# Predicted: ['lebenslauf', 'siegfried dais']
#
# Precision: 0.5
# Recall: 1.0
# F1-Score: 0.6666666666666666
# ___________________________
# Presseinformation: 2005 0607
# Goldstandard: []
# Predicted: ['uta-micaela dürig', 'journalistenkontakt', 'gerhard ketterer', 'robert bosch']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2005 0951
# Goldstandard: []
# Predicted: ['messeingänge']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2006 0307
# Goldstandard: ['dr. rolf leonhard']
# Predicted: ['rolf leonhard', 'leonhard', 'richard backhaus', 'robert bosch']
#
# Precision: 0.5
# Recall: 1.0
# F1-Score: 0.6666666666666666
# ___________________________
# Presseinformation: 2006 0911
# Goldstandard: []
# Predicted: ['robert bosch', 'uta-micaela dürig', 'journalistenkontakt', 'michael schmidtke', 'gerhard ketterer']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2007 0307
# Goldstandard: []
# Predicted: ['winkelschleifer', 'bohr', 'uta-micaela dürig', 'schen dübelloch', 'journalistenkontakt', 'robert bosch', 'michael schmidtke', 'gerhard ketterer']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2007 1001
# Goldstandard: []
# Predicted: ['uta-micaela dürig', 'heiderose dreiner', 'robert bosch']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2008 0318
# Goldstandard: []
# Predicted: ['uta-micaela dürig', 'erika görge', 'robert bosch']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2008 1101
# Goldstandard: ['dr. bernd bohr']
# Predicted: ['viviane reding', 'bernd bohr', 'bohr', 'uta-micaela dürig', 'journalistenkontakt', 'stephan kraus', 'robert bosch']
#
# Precision: 0.14285714285714285
# Recall: 1.0
# F1-Score: 0.25
# ___________________________
# Presseinformation: 2009 0419
# Goldstandard: []
# Predicted: ['robert bosch', 'uta-micaela dürig', 'heiderose dreiner']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2009 1004
# Goldstandard: ['friedbert klefenz']
# Predicted: ['friedbert klefenz', 'uta-micaela dürig', 'margit nuck', 'robert bosch']
#
# Precision: 0.25
# Recall: 1.0
# F1-Score: 0.4
# ___________________________
# Presseinformation: 2010 0701
# Goldstandard: []
# Predicted: ['robert bosch', 'uta-micaela dürig', 'divar', 'erika görge']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2010 1019
# Goldstandard: []
# Predicted: ['diamant-riff-segmentsägeblatt', 'titannitrid', 'robert bosch', 'uta-micaela dürig', 'karin heinlein telefon', 'gerhard ketterer']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2011 0326
# Goldstandard: ['dr. wolfgang malchow']
# Predicted: ['dr. malchow', 'wolfgang malchow', 'uta-micaela dürig', 'karriereberatungsseminare', 'journalistenkontakt', 'dirk haushalter', 'robert bosch']
#
# Precision: 0.2857142857142857
# Recall: 1.0
# F1-Score: 0.4444444444444445
# ___________________________
# Presseinformation: 2011 0807
# Goldstandard: ['michael voeth']
# Predicted: ['müllereitagung', 'uta-micaela dürig', 'antriebsbereich', 'produktreste', 'michael voeth', 'journalistenkontakt', 'johanna bauer', 'robert bosch']
#
# Precision: 0.125
# Recall: 1.0
# F1-Score: 0.2222222222222222
# ___________________________
# Presseinformation: 2012 0113
# Goldstandard: []
# Predicted: ['bosch sensortec', 'uta-micaela dürig', 'endgerätehersteller', 'martina förster', 'thomas knoll']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2012 0808
# Goldstandard: ['gerhard steiger']
# Predicted: ['gerhard steiger', 'robert bosch', 'uta-micaela dürig', 'stephan kraus']
#
# Precision: 0.25
# Recall: 1.0
# F1-Score: 0.4
# ___________________________
# Presseinformation: 2013 0201
# Goldstandard: []
# Predicted: ['uta-micaela dürig', 'lithium-ionen-akkus', 'max', 'schraubendurchmesser max', 'journalistenkontakt', 'robert bosch']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2013 0618
# Goldstandard: ['franz fehrenbach', 'angela merkel']
# Predicted: ['franz fehrenbach', 'bosch-aufsichtsratsvorsitzender', 'fehrenbach', 'wohlstandsverlust', 'robert bosch', 'uta-micaela dürig', 'josef schumpeters', 'dr. angela merkel', 'merkel', 'rené ziegler']
#
# Precision: 0.5
# Recall: 1.0
# F1-Score: 0.6666666666666666
# ___________________________
# Presseinformation: 2013 0947
# Goldstandard: []
# Predicted: ['uta-micaela dürig', 'journalistenkontakt', 'robert bosch']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2014 0218
# Goldstandard: ['klaus peter fouquet', 'klaus huttelmaier']
# Predicted: ['klaus peter fouquet', 'klaus huttelmaier', 'fouquet', 'journalistenkontakt', 'angelika kiessling']
#
# Precision: 0.6
# Recall: 1.0
# F1-Score: 0.7499999999999999
# ___________________________
# Presseinformation: 2014 0912
# Goldstandard: ['volkmar denner']
# Predicted: ['volkmar denner', 'uta-micaela dürig', 'ralf p. thomas', 'thoma', 'uwe raschke', 'nachsteuerergebnis', 'karsten ottenberg', 'raschke', 'robert bosch', 'ingo rapold', 'rené ziegler']
#
# Precision: 0.09090909090909091
# Recall: 1.0
# F1-Score: 0.16666666666666669
# ___________________________
# Presseinformation: 2015 0405
# Goldstandard: []
# Predicted: ['türk traktör', 'bosell']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2015 0908
# Goldstandard: []
# Predicted: ['friedbert klefenz', 'christoph zemelka', 'bill crist', 'klefenz', 'ampack', 'alissa cleland', 'dirk haushalter', 'robert bosch']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2016 0501
# Goldstandard: ['bernhard bihr', 'christoph zemelka']
# Predicted: ['kollisionswarnsystem', 'bernhard bihr', 'christoph zemelka', 'bihr', 'annett fischer']
#
# Precision: 0.6
# Recall: 1.0
# F1-Score: 0.7499999999999999
# ___________________________
# Presseinformation: 2016 0922
# Goldstandard: []
# Predicted: ['geringere', 'robert bosch', 'christoph zemelka', 'heiderose dreiner']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2017 0303
# Goldstandard: []
# Predicted: ['christoph zemelka', 'journalistenkontakt', 'heiderose dreiner']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2018 0204
# Goldstandard: ['christoph kübel', 'kerstin mai']
# Predicted: ['fahrradfahren', 'christoph kübel', 'bike-leasing', 'kerstin mai', 'christoph zemelka', 'michael kattau', 'robert bosch']
#
# Precision: 0.42857142857142855
# Recall: 1.0
# F1-Score: 0.6
# ___________________________
# Presseinformation: 2019 0501
# Goldstandard: []
# Predicted: ['christof ehrhart', 'nico krespach']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2019 1103
# Goldstandard: ['andrew allen']
# Predicted: ['andrew allen', 'robert bosch', 'plattformkonzept', 'christof ehrhart', 'andrea fluhr', 'cornelia dürr']
#
# Precision: 0.3333333333333333
# Recall: 1.0
# F1-Score: 0.5
# ___________________________
# 0.12550112930547713 0.32608695652173914 0.16889233954451346

# %%
#Themen-Index

all_thema_precision = []
all_thema_recall = []
all_thema_f1 = []
for filename in os.listdir(r"C:\Users\Goegg\OneDrive\Desktop\zu annotieren"):
    
    pi_name = get_PI(filename)
    print("Presseinformation:", pi_name)
    #get thema-pred
    df_pred = pd.read_excel(os.path.join(directory, pi_name + extension), header=0)
    pred_thema_out = df_pred['Themen-Index'].tolist()
    pred_thema = [x for x in pred_thema_out if x == x]
    #get thema-gold
    df_gold = pd.read_excel(goldstandard, pi_name)
    gold_thema_out = df_gold['Themen-Index'].tolist()
    gold_thema = [lemmatizer(x, NOUN)[0].lower() for x in gold_thema_out if x == x]
    print("Goldstandard:", gold_thema)
    print("Predicted:", pred_thema, "\n")
    if len(gold_thema) == 0 and len(pred_thema) == 0:
        print("both nothing\n __________________________")
        all_thema_precision.append(1.0)
        all_thema_recall.append(1.0)
        all_thema_f1.append(1.0)
        continue
    else:
        print("Precision:", precision(gold_thema, pred_thema))
        print("Recall:", recall(gold_thema, pred_thema))
        print("F1-Score:", f1(gold_thema, pred_thema), "\n___________________________")
        all_thema_precision.append(precision(gold_thema, pred_thema))
        all_thema_recall.append(recall(gold_thema, pred_thema))
        all_thema_f1.append(f1(gold_thema, pred_thema))
        
mean_thema_precision = sum(all_thema_precision) / len(all_thema_precision)
mean_thema_recall = sum(all_thema_recall) / len(all_thema_recall)
mean_thema_f1 = sum(all_thema_f1) / len(all_thema_f1)    
print(mean_thema_precision, mean_thema_recall, mean_thema_f1)
# Out:
# Presseinformation: 2000 0310
# Goldstandard: ['elektrowerkzeug']
# Predicted: ['pro', 'internet', 'browser']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2000 0702
# Goldstandard: ['raumfahrttechnik']
# Predicted: ['gmbh']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2000 1009
# Goldstandard: []
# Predicted: ['gmbh', 'werk', 'bild', 'leistung', 'modell', 'platin', 'mercedes c-kla11e', 'die fließgepresste mittelelektrode', 'internet', 'mercedes c-klasse', 'browser']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2001 0350
# Goldstandard: []
# Predicted: ['prozent', 'anspruch', 'silver plus', 'die spitzenbatterie von bosch']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2001 0909
# Goldstandard: ['hammerbohrer', 'diamant']
# Predicted: ['september', 'leiter', 'hersteller', 'pressekonferenz', 'marktführer', 'handwerker']
#
# Precision: 0.16666666666666666
# Recall: 0.5
# F1-Score: 0.25
# ___________________________
# Presseinformation: 2002 0114
# Goldstandard: ['mitarbeiter', 'kündigung']
# Predicted: ['firma', 'gmbh', 'unternehmen', 'im jahr 1902', 'zeit', 'ersten weltkrieg', 'ein jahr', 'sozial', 'jahr 1906', 'weltkrieg', 'verlorenen krieg', 'amerikanischer', 'krieg', 'ersten weltkriegs', 'deutschen', 'ein jahr später', 'schwarzen freitag', 'berliner', 'dem krieg', 'wenige jahre später', 'dreißiger jahre arg', 'dreißiger jahre', 'kriegsausbruch', 'leipziger', 'deutscher', 'attentat des 20. juli 1944', 'kriegsende', 'währungsreform des jahres 1948', 'amerikanische', 'deutsche', 'hauses bosch', 'gerechter der völker', 'jude', 'deportation', 'fünfziger jahre', 'zweiten weltkrieg', 'im jahr 1974', 'westeuropa im jahr 2001', 'before starting up his business', 'for it', 'over the previous years karl had done a lot for his youngest brother', 'the final deciding factor to start up  ', 'even the object ofthe company foundation had long been far from clear', 'by the fact that he attended lectures at  stuttgart polytechnic as a non-registered student for one semester and also spent six months in the  company run by his brother karl', 'order to improve his knowlcdge ofbook-keeping', 'he must have filed two patents', 'slightly more money could be eamed by installing telephones  and staff paging systems', 'and the remote electric water-level indicators designed and fitted by him  even kept the business afloat for some time', 'played a not  unimportant role', 'first constructed by bosch', 'tumed out', 'this is where bosch profited from the practical experience he  had gained over many years during his travels as a mechanic', 'germany germany', 'the deutz sample magneto ignition system did not have a very long service life   and amended the unpatented', 'all the same', 'from then on', 'the workshop of bosch  the mechanic never looked back', 'the early years', 'frequently needed to turn to  his mother and his brother karl for financial support', 'with a considcrably  improved', 'it was now possible to use  the ignition device', 'originally only suitable for stationary combustion engines with low speeds up  to a maximum of200', 'for smaller engines runing at higher speeds of 800', 'or  even 1200 rpm', 'a motor vehicle for the first time', 'the vehicle', 'one of the de dion bouton', 'motor tricycles that were quite common at that date', 'the experiment', 'bosch had also begun to supply his magneto ignition systems to  foreign customers', 'at the turn ofthe century', 'bosch and his 45', 'the neo-renaissance style', 'with its round  staircase tower', 'there was no longer any need for the break-spark rodding', 'difficult to implement', 'the ignition spark', 'and this device', 'particularly after the break with simms and the foundation ofan agency in the usa', 'within a few years the company had developed into one ofthe most important   ', 'this success', 'basically due to the  new magneto ignition system', 'other pre-first-world-war products for motor vehicles are hardly  worth mentioning', 'even the complete electrical installation for motor vehicles developed', 'only able to make its füll contribution to the success ofthe company', 'this great commercial success', 'a year after the foundation ofhis company', 'the marriage produced two daughters and a son', 'named robert after his father', 'this son  ', 'this blow of fate', 'followed by another', 'the increasing alienation of  robert bosch from his two daughters and even his wife', 'for the bosch parents', 'view of  the fact that georg zundel', 'at first she', 'entirely on', "paula's side", 'all too often', 'despite its commercial success', 'deliberate provocative actions by the association of  metal workers led to a strike within the company to which the founder and proprietor replied', 'the reasons for this strike were', 'the final analysis', 'germany to  introduce', 'as early as 1906', 'saturday aftemoon and graded holiday arrangements', 'almost revolutionary innovation at that  time', 'lt is even harder to understand the strike when one considers the fact that bosch paid the  h ...
# Precision: 0.052
# Recall: 1.0
# F1-Score: 0.0988593155893536
# ___________________________
# Presseinformation: 2002 0403
# Goldstandard: []
# Predicted: ['prozent']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2002 0710
# Goldstandard: ['chassissysteme']
# Predicted: ['richtfest', 'gmbh', 'entwicklung', 'milliarde', 'ingenieur', 'mitarbeiter', 'stuttgart', 'by wire', 'vergangenen jahr', 'euro', 'die jpeg-bilder', 'browser']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2002 1008
# Goldstandard: ['junkers/bosch-thermotechnik', 'junkers-website', 'heizung']
# Predicted: ['tipps', 'auftritt', 'konzept', 'design', 'rubrik', 'neuer junkers-internetauftritt', 'internet']
#
# Precision: 0.14285714285714285
# Recall: 0.3333333333333333
# F1-Score: 0.2
# ___________________________
# Presseinformation: 2003 0212
# Goldstandard: ['elektrowerkzeugen']
# Predicted: ['februar', 'kompetenz', 'anbieter', 'saw  line visor']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2003 0512
# Goldstandard: ['garten- und forstgeräte']
# Predicted: ['garten', 'mai', 'markt', 'betrieb', 'anwendung', 'gmbh']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2003 0811
# Goldstandard: ['abtragsleistung']
# Predicted: ['prozent', 'august', 'modell', 'material', 'holz', 'das geheimnis des 250 mil limeter', 'rich']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2003 1203
# Goldstandard: ['videoüberwachung', 'sicherheit']
# Predicted: ['schule', 'hotel', 'betrieb', 'dezember', 'betrieb', 'sicherheit']
#
# Precision: 0.16666666666666666
# Recall: 0.5
# F1-Score: 0.25
# ___________________________
# Presseinformation: 2004 0317
# Goldstandard: []
# Predicted: ['märz', 'bereich', 'gke-modellen für ermüdungsarmes arbeiten', 'press text.cfm']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2004 0615
# Goldstandard: []
# Predicted: ['aluminium', 'juni', 'wärme']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2004 0951
# Goldstandard: ['fahrzeuggewicht', 'nutzfahrzeug']
# Predicted: ['februar', 'lösung', 'voraussetzung', 'die effiziente fahrzeug-diagnose', 'anschluss']
#
# Precision: 0.2
# Recall: 0.5
# F1-Score: 0.28571428571428575
# ___________________________
# Presseinformation: 2005 0112
# Goldstandard: ['forschung', 'kraftfahrzeugausrüstung', 'kommunikationstechnik', 'geschäftsführung']
# Predicted: ['januar', 'gmbh', 'vorsitzender', 'mitglied', 'pi g2 de']
#
# Precision: 0.2
# Recall: 0.25
# F1-Score: 0.22222222222222224
# ___________________________
# Presseinformation: 2005 0607
# Goldstandard: ['videoüberwachungssysteme']
# Predicted: ['nacht']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2005 0951
# Goldstandard: []
# Predicted: ['prüfung', 'das multiscope', 'deutsch', 'englisch', 'französisch']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2006 0307
# Goldstandard: ['benzin-direkteinspritzung', 'strahlgeführtes brennverfahren']
# Predicted: ['premiere', 'prozent', 'benzin', 'jahr 2005', 'deutsche', 'vi   robert bosch gmbh']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2006 0911
# Goldstandard: ['heimwerker']
# Predicted: ['september', 'einstellung']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2007 0307
# Goldstandard: ['elektrowerkzeuge', 'vibrationsschutz']
# Predicted: ['märz', 'benutzung', 'jahr 2001', 'zeit']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2007 1001
# Goldstandard: ['ersatzteile']
# Predicted: ['klassik', 'tradition', 'teil', 'lager', 'million', 'internet', 'bosch klassik teilevermittlung', 'auf der breit 4']
#
# Precision: 0.25
# Recall: 1.0
# F1-Score: 0.4
# ___________________________
# Presseinformation: 2008 0318
# Goldstandard: ['tonwiedergabe']
# Predicted: ['märz', 'höhe']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2008 1101
# Goldstandard: []
# Predicted: ['technologie', 'aufklärung', 'erfolg', 'industrie', 'einsatz', 'kategorie', 'esafety award', 'brüssel', 'esafety award 2008', 'fia world prize for road safety', 'the environment and mobility', 'jahr 2003', 'europäische', 'pro jahr']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2009 0419
# Goldstandard: ['pollen', 'gesundheitsschutz', 'sicherheit', 'komfort']
# Predicted: ['gmbh', 'april', 'kilometer', 'wechsel', 'prozent', 'internet', 'pro jahr']
#
# Precision: 0.14285714285714285
# Recall: 0.25
# F1-Score: 0.18181818181818182
# ___________________________
# Presseinformation: 2009 1004
# Goldstandard: []
# Predicted: ['niederlassung', 'oktober', 'präsenz', 'im jahr 2008', 'pro jahr']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2010 0701
# Goldstandard: []
# Predicted: ['serie', 'juli', 'budget', 'anbieter', 'anschluss', 'd-85626 grasbrunn deutschland', 'pro jahr']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2010 1019
# Goldstandard: ['feinmechanik']
# Predicted: ['gmbh', 'entfernen', 'mörtel', 'anwendung', 'bosch gop', 'deutsche', 'pro jahr']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2011 0326
# Goldstandard: ['akademiker', 'kaufleute', 'jubiläumsjahr', 'mitarbeiter', 'junior manager program', 'graduate specialist program']
# Predicted: ['akademiker', 'stelle', 'kaufleute', 'jubiläumsjahr', 'mitarbeiter', 'im jahr des 125.', 'im jahr 2010']
#
# Precision: 0.8571428571428571
# Recall: 1.0
# F1-Score: 0.923076923076923
# ___________________________
# Presseinformation: 2011 0807
# Goldstandard: ['müllereitagung']
# Predicted: ['august', 'design', 'land', 'kurze umrüstzeiten', 'im jahr 2010']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2012 0113
# Goldstandard: []
# Predicted: ['milliarde', 'dieser dreiachsige drehratensensor', 'im jahr 2010']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2012 0808
# Goldstandard: ['sicherheit', 'komfort', 'bremsregelsysteme']
# Predicted: ['basis', 'sicherheit', 'vorgänger', '\uf084 nochmals', 'esp® 9 premium', '9 bosch', 'youtube link', 'im jahr 2011']
#
# Precision: 0.125
# Recall: 0.3333333333333333
# F1-Score: 0.18181818181818182
# ___________________________
# Presseinformation: 2013 0201
# Goldstandard: ['electronic cell protection', 'leistung']
# Predicted: ['euro', 'februar', 'leistung', 'anwendung', 'leichtgewicht', 'prozent', 'electronic cell protection', 'im jahr 2011', 'im jahr 2012']
#
# Precision: 0.4444444444444444
# Recall: 1.0
# F1-Score: 0.6153846153846153
# ___________________________
# Presseinformation: 2013 0618
# Goldstandard: ['wohlstandsverlust', 'wirtschaft', 'lebensqualität', 'fortschritt', 'wettbewerb']
# Predicted: ['wettbewerb', 'herausforderung', 'fortschritt', 'lebensqualität', 'lösung', 'lösung', 'weg', 'was den menschen', 'europäische', 'im jahr 2012']
#
# Precision: 0.3
# Recall: 0.6
# F1-Score: 0.4
# ___________________________
# Presseinformation: 2013 0947
# Goldstandard: ['metall']
# Predicted: ['september', 'metall', 'handwerker', 'euro', 'metall', 'die kaltkreissäge', 'im jahr 2012']
#
# Precision: 0.2857142857142857
# Recall: 1.0
# F1-Score: 0.4444444444444445
# ___________________________
# Presseinformation: 2014 0218
# Goldstandard: ['wechsel', 'vorstand', 'ruhestand', 'manager']
# Predicted: ['april', 'februar', 'wechsel', 'vorstand', 'ruhestand', 'manager', 'im jahr 2014']
#
# Precision: 0.5714285714285714
# Recall: 1.0
# F1-Score: 0.7272727272727273
# ___________________________
# Presseinformation: 2014 0912
# Goldstandard: []
# Predicted: ['euro', 'gmbh', 'milliarde', 'unternehmen', 'leistung', '50-prozent-anteils 3 milliarden euro', 'im jahr 1967', 'smart home-konzepten', 'im jahr 2013', 'internet', 'zeit zu zeit']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2015 0405
# Goldstandard: ['absicherung']
# Predicted: ['april', 'werk', 'hersteller', 'traktor', 'absicherung', 'lösung', 'brandmeldeanlage serie 5000']
#
# Precision: 0.14285714285714285
# Recall: 1.0
# F1-Score: 0.25
# ___________________________
# Presseinformation: 2015 0908
# Goldstandard: ['unternehmen', 'übernahme', 'ausbau']
# Predicted: ['unternehmen', 'übernahme', 'ausbau', 'region', 'englische', 'im jahr 2014']
#
# Precision: 0.5
# Recall: 1.0
# F1-Score: 0.6666666666666666
# ___________________________
# Presseinformation: 2016 0501
# Goldstandard: ['sicherheit', 'straßenbahnen', 'unfall', 'beifahrer']
# Predicted: ['straßenbahnen', 'bahn', 'sicherheit', 'information', 'mai', 'fahrer', 'unfall', 'beifahrer', 'tag und nacht', 'jahr 2014', 'internet']
#
# Precision: 0.8181818181818182
# Recall: 1.0
# F1-Score: 0.9
# ___________________________
# Presseinformation: 2016 0922
# Goldstandard: ['werkstätte', 'dienstleistung', 'betreuung', 'service']
# Predicted: ['werkstätte', 'information', 'dienstleistung', 'betreuung', 'september', 'service', 'die reparaturbetriebe']
#
# Precision: 0.7142857142857143
# Recall: 1.0
# F1-Score: 0.8333333333333333
# ___________________________
# Presseinformation: 2017 0303
# Goldstandard: ['rallye', 'bosch boxberg klassik rallye']
# Predicted: ['juni', 'klassik', 'märz', 'höhepunkt', 'information', 'lösung', 'aa dr', 'karlsruhe', 'oldtimer-rallye bosch boxberg klassik', 'rallye', 'bosch boxberg klassik', 'internet']
#
# Precision: 0.25
# Recall: 1.0
# F1-Score: 0.4
# ___________________________
# Presseinformation: 2018 0204
# Goldstandard: ['fahrrad-leasing', 'mitarbeiter', 'gesundheit', 'sport']
# Predicted: ['mitarbeiter', 'förderung', 'unternehmen', 'stadt', 'gesundheit', 'bosch ebike-marktstudie', 'britische']
#
# Precision: 0.2857142857142857
# Recall: 0.5
# F1-Score: 0.36363636363636365
# ___________________________
# Presseinformation: 2019 0501
# Goldstandard: ['online', 'computer aided service']
# Predicted: ['online', 'information', 'mai', 'zugriff', 'karlsruhe', 'zeit', 'd-76225 karlsruhe twitter', 'computer aided service', 'cas plus']
#
# Precision: 0.3333333333333333
# Recall: 1.0
# F1-Score: 0.5
# ___________________________
# Presseinformation: 2019 1103
# Goldstandard: ['landwirtschaft', 'effizienz', 'automatisierung', 'vernetzung']
# Predicted: ['landwirtschaft', 'service', 'automatisierung', 'vernetzung', 'unternehmen', 'kosten', 'agritechnica innovation award', 'zeit', 'nevonex powered by bosch', 'feature', 'nevonex by bosch']
#
# Precision: 0.36363636363636365
# Recall: 1.0
# F1-Score: 0.5333333333333333
# ___________________________
# 0.1589736181692703 0.3644927536231884 0.2092952303111007

# %%
#Produkt-Index

all_prod_precision = []
all_prod_recall = []
all_prod_f1 = []
for filename in os.listdir(r"C:\Users\Goegg\OneDrive\Desktop\zu annotieren"):
    
    pi_name = get_PI(filename)
    print("Presseinformation:", pi_name)
    #get prod-pred
    df_pred = pd.read_excel(os.path.join(directory, pi_name + extension), header=0)
    pred_prod_out = df_pred['Produkt-Index'].tolist()
    pred_prod = [x for x in pred_prod_out if x == x]
    #get prod-gold
    df_gold = pd.read_excel(goldstandard, pi_name)
    gold_prod_out = df_gold['Produkt-Index'].tolist()
    gold_prod = [lemmatizer(x, NOUN)[0].lower() for x in gold_prod_out if x == x]
    print("Goldstandard:", gold_prod)
    print("Predicted:", pred_prod, "\n")
    if len(gold_prod) == 0 and len(pred_prod) == 0:
        print("both nothing\n __________________________")
        all_prod_precision.append(1.0)
        all_prod_recall.append(1.0)
        all_prod_f1.append(1.0)
        continue
    else:
        print("Precision:", precision(gold_prod, pred_prod))
        print("Recall:", recall(gold_prod, pred_prod))
        print("F1-Score:", f1(gold_prod, pred_prod), "\n___________________________")
        all_prod_precision.append(precision(gold_prod, pred_prod))
        all_prod_recall.append(recall(gold_prod, pred_prod))
        all_prod_f1.append(f1(gold_prod, pred_prod))
        
mean_prod_precision = sum(all_prod_precision) / len(all_prod_precision)
mean_prod_recall = sum(all_prod_recall) / len(all_prod_recall)
mean_prod_f1 = sum(all_prod_f1) / len(all_prod_f1)    
print(mean_prod_precision, mean_prod_recall, mean_prod_f1)
# Out:
# Presseinformation: 2000 0310
# Goldstandard: ['ahs 6000 pro', 'ahs 7000']
# Predicted: ['maßstab', 'messer']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2000 0702
# Goldstandard: ['leiterplatten']
# Predicted: ['anforderung', 'leiterplatten', 'fax']
#
# Precision: 0.3333333333333333
# Recall: 1.0
# F1-Score: 0.5
# ___________________________
# Presseinformation: 2000 1009
# Goldstandard: ['slk 320', 'zündkerze']
# Predicted: ['anforderung', 'elektrode']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2001 0350
# Goldstandard: ['silver plus', 'powercontrol system', 'esp', 'common rail', 'bea 350', 'zündkerze', 'funline']
# Predicted: ['start', 'produktvorteil powercontrol system']
#
# Precision: 1.0
# Recall: 0.2857142857142857
# F1-Score: 0.4444444444444445
# ___________________________
# Presseinformation: 2001 0909
# Goldstandard: ['quadro-x', 'sägeblätter']
# Predicted: ['qualität', 'ausführung']
#
# Precision: 0.5
# Recall: 0.5
# F1-Score: 0.5
# ___________________________
# Presseinformation: 2002 0114
# Goldstandard: ['starter']
# Predicted: ['telefon', 'telefax', 'motronic', 'travel pilot navigationssystem', 'this magneto ignition system', 'electronic fucl injection', 'ari traffic information system', 'contact-frce transistor ignition', 'automatie slip control', 'travel pilot navigation system', 'common rail high-pressure diesel injection', 'direct petrol injection']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2002 0403
# Goldstandard: ['bremse', 'bremsanlage']
# Predicted: ['bremse', 'fahrzeug', 'bremsanlage', 'auto']
#
# Precision: 0.5
# Recall: 1.0
# F1-Score: 0.6666666666666666
# ___________________________
# Presseinformation: 2002 0710
# Goldstandard: []
# Predicted: ['sensotronic brake control']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2002 1008
# Goldstandard: []
# Predicted: ['suche', 'produkt']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2003 0212
# Goldstandard: ['handkreissägen', 'säge']
# Predicted: ['säge']
#
# Precision: 1.0
# Recall: 0.5
# F1-Score: 0.6666666666666666
# ___________________________
# Presseinformation: 2003 0512
# Goldstandard: ['zündkerze', 'rasenmäher', 'rasentrimmer', 'blattgebläse', 'gartentraktoren', 'heckenscheren', 'kettensägen', 'laubsauger', 'motorsensen', 'netzstromaggregate', 'wasserpumpen', 'schneefräsen', 'schneewerfer']
# Predicted: ['zündkerze', 'telefon', 'automobile']
#
# Precision: 0.3333333333333333
# Recall: 0.07692307692307693
# F1-Score: 0.125
# ___________________________
# Presseinformation: 2003 0811
# Goldstandard: ['sds-plus-flachmeißel', 'meißel']
# Predicted: ['fax']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2003 1203
# Goldstandard: ['eazeo', 'kamera']
# Predicted: ['kamera', 'ein wetterfestes kameragehäuse']
#
# Precision: 1.0
# Recall: 1.0
# F1-Score: 1.0
# ___________________________
# Presseinformation: 2004 0317
# Goldstandard: ['kettensägen', 'sägekette']
# Predicted: ['mittwoch']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2004 0615
# Goldstandard: ['wärmeübertrager', 'cerasmart']
# Predicted: ['heizgerät', 'wasser']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2004 0951
# Goldstandard: ['esp', 'load adaptive control']
# Predicted: ['messtechnik']
#
# Precision: 1.0
# Recall: 0.5
# F1-Score: 0.6666666666666666
# ___________________________
# Presseinformation: 2005 0112
# Goldstandard: []
# Predicted: []
#
# both nothing
#  __________________________
# Presseinformation: 2005 0607
# Goldstandard: ['autodome-kameras']
# Predicted: ['kamera']
#
# Precision: 1.0
# Recall: 1.0
# F1-Score: 1.0
# ___________________________
# Presseinformation: 2005 0951
# Goldstandard: ['travelpilot rome', 'radio']
# Predicted: ['elektrik', 'elektronik', 'fahrzeug', 'akku', 'touchscreen', 'telefon', 'signal']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2006 0307
# Goldstandard: ['piezo-injektoren']
# Predicted: ['brennraum']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2006 0911
# Goldstandard: ['bosch-sds-system', 'maschine', 'säge']
# Predicted: ['säge', 'komfort', 'maßstab', 'maschine', 'pt ms']
#
# Precision: 0.4
# Recall: 0.6666666666666666
# F1-Score: 0.5
# ___________________________
# Presseinformation: 2007 0307
# Goldstandard: ['winkelschleifer ', 'vibration control']
# Predicted: ['maschine']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2007 1001
# Goldstandard: []
# Predicted: ['automobile', 'produkt']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2008 0318
# Goldstandard: ['lautsprecher']
# Predicted: ['lautsprecher']
#
# Precision: 1.0
# Recall: 1.0
# F1-Score: 1.0
# ___________________________
# Presseinformation: 2008 1101
# Goldstandard: ['esp®']
# Predicted: ['wissen', 'nutzen', 'elektronischen stabilitäts-programms esp', 'intelligent car']
#
# Precision: 0.25
# Recall: 1.0
# F1-Score: 0.4
# ___________________________
# Presseinformation: 2009 0419
# Goldstandard: ['aktivkohle-innenraumfilter', 'innenraumfilter']
# Predicted: []
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2009 1004
# Goldstandard: []
# Predicted: ['vorteil']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2010 0701
# Goldstandard: ['kamera']
# Predicted: ['kamera', 'überwachung', 'speicherung', 'open network video interface forum', 'secure digital', 'pcs']
#
# Precision: 0.6666666666666666
# Recall: 1.0
# F1-Score: 0.8
# ___________________________
# Presseinformation: 2010 1019
# Goldstandard: ['mörtel', 'mörtelentferner', 'oscillating interface system']
# Predicted: ['zubehör']
#
# Precision: 1.0
# Recall: 0.3333333333333333
# F1-Score: 0.5
# ___________________________
# Presseinformation: 2011 0326
# Goldstandard: []
# Predicted: []
#
# both nothing
#  __________________________
# Presseinformation: 2011 0807
# Goldstandard: ['dornrad-paketieranlage', 'paketieranlage']
# Predicted: ['maschine']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2012 0113
# Goldstandard: ['smartphones', 'drehratensensor', 'sensor', 'applikation', 'telefon']
# Predicted: ['sensor', 'smartphones', 'sensor', 'applikation', 'funktionalität', 'telefon']
#
# Precision: 0.8333333333333334
# Recall: 1.0
# F1-Score: 0.9090909090909091
# ___________________________
# Presseinformation: 2012 0808
# Goldstandard: ['rückförderpumpe', 'adaptive cruise control', 'hill hold control']
# Predicted: ['komfort', 'version', 'adaptive cruise control', 'cruise control']
#
# Precision: 0.5
# Recall: 0.6666666666666666
# F1-Score: 0.5714285714285715
# ___________________________
# Presseinformation: 2013 0201
# Goldstandard: ['schlagbohrschrauber', 'schlagfunktion', 'akku']
# Predicted: ['akku', 'akku']
#
# Precision: 0.5
# Recall: 0.3333333333333333
# F1-Score: 0.4
# ___________________________
# Presseinformation: 2013 0618
# Goldstandard: []
# Predicted: ['zukunft', 'was menschen wichtig ist']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2013 0947
# Goldstandard: ['kaltkreissäge', 'expert for steel']
# Predicted: []
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2014 0218
# Goldstandard: []
# Predicted: []
#
# both nothing
#  __________________________
# Presseinformation: 2014 0912
# Goldstandard: ['hausgeräte']
# Predicted: ['aussage', 'hausgeräte']
#
# Precision: 0.5
# Recall: 1.0
# F1-Score: 0.6666666666666666
# ___________________________
# Presseinformation: 2015 0405
# Goldstandard: ['traktor', 'serie 5000']
# Predicted: []
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2015 0908
# Goldstandard: []
# Predicted: []
#
# both nothing
#  __________________________
# Presseinformation: 2016 0501
# Goldstandard: ['rail control unit']
# Predicted: ['system']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2016 0922
# Goldstandard: []
# Predicted: []
#
# both nothing
#  __________________________
# Presseinformation: 2017 0303
# Goldstandard: []
# Predicted: ['telefon', 'fahrzeug', 'bremse', 'internet der dinge', 'iot cloud']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# Presseinformation: 2018 0204
# Goldstandard: ['fahrrad', 'ebikes']
# Predicted: ['fahrrad', 'internet der dinge', 'iot cloud']
#
# Precision: 0.3333333333333333
# Recall: 0.5
# F1-Score: 0.4
# ___________________________
# Presseinformation: 2019 0501
# Goldstandard: ['esitronic', 'festplatte']
# Predicted: ['datum', 'festplatte', 'internet der dinge', 'iot cloud']
#
# Precision: 0.25
# Recall: 0.5
# F1-Score: 0.3333333333333333
# ___________________________
# Presseinformation: 2019 1103
# Goldstandard: ['nevonex']
# Predicted: ['effizienz', 'gerät', 'internet der dinge', 'iot cloud']
#
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# ___________________________
# 0.38913043478260867 0.4100573339703775 0.3706513896731288

# %%
print("Standard Deviation of Precision/Products is ", np.std(all_thema_precision))
# Out:
# Standard Deviation of Precision/Products is  0.22662733593975792

# %% [markdown]
# ###

# %% [markdown]
# ######
